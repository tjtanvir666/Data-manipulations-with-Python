# %%
import numpy as np
import requests
import urllib, json
import urllib.request
import urllib.parse
from urllib.request import urlopen
from urllib.parse import urlencode
from bs4 import BeautifulSoup
from pandas.io.json import json_normalize
import pandas as pd
import selenium
import pprint
from datetime import datetime
import dateutil.parser
import math

# %%
#need to know YQL for query
baseurl = "https://query.yahooapis.com/v1/public/yql?"
yql_query = "select wind from weather.forecast where woeid=2460286"
yql_url = baseurl + urlencode({'q':yql_query}) + "&format=json"
result = urlopen(yql_url).read()
data = json.loads(result)
print (data['query']['results'])
# Out:
# {'channel': {'wind': {'chill': '50', 'direction': '248', 'speed': '11'}}}

# %% [markdown]
# ## Parsing HTML

# %%
#url of the page
url = "https://openweathermap.org/find?utf8=%E2%9C%93&q=cyberjaya"

#open the page and return it to the page
page = urlopen(url)

# parse the html using beautiful soup and store in variable `soup`
soup = BeautifulSoup(page, "html.parser")

# %%
weather = soup.find('div', attrs={'class':'forcast_list_'})
print(weather)
# Out:
# None

# %%
print(soup)
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="Tue, Sep 20 2018 15:27:22 GMT" http-equiv="Expires"/>
# <meta content="Tue, Sep 20 2018 15:27:22 GMT" http-equiv="Last-Modified"/>
# <!--<meta http-equiv="X-UA-Compatible" content="IE=edge">-->
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <meta content="weather, world, Openstreetmap, forecast, Openweather, current" name="keywords"/>
# <meta content="" name="description"/>
# <meta content="OpenWeatherMap.org" name="author"/>
# <meta content="OpenWeatherMap.org" name="domain"/>
# <meta content="34fe229eab8562dca90f4a5962ff80a9" name="p:domain_verify">
# <meta content="Find" property="title">
# <link href="/themes/openweathermap/assets/vendor/owm/img/icons/favicon.ico" rel="shortcut icon"/>
# <link href="/themes/openweathermap/assets/vendor/owm/img/icons/logo_16x16.png" rel="icon" sizes="16x16" type="image/png"/>
# <link href="/themes/openweathermap/assets/vendor/owm/img/icons/logo_32x32.png" rel="icon" sizes="32x32" type="image/png"/>
# <link href="/themes/openweathermap/assets/vendor/owm/img/icons/logo_60x60.png" rel="icon" sizes="60x60" type="image/png"/>
# <title>Find - OpenWeatherMap</title>
# <script type="text/javascript">
#   var _gaq = _gaq || [];
#   _gaq.push(['_setAccount', 'UA-31601618-1']);
#   _gaq.push(['_setDomainName', 'openweathermap.org']);
#   _gaq.push(['_trackPageview']);
#   (function() {
#     var ga = document.createElement('script'); ga.type = 'text/javascript'; ga.async = true;
#     ga.src = ('https:' == document.location.protocol ? 'https://ssl' : 'http://www') + '.google-analytics.com/ga.js';
#     var s = document.getElementsByTagName('script')[0]; s.parentNode.insertBefore(ga, s);
#   })();
# </script>
# <script crossorigin="anonymous" integrity="sha256-wS9gmOZBqsqWxgIVgA8Y9WcQOa7PgSIX+rPA0VL2rbQ=" src="//code.jquery.com/jquery-1.9.1.min.js"></script>
# <script src="https://cdn.polyfill.io/v2/polyfill.min.js?features=Array.from,Array.assign,fetch&amp;flags=always,gated"></script>
# <script src="/themes/openweathermap/assets/js/bundle_owm_preload.7e226f96a22e359da6e5.js"></script>
# <link href="/themes/openweathermap/assets/css/bundle_owm_styles.7e226f96a22e359da6e5.css" rel="stylesheet"/>
# <link href="/themes/openweathermap/assets/css/stick_footer_panel.7e226f96a22e359da6e5.css" rel="stylesheet"/>
# <!-- Resources -->
# <!--link href='/themes/openweathermap/assets/vendor/mosaic/fonts/font-awesome/css/font-awesome.min.css' rel="stylesheet"-->
# <link crossorigin="anonymous" href="https://maxcdn.bootstrapcdn.com/font-awesome/4.7.0/css/font-awesome.min.css" integrity="sha384-wvfXpqpZZVQGK6TAh5PVlGOfQNHSoD2xbE+QkPxCAFlNEevoEH3Sl0sibVcOQVnN" rel="stylesheet"/>
# <link href="https://fonts.googleapis.com/css?family=Oswald:400,700,300" rel="stylesheet"/>
# <link href="https://fonts.googleapis.com/css?family=Roboto:400,700,500,400italic,500italic" rel="stylesheet"/>
# </meta></meta></head>
# <body class="body-orange">
# <!-- Extra Bar -->
# <div class="mini-navbar mini-navbar-dark">
# <div class="container">
# <div class="row">
# <div class="col-lg-9 col-md-9 col-sm-9 hidden-xs">
# <a class="first-child" href="//openweathermap.desk.com/" target="_blank">
# <i class="fa fa-envelope"> </i> <span class="hidden-xs">Support Center</span></a>
# <a class="pull-right" href="//home.openweathermap.org/users/sign_up" onclick="_gaq.push(['_trackEvent', 'Navbar', 'Main', 'register']);"><i class="fa fa-arrow-circle-down"></i> Sign Up</a>
# <a class="pull-right" href="//home.openweathermap.org/users/sign_in" onclick="_gaq.push(['_trackEvent', 'Navbar', 'Main', 'signin']);"><i class="fa fa-sign-in"></i> Sign In</a>
# <a class="pull-right" href="#" id="nav-search"><i class="fa fa-search" onclick="_gaq.push(['_trackEvent', 'Navbar', 'Main', 'search']);"></i> Weather in your city</a>
# <a class="pull-right hidden" href="#" id="nav-search-close"><i class="fa fa-times"></i></a>
# <!-- Search Form -->
# <form action="/find" class="pull-right hidden" id="nav-search-form" method="get" role="search">
# <div class="input-group">
# <input class="form-control" id="q" name="q" placeholder="Search" type="text"/>
# <span class="input-group-btn">
# <button class="btn btn-default" type="submit"><i class="fa fa-search"></i></button>
# </span>
# </div>
# </form>
# </div>
# <div class="col-lg-3 col-md-3 col-sm-3 units-selector">
# <label class="toggle candy blue" onclick="" style="width:100px;animation:none;position:fixed;top:0">
# <input checked="checked" id="units_check" type="checkbox"/>
# <p><span id="metric">  °C</span><span id="imperial">°F</span></p>
# <a class="slide-button"></a><a class="slide-button"></a>
# </label>
# </div>
# </div>
# </div>
# </div>
# <div class="navbar navbar-dark navbar-static-top" role="navigation">
# <div class="container">
# <div class="row">
# <!-- Navbar Header -->
# <div class="col-lg-3 col-md-3 col-sm-5 col-xs-8 navbar-header">
# <a class="navbar-brand" href="/">
# <img alt="openweathermap" class="img-responsive" height="30" src="/themes/openweathermap/assets/vendor/owm/img/logo_OpenWeatherMap_orange.svg" width="240"/>
# </a>
# </div>
# <!-- / Navbar Header -->
# <!-- Navbar toggle -->
# <button class="navbar-toggle" data-target=".navbar-collapse" data-toggle="collapse" type="button">
# <span class="sr-only">Toggle navigation</span>
# <span class="icon-bar"></span>
# <span class="icon-bar"></span>
# <span class="icon-bar"></span>
# </button>
# <!-- Navbar Links -->
# <div class="col-lg-9 col-md-9 col-sm-7 col-xs-12 navbar-collapse collapse">
# <ul class="nav navbar-nav navbar-right">
# <li class="visible-xs"><a class="bg-hover-color" href="//home.openweathermap.org/users/sign_in"><i class="fa fa-sign-in"></i>  Sign In</a></li>
# <li class="visible-xs"><a class="bg-hover-color" href="//home.openweathermap.org/users/sign_up"><i class="fa fa-arrow-circle-down"></i>  Sign up</a></li>
# <li class="nav__item"><a class="nav__link bg-hover-color" href="/city" onclick="_gaq.push(['_trackEvent', 'Navbar', 'Main', 'weather']);">Weather</a></li>
# <li class="nav__item dropdown">
# <a class="nav__link dropdown-toggle bg-hover-color" data-toggle="dropdown" href="#">Maps <b class="caret"></b></a>
# <ul class="dropdown-menu">
# <li><a class="bg-hover-color" href="/weathermap">Weather maps</a></li>
# <li><a class="bg-hover-color" href="/weathermap?basemap=satellite&amp;cities=false&amp;layer=precipitation&amp;lat=30&amp;lon=-20&amp;zoom=3" target="_blank">Current satellite maps</a></li>
# <li><a class="bg-hover-color" href="//owm.io/beautiful_maps" target="_blank">Beautiful places</a></li>
# </ul>
# </li>
# <li class="nav__item"><a class="nav__link bg-hover-color" href="/api" onclick="_gaq.push(['_trackEvent', 'Navbar', 'Main', 'api']);">API</a></li>
# <li class="nav__item"><a class="nav__link bg-hover-color" href="/price" onclick="_gaq.push(['_trackEvent', 'Navbar', 'Main', 'price']);">Price</a></li>
# <li class="nav__item"><a class="nav__link bg-hover-color" href="/examples" onclick="_gaq.push(['_trackEvent', 'Navbar', 'Main', 'examples']);">Partners</a></li>
# <li class="nav__item"><a class="nav__link bg-hover-color" href="/stations" onclick="_gaq.push(['_trackEvent', 'Navbar', 'Main', 'station']);">Stations</a></li>
# <li class="nav__item"><a class="nav__link bg-hover-color" href="/widgets-constructor" onclick="_gaq.push(['_trackEvent', 'Navbar', 'Main', 'widgets']);">Widgets</a></li>
# <li class="nav__item"><a class="nav__link bg-hover-color" href="/news" onclick="_gaq.push(['_trackEvent', 'Navbar', 'Main', 'news']);">News</a></li>
# </ul>
# <!-- Search Form (xs) -->
# <!--
#         <form class="navbar-form navbar-left visible-xs" role="search">
#           <div class="form-group">
#             <input type="text" class="form-control" placeholder="Search">
#           </div>
#           <button type="submit" class="btn btn-default">Go!</button>
#         </form>
#         -->
# <!-- / Search Form (xs) -->
# </div>
# <!-- / Navbar Links -->
# </div>
# </div>
# <!-- / container -->
# </div>
# <!-- / navbar -->
# <div id="notes_block"></div>
# <main class="wrapper">
# <div class="container">
# <div class="row">
# <div class="col-sm-12">
# <h2 class="headline first-child text-color"><span class="border-color">Weather in your city</span></h2>
# </div>
# </div> <!-- / .row -->
# </div> <!-- / .container -->
# <div class="color-jumbotron jumbotron-green">
# <div class="container">
# <div class="row">
# <div class="col-sm-12">
# <form action="#" class="form-inline text-center first-child" id="searchform" method="get" onsubmit="FindCity(); return false" role="form">
# <div class="form-group">
# <label class="sr-only" for="help-search">Search</label>
# <input class="form-control border-color col-sm-12" id="search_str" name="q" onfocus="this.value = (this.value=='London, UK')? '' : this.value;" value="cyberjaya"/>
# </div>
# <button class="btn btn-color" type="submit"><i class="fa fa-question-circle"></i> Search</button>
# </form>
# </div>
# </div> <!-- / .row -->
# </div> <!-- / .container -->
# </div> <!-- / .color-jumbotron -->
# <div class="progress progress-striped active" id="pbar" style="visibility: none">
# <div class="bar" style="width: 100%;"></div>
# </div>
# <div class="container">
# <div class="row">
# <div class="col-sm-12">
# <div class="tab-pane active" id="forecast-list">
# <div id="forecast_list_ul"></div>
# </div>
# </div>
# </div>
# </div>
# <div class="container">
# <div class="row">
# <div class="col-sm-12">
# <h3>Search engine is very flexible. How it works:</h3>
# <ul>
# <li>Put the city's name or its part and get the list of the most proper cities in the world. Example - <b>Lon</b> or
#       <b>Lond</b> or <b>London</b>. The more precise city name you put the more precise list you will get. </li>
# <li> To make it more precise put the city's name or its part, comma, the name of the country or 2-letter country code.
#     You will get all proper cities in chosen country. The order is important - the first is city name then comma then country. Example - <b>Lon, UK</b> or <b>Lon, GB</b> or <b>London, GB</b> or <b>Lon, England</b>.</li>
# </ul>
# </div>
# </div>
# </div>
# <script type="text/javascript">
#
# 'use strict';
#
# $("#pbar").hide("fast");
#
# function ShowAlertMess(mess)
# {
#   	var html = '<div class="alert alert-warning" role="alert"><a class="close" data-dismiss="alert" href="#">×</a>'+mess+'</div>';
#     $("#forecast_list_ul").html(html);
# }
#
# function getSearchData(JSONobject) {
#   //console.log( JSONobject  );
#   //JSONobject = ParseJson(JSONtext);
#
#   var city = JSONobject.list;
#   if( city.length == 0 ) {
#     ShowAlertMess( 'Not found' );
#     return;
#   }
#
#   var html = '';
#
#   for(var i = 0; i <  JSONobject.list.length; i ++){
#
#
#     var name = JSONobject.list[i].name +', '+JSONobject.list[i].sys.country;
#
#     var temp = Math.round(10*(JSONobject.list[i].main.temp -273.15))/10 ;
#     var tmin = Math.round(10*(JSONobject.list[i].main.temp_min -273.15)) / 10;
#     var tmax = Math.round(10*(JSONobject.list[i].main.temp_max -273.15)) / 10 ;
#
#     var text = JSONobject.list[i].weather[0].description;
#     var img =  "http://openweathermap.org/img/w/" +JSONobject.list[i].weather[0].icon + ".png";
#     var flag = "http://openweathermap.org/images/flags/" +JSONobject.list[i].sys.country.toLowerCase()  + ".png";
#     var gust = JSONobject.list[i].wind.speed;
#     var pressure = JSONobject.list[i].main.pressure ;
#     var cloud=JSONobject.list[i].clouds.all ;
#
#
#     var row = '<tr><td><img src="' + img + '"></td><td><b><a href="/city/' + JSONobject.list[i].id + '"> ' + name + '</a></b> <img src="' + flag + '" ><b><i> ' + text + '</i></b><p><span class="badge badge-info">' + temp + '°С </span> temperature from '+ tmin + ' to ' + tmax + ' °С, wind ' + gust+ ' m/s. clouds ' + cloud + ' %, ' + pressure + ' hpa</p><p>Geo coords <a href="/weathermap?zoom=12&lat=' + JSONobject.list[i].coord.lat + '&lon=' + JSONobject.list[i].coord.lon + '">[' + JSONobject.list[i].coord.lat + ', ' + JSONobject.list[i].coord.lon + ']</a></p></td></tr>';
#
#
#    /* var column = `<td><img src="${img}"></td><td><b><a href="/city/${JSONobject.list[i].id}"> ${name}</a></b> <img src="${flag}"><b><i> ${text}</i></b><p><span class="badge badge-info">${temp} °С </span> temperature from ${tmin} to ${tmax}°С, wind ${gust} m/s. clouds ${cloud}%, ${pressure} hpa</p><p>Geo coords <a href="/weathermap?zoom=12&lat=${JSONobject.list[i].coord.lat}&lon=${JSONobject.list[i].coord.lon}">[${JSONobject.list[i].coord.lat}, ${JSONobject.list[i].coord.lon}]</a></p></td>`;
#     var row = `<tr>${column}</tr>`;
#     */
#
#     html = html + row;
#
#   }
#
#    /* html=`<table class="table">${html}</table>`; */
#    html='<table class="table">' + html + '</table>';
#
#   $("#forecast_list_ul").html(html);
#   //ShowInfoMess(html);
#   $("#pbar").hide("fast");
#
# }
#
# function FindCity() {
#  // $("#pbar").style.visibility = 'visible';
#   $("#pbar").show("fast");
#   $("#forecast_list_ul").html('');
#   var param = document.getElementById('search_str').value;
#   var jsonurl = "/data/2.5/find?callback=?&q="+param+ "&type=like&sort=population&cnt=30&appid=b6907d289e10d714a6e88b30761fae22";
#   $.getJSON(jsonurl, getSearchData).error();
#   return false;
# }
#
# function GetURLParameter(sParam)
# {
#     var sPageURL = window.location.search.substring(1);
#     var sURLVariables = sPageURL.split('&');
#     for (var i = 0; i < sURLVariables.length; i++)
#     {
#         var sParameterName = sURLVariables[i].split('=');
#         if (sParameterName[0] == sParam)
#         {
#             return sParameterName[1];
#         }
#     }
# }
#
# var q = GetURLParameter('q');
# if ( q ) {
# FindCity();
# }
#
#
# </script>
# <div class="container">
# <div class="row">
# <div class="col-sm-12">
# <script async="" src="//pagead2.googlesyndication.com/pagead/js/adsbygoogle.js"></script>
# <!-- OWM long bottom -->
# <ins class="adsbygoogle" data-ad-client="ca-pub-9649553505534207" data-ad-slot="1070308379" style="display:inline-block;width:728px;height:90px"></ins>
# <script>
# (adsbygoogle = window.adsbygoogle || []).push({});
# </script> </div>
# </div>
# </div>
# </main>
# <div id="stick-footer-panel"></div>
# <!-- Footer -->
# <footer class="footer-dark">
# <div class="container">
# <div class="row">
# <!-- API -->
# <div class="col-sm-4">
# <h3 class="text-color">Weather in your city</h3>
# <ul>
# <li><a href="../find?q=">Find your city</a></li>
# <li><a href="../weathermap">Weather maps</a></li>
# </ul>
# <h3 class="text-color">Weather APIs</h3>
# <div class="content">
# <ul>
# <li><a href="../appid">How to start</a></li>
# <li><a href="../api">Weather APIs for developers</a></li>
# <li><a href="../current">Current weather</a></li>
# <li><a href="../forecast5">5 day / 3 hour weather forecast</a></li>
# <li><a href="../forecast16">16 day / daily weather forecast</a></li>
# <li><a href="../history">Hourly historical data</a></li>
# <li><a href="../history-bulk">History bulk</a></li>
# <li><a href="../examples">Examples of API use</a></li>
# </ul>
# </div>
# </div>
# <!-- Map layers -->
# <div class="col-sm-4">
# <h3 class="text-color">Map layers</h3>
# <div class="content">
# <ul>
# <li><a href="../api/weathermaps#examples"> Examples of weather map layers</a>
# <li><a href="../api/weathermaps#legend"> Map styles legend</a></li>
# <li><a href="../api/weathermaps#library"> Libraries to connect weather layers</a></li>
# </li></ul>
# <h3 class="text-color">How to subscribe</h3>
# <ul>
# <li><a href="../price">Price-list</a></li>
# <li><a href="../price_subscribe">Subscribe to APIs</a></li>
# </ul>
# <div class="alert alert-info">
#             Found a bug? Have a question or idea? Welcome to
#             <a class="alert-link" href="https://openweathermap.desk.com/customer/portal/emails/new" target="_blank">Support center
#             </a>
# </div>
# <div class="clearfix">
# </div>
# </div>
# </div>
# <!-- Column 3 -->
# <div class="col-sm-4">
# <h3 class="text-color">Weather station network</h3>
# <ul>
# <li><a href="../stations">How to connect your weather station</a></li>
# </ul>
# <h3 class="text-color">About</h3>
# <ul>
# <li><a href="/about">About company</a></li>
# <li><a href="/team">Team</a></li>
# <li><a href="/technology">Weather model</a></li>
# </ul>
# <h3 class="text-color">Go Social</h3>
# <ul>
# <li>
# <p>Follow OpenWeatherMap on </p>
# <div class="content social">
# <div class="main-footer__socials"><a class="icon-social" href="https://www.facebook.com/groups/270748973021342" target="_blank" title="facebook"><i aria-hidden="true" class="fa fa-facebook"></i></a><a class="icon-social" href="https://twitter.com/OpenWeatherMap" target="_blank" title="twitter"><i aria-hidden="true" class="fa fa-twitter"></i></a><a class="icon-social" href="https://www.linkedin.com/company/9816754" target="_blank" title="linkedin"><i aria-hidden="true" class="fa fa-linkedin"></i></a><a class="icon-social" href="https://www.instagram.com/openweathermap/" target="_blank"><i aria-hidden="true" class="fa fa-instagram"></i></a><a class="icon-social" href="https://t.me/openweathermap" target="_blank"><i aria-hidden="true" class="fa fa-telegram"></i></a><a class="icon-social" href="https://github.com/search?q=openweathermap&amp;ref=cmdform" target="_blank"><i aria-hidden="true" class="fa fa-github"></i></a></div>
# </div>
# </li>
# </ul>
# </div>
# </div>
# <div class="row">
# <div class="col-sm-12">
# <hr/>
# </div>
# </div>
# <!-- Copyrights -->
# <div class="row">
# <div class="col-sm-12">
# <p>© 2012 — <span id="template-current-year">2018</span> OpenWeather ® All rights reserved. <a href="/about">Our company</a> |
#         <a href="https://openweather.co.uk/privacy-policy" target="_blank">Privacy Policy</a> |
#         <a href="/terms">Terms of Service</a></p>
# </div>
# </div>
# </div>
# </footer>
# <script src="https://cdn.ravenjs.com/3.6.1/raven.min.js"></script>
# <script>Raven.config('http://66df88eb63e94f27964b84031e49b358@sentry.owm.io/16').install()</script>
# <script src="/themes/openweathermap/assets/js/bundle_owm_postload.7e226f96a22e359da6e5.js"></script>
# <script src="/themes/openweathermap/assets/js/stick_footer_panel.7e226f96a22e359da6e5.js"></script>
# </body>
# </html>

# %%
#city_name = "cyberjaya,malaysia"
#city_name = input("City name: ")
api_address = 'https://api.darksky.net/forecast/869a553c7b7938eec974e393c4ee789e/2.9213,101.6559'

print(api_address)math.

url = api_address + city_name

json_data = requests.get(api_address).json()

print(json_data)
# Out:
#   File "<ipython-input-11-b82bf1d580ba>", line 5
#     print(api_address)math.
#                          ^
# SyntaxError: invalid syntax

# %%
#city_name = "cyberjaya,malaysia"
city_name = input("City name: ")
api_address = 'http://api.weatherunlocked.com/api/forecast/2.9213,101.6559?app_id=05df3bc9&app_key=1a91dc19bc73cfe28941c5708bf93849'

print(api_address)

url = api_address + city_name

json_data = requests.get(api_address).json()

print(json_data.latitude)
# Out:
# City name: Melaka
# http://api.weatherunlocked.com/api/forecast/2.9213,101.6559?app_id=05df3bc9&app_key=1a91dc19bc73cfe28941c5708bf93849
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-2-55c16cfa6bef> in <module>()
#       9 json_data = requests.get(api_address).json()
#      10
# ---> 11 print(json_data.latitude)
#
# AttributeError: 'dict' object has no attribute 'latitude'

# %% [markdown]
# ## The weather API Call (Open Weather Map)

# %%
#city_name = 'bukit jalil'
#city_name = input("City name: ")
#api_address = 'http://api.openweathermap.org/data/2.5/weather?q='+ city_name +'&appid=c9b9201a18e08ae3bb54d622f55c6c14'

lat =  6.352057
lon =   99.733603
appid = 'c9b9201a18e08ae3bb54d622f55c6c14'

api_address = 'http://api.openweathermap.org/data/2.5/weather?lat={0}&lon={1}&units=imperial&appid={2}'.format(lat,lon,appid)



print(api_address)

url = api_address + city_name

json_data = requests.get(api_address).json()

pprint.pprint(json_data)
# Out:
# http://api.openweathermap.org/data/2.5/weather?lat=6.352057&lon=99.733603&units=imperial&appid=c9b9201a18e08ae3bb54d622f55c6c14
# {'base': 'stations',
#  'clouds': {'all': 75},
#  'cod': 200,
#  'coord': {'lat': 6.35, 'lon': 99.73},
#  'dt': 1530244800,
#  'id': 6804725,
#  'main': {'humidity': 74,
#           'pressure': 1010,
#           'temp': 84.2,
#           'temp_max': 84.2,
#           'temp_min': 84.2},
#  'name': 'Chabang Wahid',
#  'sys': {'country': 'MY',
#          'id': 8133,
#          'message': 0.0055,
#          'sunrise': 1530227393,
#          'sunset': 1530272351,
#          'type': 1},
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04d',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 130, 'speed': 5.82}}

# %% [markdown]
# #### This is just a test implementationm

# %%
#this tis the location lsit we imported from a csv file of the location
locations = pd.read_csv(r"G:\MovingWalls\location-orgi.csv", header = None)
locationList = locations.values.tolist()
print(len(locationList))
print(str(locationList[0]).strip('[]\''))


r = 0
loclist = []
while r <= len(locationList)-1:
    print(locationList[r])
    place = str(locationList[r]).strip('[]\'')
    print(r, "\n")
    loclist.append(place)
    r+=1
print(loclist)
# Out:
# 163
# Cheras
# ['Cheras']
# 0
#
# ['Sandakan']
# 1
#
# ['Kajang']
# 2
#
# ['Seremban']
# 3
#
# ['Kuantan']
# 4
#
# ['Tawau']
# 5
#
# ['Kuala Terengganu']
# 6
#
# ['Miri']
# 7
#
# ['Kota Bharu']
# 8
#
# ['Selayang Baru']
# 9
#
# ['Subang Jaya']
# 10
#
# ['Kuala Lumpur']
# 11
#
# ['Klang']
# 12
#
# ['Johor Bahru']
# 13
#
# ['Ampang']
# 14
#
# ['Ipoh']
# 15
#
# ['Shah Alam']
# 16
#
# ['Kuching']
# 17
#
# ['Petaling Jaya']
# 18
#
# ['Kota Kinabalu']
# 19
#
# ['George Town']
# 20
#
# ['Iskandar Puteri']
# 21
#
# ['Melaka ']
# 22
#
# ['Alor Setar']
# 23
#
# ['Bintulu']
# 24
#
# ['Kampung Baru Subang']
# 25
#
# ['Kota Bharu']
# 26
#
# ['Sungai Petani']
# 27
#
# ['Taiping']
# 28
#
# ['Bukit Mertajam']
# 29
#
# ['Sepang']
# 30
#
# ['Sibu']
# 31
#
# ['Kulim']
# 32
#
# ['Kluang']
# 33
#
# ['Skudai']
# 34
#
# ['Batu Pahat']
# 35
#
# ['Kampung Pasir Gudang Baru']
# 36
#
# ['Kampung Sungai Ara']
# 37
#
# ['Tasek Glugor']
# 38
#
# ['Muar']
# 39
#
# ['Rawang']
# 40
#
# ['Butterworth']
# 41
#
# ['Lahad Datu']
# 42
#
# ['Semenyih']
# 43
#
# ['Port Dickson']
# 44
#
# ['Cukai']
# 45
#
# ['Putatan']
# 46
#
# ['Keningau']
# 47
#
# ['Ulu Tiram']
# 48
#
# ['Victoria']
# 49
#
# ['Taman Senai']
# 50
#
# ['Donggongon']
# 51
#
# ['Segamat']
# 52
#
# ['Kampong Baharu Balakong']
# 53
#
# ['Perai']
# 54
#
# ['Kangar']
# 55
#
# ['Kulai']
# 56
#
# ['Jitra']
# 57
#
# ['Teluk Intan']
# 58
#
# ['Semporna']
# 59
#
# ['Putra Heights']
# 60
#
# ['Temerluh']
# 61
#
# ['Kampong Dungun']
# 62
#
# ['Simpang Empat']
# 63
#
# ['Kuala Selangor']
# 64
#
# ['Kampung Bukit Baharu']
# 65
#
# ['Bandar Labuan']
# 66
#
# ['Kota Tinggi']
# 67
#
# ['Pontian Kechil']
# 68
#
# ['Putrajaya']
# 69
#
# ['Bentong Town']
# 70
#
# ['Banting']
# 71
#
# ['Bedong']
# 72
#
# ['Batu Gajah']
# 73
#
# ['Mentekab']
# 74
#
# ['Nibong Tebal']
# 75
#
# ['Raub']
# 76
#
# ['Kampong Pangkal Kalong']
# 77
#
# ['Lumut']
# 78
#
# ['Kuala Kangsar']
# 79
#
# ['Klebang Besar']
# 80
#
# ['Kampung Ayer Keroh']
# 81
#
# ['Kampung Baharu Nilai']
# 82
#
# ['Tangkak']
# 83
#
# ['Jerantut']
# 84
#
# ['Kudat']
# 85
#
# ['Pekan']
# 86
#
# ['Bahau']
# 87
#
# ['Bakri']
# 88
#
# ['Kuah']
# 89
#
# ['Bidur']
# 90
#
# ['Sarikei']
# 91
#
# ['Kampong Masjid Tanah']
# 92
#
# ['Tanah Merah']
# 93
#
# ['Serendah']
# 94
#
# ['Tampin']
# 95
#
# ['Tapah Road']
# 96
#
# ['Parit Buntar']
# 97
#
# ['Simanggang']
# 98
#
# ['Permatang Kuching']
# 99
#
# ['Yong Peng']
# 100
#
# ['Sungai Besar']
# 101
#
# ['Limbang']
# 102
#
# ['Sungai Udang']
# 103
#
# ['Batu Berendam']
# 104
#
# ['Jenjarum']
# 105
#
# ['Kertih']
# 106
#
# ['Tanjung Tokong']
# 107
#
# ['Ladang Seri Kundang']
# 108
#
# ['Pekan Nenas']
# 109
#
# ['Peringat']
# 110
#
# ['Batu Arang']
# 111
#
# ['Tanjung Sepat']
# 112
#
# ['Mersing']
# 113
#
# ['Labis']
# 114
#
# ['Marang']
# 115
#
# ['Kuang']
# 116
#
# ['Paka']
# 117
#
# ['Bagan Serai']
# 118
#
# ['Alor Gajah']
# 119
#
# ['Batang Berjuntai']
# 120
#
# ['Pelabuhan Klang']
# 121
#
# ['Batu Ferringhi']
# 122
#
# ['Gua Musang']
# 123
#
# ['Kuala Pilah']
# 124
#
# ['Ranau']
# 125
#
# ['Papar']
# 126
#
# ['Kampong Kadok']
# 127
#
# ['Kuala Kedah']
# 128
#
# ['Kampar']
# 129
#
# ['Pasir Mas']
# 130
#
# ['Kampung Simpang Renggam']
# 131
#
# ['Parit Raja']
# 132
#
# ['Bukit Rambai']
# 133
#
# ['Sabak Bernam']
# 134
#
# ['Kepala Batas']
# 135
#
# ['Kampung Tanjung Karang']
# 136
#
# ['Pantai Remis']
# 137
#
# ['Gurun']
# 138
#
# ['Beaufort']
# 139
#
# ['Kapit']
# 140
#
# ['Kinarut']
# 141
#
# ['Kampung Ayer Molek']
# 142
#
# ['Kuala Lipis']
# 143
#
# ['Pantai Cenang']
# 144
#
# ['Bemban']
# 145
#
# ['Kuala Perlis']
# 146
#
# ['Sungai Pelek New Village']
# 147
#
# ['Jertih']
# 148
#
# ['Kelapa Sawit']
# 149
#
# ['Buloh Kasap']
# 150
#
# ['Kota Belud']
# 151
#
# ['Kampung Bukit Tinggi']
# 152
#
# ['Tumpat']
# 153
#
# ['Kuala Sungai Baru']
# 154
#
# ['Juru']
# 155
#
# ['Pulau Sebang']
# 156
#
# ['Chaah']
# 157
#
# ['Ayer Hangat']
# 158
#
# ['Telaga Batu']
# 159
#
# ['Padang Mat Sirat']
# 160
#
# ['Taman Rajawali']
# 161
#
# ['Tanah Rata']
# 162
#
# ['Cheras', 'Sandakan', 'Kajang', 'Seremban', 'Kuantan', 'Tawau', 'Kuala Terengganu', 'Miri', 'Kota Bharu', 'Selayang Baru', 'Subang Jaya', 'Kuala Lumpur', 'Klang', 'Johor Bahru', 'Ampang', 'Ipoh', 'Shah Alam', 'Kuching', 'Petaling Jaya', 'Kota Kinabalu', 'George Town', 'Iskandar Puteri', 'Melaka ', 'Alor Setar', 'Bintulu', 'Kampung Baru Subang', 'Kota Bharu', 'Sungai Petani', 'Taiping', 'Bukit Mertajam', 'Sepang', 'Sibu', 'Kulim', 'Kluang', 'Skudai', 'Batu Pahat', 'Kampung Pasir Gudang Baru', 'Kampung Sungai Ara', 'Tasek Glugor', 'Muar', 'Rawang', 'Butterworth', 'Lahad Datu', 'Semenyih', 'Port Dickson', 'Cukai', 'Putatan', 'Keningau', 'Ulu Tiram', 'Victoria', 'Taman Senai', 'Donggongon', 'Segamat', 'Kampong Baharu Balakong', 'Perai', 'Kangar', 'Kulai', 'Jitra', 'Teluk Intan', 'Semporna', 'Putra Heights', 'Temerluh', 'Kampong Dungun', 'Simpang Empat', 'Kuala Selangor', 'Kampung Bukit Baharu', 'Bandar Labuan', 'Kota Tinggi', 'Pontian Kechil', 'Putrajaya', 'Bentong Town', 'Banting', 'Bedong', 'Batu Gajah', 'Mentekab', 'Nibong Tebal', 'Raub', 'Kampong Pangkal Kalong', 'Lumut', 'Kuala Kangsar', 'Klebang Besar', 'Kampung Ayer Keroh', 'Kampung Baharu Nilai', 'Tangkak', 'Jerantut', 'Kudat', 'Pekan', 'Bahau', 'Bakri', 'Kuah', 'Bidur', 'Sarikei', 'Kampong Masjid Tanah', 'Tanah Merah', 'Serendah', 'Tampin', 'Tapah Road', 'Parit Buntar', 'Simanggang', 'Permatang Kuching', 'Yong Peng', 'Sungai Besar', 'Limbang', 'Sungai Udang', 'Batu Berendam', 'Jenjarum', 'Kertih', 'Tanjung Tokong', 'Ladang Seri Kundang', 'Pekan Nenas', 'Peringat', 'Batu Arang', 'Tanjung Sepat', 'Mersing', 'Labis', 'Marang', 'Kuang', 'Paka', 'Bagan Serai', 'Alor Gajah', 'Batang Berjuntai', 'Pelabuhan Klang', 'Batu Ferringhi', 'Gua Musang', 'Kuala Pilah', 'Ranau', 'Papar', 'Kampong Kadok', 'Kuala Kedah', 'Kampar', 'Pasir Mas', 'Kampung Simpang Renggam', 'Parit Raja', 'Bukit Rambai', 'Sabak Bernam', 'Kepala Batas', 'Kampung Tanjung Karang', 'Pantai Remis', 'Gurun', 'Beaufort', 'Kapit', 'Kinarut', 'Kampung Ayer Molek', 'Kuala Lipis', 'Pantai Cenang', 'Bemban', 'Kuala Perlis', 'Sungai Pelek New Village', 'Jertih', 'Kelapa Sawit', 'Buloh Kasap', 'Kota Belud', 'Kampung Bukit Tinggi', 'Tumpat', 'Kuala Sungai Baru', 'Juru', 'Pulau Sebang', 'Chaah', 'Ayer Hangat', 'Telaga Batu', 'Padang Mat Sirat', 'Taman Rajawali', 'Tanah Rata']

# %%
# this location list is the same as the one above but this is hardcoded, either one can be used
loclist =  ['Cheras', 'Sandakan', 'Kajang', 'Seremban', 'Kuantan', 'Tawau', 'Kuala Terengganu', 'Miri', 'Kota Bharu', 
'Selayang Baru', 'Subang Jaya', 'Kuala Lumpur', 'Klang', 'Johor Bahru', 'Ampang', 'Ipoh', 'Shah Alam', 'Kuching', 
'Petaling Jaya', 'Kota Kinabalu', 'George Town', 'Iskandar Puteri', 'Melaka ', 'Alor Setar', 'Bintulu', 'Kampung Baru Subang',
'Kota Bharu', 'Sungai Petani', 'Taiping', 'Bukit Mertajam', 'Sepang', 'Sibu', 'Kulim', 'Kluang', 'Skudai', 'Batu Pahat', 
'Kampung Pasir Gudang Baru', 'Kampung Sungai Ara', 'Tasek Glugor', 'Muar', 'Rawang', 'Butterworth', 'Lahad Datu', 'Semenyih',
'Port Dickson', 'Cukai', 'Putatan', 'Keningau', 'Ulu Tiram', 'Victoria', 'Taman Senai', 'Donggongon', 'Segamat', 
'Kampong Baharu Balakong', 'Perai', 'Kangar', 'Kulai', 'Jitra', 'Teluk Intan', 'Semporna', 'Putra Heights', 'Temerluh',
'Kampong Dungun', 'Simpang Empat', 'Kuala Selangor', 'Kampung Bukit Baharu', 'Bandar Labuan', 'Kota Tinggi', 'Pontian Kechil',
'Putrajaya', 'Bentong Town', 'Banting', 'Bedong', 'Batu Gajah', 'Mentekab', 'Nibong Tebal', 'Raub', 'Kampong Pangkal Kalong',
'Lumut', 'Kuala Kangsar', 'Klebang Besar', 'Kampung Ayer Keroh', 'Kampung Baharu Nilai', 'Tangkak', 'Jerantut', 'Kudat', 
'Pekan', 'Bahau', 'Bakri', 'Kuah', 'Bidur', 'Sarikei', 'Kampong Masjid Tanah', 'Tanah Merah', 'Serendah', 'Tampin', 
'Tapah Road', 'Parit Buntar', 'Simanggang', 'Permatang Kuching', 'Yong Peng', 'Sungai Besar', 'Limbang', 'Sungai Udang',
'Batu Berendam', 'Jenjarum', 'Kertih', 'Tanjung Tokong', 'Ladang Seri Kundang', 'Pekan Nenas', 'Peringat', 'Batu Arang',
'Tanjung Sepat', 'Mersing', 'Labis', 'Marang', 'Kuang', 'Paka', 'Bagan Serai', 'Alor Gajah', 'Batang Berjuntai', 
'Pelabuhan Klang', 'Batu Ferringhi', 'Gua Musang', 'Kuala Pilah', 'Ranau', 'Papar', 'Kampong Kadok', 'Kuala Kedah', 
'Kampar', 'Pasir Mas', 'Kampung Simpang Renggam', 'Parit Raja', 'Bukit Rambai', 'Sabak Bernam', 'Kepala Batas', 
'Kampung Tanjung Karang', 'Pantai Remis', 'Gurun', 'Beaufort', 'Kapit', 'Kinarut', 'Kampung Ayer Molek', 'Kuala Lipis',
'Pantai Cenang', 'Bemban', 'Kuala Perlis', 'Sungai Pelek New Village', 'Jertih', 'Kelapa Sawit', 'Buloh Kasap', 'Kota Belud',
'Kampung Bukit Tinggi', 'Tumpat', 'Kuala Sungai Baru', 'Juru', 'Pulau Sebang', 'Chaah', 'Ayer Hangat', 'Telaga Batu',
'Padang Mat Sirat', 'Taman Rajawali', 'Tanah Rata']

r = 0
info_dict = {}
date = datetime.today()
print(date)
while r <= len(loclist)-1:
    address = 'https://openweathermap.org/data/2.5/find?callback=?&q='+loclist[r]+',MY&type=like&sort=population&cnt=30&appid=b6907d289e10d714a6e88b30761fae22'
 
    
   

    print(loclist[r])
    data = requests.get(address).text
    print(data)
    data = data.strip("?()")
    data=json.loads(data)
    #info_dict[places[r]] = data
    #print(data["list"],"\n")

    info_1 = {}
    info_2 = {}

    for val in data["list"]:
        info_1 = {"Returned Location"             : val['name'],
                  "Actual Location"               : loclist[r],
                  "Country"                       : val['sys']['country'],
                  "Latitude"                      : val["coord"]["lat"], 
                  "Longitude"                     : val["coord"]["lon"],
                  "Date"                          : datetime.today().strftime('%m/%d/%Y'),
                  "Time"                          : datetime.today().strftime('%H:%M:%S'),
                  "Clouds(%)"                     : val['clouds']['all'],
                  "Temparature(in celcius)"       : round((10*(val['main']["temp"] - 273.15))/10, 2), #ROUNDING TO 2 DECIMAL PLACES
                  "Max_temp"                      : round((10*(val['main']["temp_max"] - 273.15))/10, 2),
                  "Min_temp"                      : round((10*(val['main']["temp_min"] - 273.15))/10, 2), 
                  "Humidity(%)"                   : val['main']["humidity"],
                  "Pressure(hpa)"                 : val['main']["pressure"],
                  "Rain"                          : val["rain"],
                  "Wind_Speed(m/s)"               : val["wind"]['speed']}
                  #"Wind_Direction(in degree)"     : val["wind"]["deg"]}

        #print("this is the iteration", val["main"], "\n")
        #pprint.pprint(info_1)

        for item in  val["weather"]:
            info_1.update( {"Weather_Condition"   : item["main"],
                      "Weather_Description" : item["description"]})

        #pprint.pprint(info_2)
    info_dict[r]= info_1     
    r+=1
    print(r,"\n")
pprint.pprint( info_dict)
# Out:
# 2018-06-29 14:52:01.420301
# Cheras
# ?({"message":"accurate","cod":"200","count":2,"list":[{"id":1733046,"name":"Cheras","coord":{"lat":3.0858,"lon":101.7574},"main":{"temp":299.67,"pressure":1010,"humidity":78,"temp_min":299.15,"temp_max":300.15},"dt":1530252000,"wind":{"speed":4.6,"deg":330},"sys":{"country":"MY"},"rain":null,"snow":null,"clouds":{"all":75},"weather":[{"id":803,"main":"Clouds","description":"broken clouds","icon":"04d"}]},{"id":1733046,"name":"Cheras","coord":{"lat":3.1072,"lon":101.7165},"main":{"temp":299.68,"pressure":1010,"humidity":78,"temp_min":299.15,"temp_max":300.15},"dt":1530252000,"wind":{"speed":4.6,"deg":330},"sys":{"country":"MY"},"rain":null,"snow":null,"clouds":{"all":75},"weather":[{"id":803,"main":"Clouds","description":"broken clouds","icon":"04d"}]}]})
# 1
#
# Sandakan
# ?({"message":"accurate","cod":"200","count":1,"list":[{"id":1734052,"name":"Sandakan","coord":{"lat":5.8402,"lon":118.1179},"main":{"temp":305.15,"pressure":1006,"humidity":66,"temp_min":305.15,"temp_max":305.15},"dt":1530252000,"wind":{"speed":3.6,"deg":20},"sys":{"country":"MY"},"rain":null,"snow":null,"clouds":{"all":75},"weather":[{"id":803,"main":"Clouds","description":"broken clouds","icon":"04d"}]}]})
# 2
#
# Kajang
# ?({"message":"accurate","cod":"200","count":1,"list":[{"id":1734798,"name":"Kajang","coord":{"lat":2.99,"lon":101.7886},"main":{"temp":299.65,"pressure":1009,"humidity":83,"temp_min":299.15,"temp_max":300.15},"dt":1530252000,"wind":{"speed":1.5},"sys":{"country":"MY"},"rain":null,"snow":null,"clouds":{"all":75},"weather":[{"id":803,"main":"Clouds","description":"broken clouds","icon":"04d"}]}]})
# 3
#
# Seremban
# ?({"message":"accurate","cod":"200","count":1,"list":[{"id":1734810,"name":"Seremban","coord":{"lat":2.7248,"lon":101.9345},"main":{"temp":299.8,"pressure":1009,"humidity":83,"temp_min":299.15,"temp_max":300.15},"dt":1530252000,"wind":{"speed":1.5},"sys":{"country":"MY"},"rain":null,"snow":null,"clouds":{"all":75},"weather":[{"id":803,"main":"Clouds","description":"broken clouds","icon":"04d"}]}]})
# 4
#
# Kuantan
# ?({"message":"accurate","cod":"200","count":1,"list":[{"id":1735227,"name":"Kuantan","coord":{"lat":3.8197,"lon":103.3292},"main":{"temp":302.15,"pressure":1009,"humidity":79,"temp_min":302.15,"temp_max":302.15},"dt":1530252000,"wind":{"speed":4.1,"deg":210},"sys":{"country":"MY"},"rain":null,"snow":null,"clouds":{"all":75},"weather":[{"id":803,"main":"Clouds","description":"broken clouds","icon":"04d"}]}]})
# 5
#
# Tawau
# ?({"message":"accurate","cod":"200","count":1,"list":[{"id":1734199,"name":"Tawau","coord":{"lat":4.2635,"lon":117.893},"main":{"temp":304.15,"pressure":1008,"humidity":70,"temp_min":304.15,"temp_max":304.15},"dt":1530252000,"wind":{"speed":3.6,"deg":170},"sys":{"country":"MY"},"rain":null,"snow":null,"clouds":{"all":75},"weather":[{"id":803,"main":"Clouds","description":"broken clouds","icon":"04d"}]}]})
# 6
#
# Kuala Terengganu
# ?({"message":"accurate","cod":"200","count":1,"list":[{"id":1734705,"name":"Kuala Terengganu","coord":{"lat":5.3302,"lon":103.1408},"main":{"temp":306.15,"pressure":1007,"humidity":63,"temp_min":306.15,"temp_max":306.15},"dt":1530252000,"wind":{"speed":4.1,"deg":30},"sys":{"country":"MY"},"rain":null,"snow":null,"clouds":{"all":75},"weather":[{"id":803,"main":"Clouds","description":"broken clouds","icon":"04d"}]}]})
# 7
#
# Miri
# ?({"message":"accurate","cod":"200","count":1,"list":[{"id":1738050,"name":"Miri","coord":{"lat":4.4148,"lon":114.0089},"main":{"temp":304.15,"pressure":1007,"humidity":66,"temp_min":304.15,"temp_max":304.15},"dt":1530252000,"wind":{"speed":4.1,"deg":260},"sys":{"country":"MY"},"rain":null,"snow":null,"clouds":{"all":75},"weather":[{"id":803,"main":"Clouds","description":"broken clouds","icon":"04d"}]}]})
# 8
#
# Kota Bharu
# ?({"message":"accurate","cod":"200","count":1,"list":[{"id":1736376,"name":"Kota Bharu","coord":{"lat":6.1256,"lon":102.2393},"main":{"temp":305.15,"pressure":1007,"humidity":70,"temp_min":305.15,"temp_max":305.15},"dt":1530252000,"wind":{"speed":3.6,"deg":30},"sys":{"country":"MY"},"rain":null,"snow":null,"clouds":{"all":75},"weather":[{"id":521,"main":"Rain","description":"proximity shower rain","icon":"09d"}]}]})
# 9
#
# Selayang Baru
# ?({"message":"accurate","cod":"200","count":0,"list":[]})
# 10
#
# Subang Jaya
# ?({"message":"accurate","cod":"200","count":1,"list":[{"id":1733046,"name":"Subang Jaya","coord":{"lat":3.0568,"lon":101.5855},"main":{"temp":299.69,"pressure":1010,"humidity":78,"temp_min":299.15,"temp_max":300.15},"dt":1530252000,"wind":{"speed":4.6,"deg":330},"sys":{"country":"MY"},"rain":null,"snow":null,"clouds":{"all":75},"weather":[{"id":803,"main":"Clouds","description":"broken clouds","icon":"04d"}]}]})
# 11
#
# Kuala Lumpur
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-168-4c764545e7fe> in <module>()
#      32
#      33     print(loclist[r])
# ---> 34     data = requests.get(address).text
#      35     print(data)
#      36     data = data.strip("?()")
#
# C:\Anaconda3\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      68
#      69     kwargs.setdefault('allow_redirects', True)
# ---> 70     return request('get', url, params=params, **kwargs)
#      71
#      72
#
# C:\Anaconda3\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      54     # cases, and look like a memory leak in others.
#      55     with sessions.Session() as session:
# ---> 56         return session.request(method=method, url=url, **kwargs)
#      57
#      58
#
# C:\Anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     486         }
#     487         send_kwargs.update(settings)
# --> 488         resp = self.send(prep, **send_kwargs)
#     489
#     490         return resp
#
# C:\Anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     607
#     608         # Send the request
# --> 609         r = adapter.send(request, **kwargs)
#     610
#     611         # Total elapsed time of the request (approximately)
#
# C:\Anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     421                     decode_content=False,
#     422                     retries=self.max_retries,
# --> 423                     timeout=timeout
#     424                 )
#     425
#
# C:\Anaconda3\lib\site-packages\requests\packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, **response_kw)
#     592                                                   timeout=timeout_obj,
#     593                                                   body=body, headers=headers,
# --> 594                                                   chunked=chunked)
#     595
#     596             # If we're going to release the connection in ``finally:``, then
#
# C:\Anaconda3\lib\site-packages\requests\packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     348         # Trigger any extra validation we need to do.
#     349         try:
# --> 350             self._validate_conn(conn)
#     351         except (SocketTimeout, BaseSSLError) as e:
#     352             # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#
# C:\Anaconda3\lib\site-packages\requests\packages\urllib3\connectionpool.py in _validate_conn(self, conn)
#     833         # Force connect early to allow us to validate the connection.
#     834         if not getattr(conn, 'sock', None):  # AppEngine might not have  `.sock`
# --> 835             conn.connect()
#     836
#     837         if not conn.is_verified:
#
# C:\Anaconda3\lib\site-packages\requests\packages\urllib3\connection.py in connect(self)
#     321             ca_cert_dir=self.ca_cert_dir,
#     322             server_hostname=hostname,
# --> 323             ssl_context=context)
#     324
#     325         if self.assert_fingerprint:
#
# C:\Anaconda3\lib\site-packages\requests\packages\urllib3\util\ssl_.py in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir)
#     322         context.load_cert_chain(certfile, keyfile)
#     323     if HAS_SNI:  # Platform-specific: OpenSSL with enabled SNI
# --> 324         return context.wrap_socket(sock, server_hostname=server_hostname)
#     325
#     326     warnings.warn(
#
# C:\Anaconda3\lib\site-packages\requests\packages\urllib3\contrib\pyopenssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname)
#     415         while True:
#     416             try:
# --> 417                 cnx.do_handshake()
#     418             except OpenSSL.SSL.WantReadError:
#     419                 rd, _, _ = select.select([sock], [], [], sock.gettimeout())
#
# C:\Anaconda3\lib\site-packages\OpenSSL\SSL.py in do_handshake(self)
#    1423         :return: None.
#    1424         """
# -> 1425         result = _lib.SSL_do_handshake(self._ssl)
#    1426         self._raise_ssl_error(self._ssl, result)
#    1427
#
# KeyboardInterrupt:

# %% [markdown]
# #### This is the real script ( we implemented functions )

# %%
### the function that searches weather by the name of the location    

def nonCoordinates(loclist):
    address = 'https://openweathermap.org/data/2.5/find?callback=?&q='+loclist+',MY&type=like&sort=population&cnt=30&appid=b6907d289e10d714a6e88b30761fae22'
    print(loclist)
    data = requests.get(address).text
    print(data)
    data = data.strip("?()")
    data=json.loads(data)
    
    info_1 = {}
   

    for val in data["list"]:
        info_1 = {"Returned Location"             : val['name'],
                  "Actual Location"               : loclist,
                  "Country"                       : val['sys']['country'],
                  "Latitude"                      : val["coord"]["lat"], 
                  "Longitude"                     : val["coord"]["lon"],
                  "Date"                          : datetime.today().strftime('%m/%d/%Y'),
                  "Time"                          : datetime.today().strftime('%H:%M:%S'),
                  "Clouds(%)"                     : val['clouds']['all'],
                  "Temparature(in celcius)"       : round((10*(val['main']["temp"] - 273.15))/10, 2), #ROUNDING TO 2 DECIMAL PLACES
                  "Max_temp"                      : round((10*(val['main']["temp_max"] - 273.15))/10, 2),
                  "Min_temp"                      : round((10*(val['main']["temp_min"] - 273.15))/10, 2), 
                  "Humidity(%)"                   : val['main']["humidity"],
                  "Pressure(hpa)"                 : val['main']["pressure"],
                  #"Rain"                          : val["rain"]["3h"],
                  "Wind_Speed(m/s)"               : val["wind"]['speed']}
                  #"Wind_Direction(in degree)"     : val["wind"]["deg"]}
        for item in  val["weather"]:
            info_1.update( {"Weather_Condition"   : item["main"],
                      "Weather_Description" : item["description"]})
    return info_1

### the funciton that searches weather by using the co-ordinates of the locations

def coordinates(loclist):  
  
    address = 'http://api.openweathermap.org/data/2.5/weather?lat={0}&lon={1}&units=metric&appid={2}'
    appid = 'c9b9201a18e08ae3bb54d622f55c6c14'

    if loclist == 'Selayang Baru':
        lat =  3.2140
        lon =   101.6356
        address = address.format(lat,lon,appid)

    elif loclist == 'Pantai Cenang':
        lat =  6.2956 
        lon =   99.7228
        address = address.format(lat,lon,appid)

    elif loclist == 'Ayer Hangat':
        lat =  6.4252 
        lon =   99.8069
        address = address.format(lat,lon,appid)

    elif loclist == 'Telaga Batu':
        lat =  5.467
        lon =   100.233
        address = address.format(lat,lon,appid)

    elif  loclist == 'Padang Mat Sirat':
        lat =  6.352057
        lon =   99.733603
        address = address.format(lat,lon,appid)

    elif  loclist == 'Taman Rajawali':
        lat =  5.889618
        lon =   118.041484
        address = address.format(lat,lon,appid)
    else: 
        return {}

    print(loclist)
    data = requests.get(address).text
    print(data)
    data = data.strip("?()")
    data=json.loads(data)
    
    info_1 = {}
    
    
    info_1 = {"Returned Location"             : data['name'],
              "Actual Location"               : loclist,
              "Country"                       : data['sys']['country'],
              "Latitude"                      : data["coord"]["lat"], 
              "Longitude"                     : data["coord"]["lon"],
              "Date"                          : datetime.today().strftime('%m/%d/%Y'),
              "Time"                          : datetime.today().strftime('%H:%M:%S'),
              "Clouds(%)"                     : data['clouds']['all'],
              "Temparature(in celcius)"       : data['main']["temp"], 
              "Max_temp"                      : data['main']["temp_max"],
              "Min_temp"                      : data['main']["temp_min"], 
              "Humidity(%)"                   : data['main']["humidity"],
              "Pressure(hpa)"                 : data['main']["pressure"],
              #"Rain"                          : data["rain"]["3h"],
              "Wind_Speed(m/s)"               : data["wind"]['speed']}
              #"Wind_Direction(in degree)"     : val["wind"]["deg"]}
    for item in  data["weather"]:
        info_1.update( {"Weather_Condition"   : item["main"],
                  "Weather_Description" : item["description"]})
    
    return info_1


def trafficUpdate(originList, destList ):
    traf_dif = []
    traf_label = []
    i = 0
    #while i<=5:
    while i<=len(originList)-1:
        print("\n", i, "\n")
        # Google Distance Matrix base URL to which all other parameters are attached
        base_url = 'https://maps.googleapis.com/maps/api/distancematrix/json?'


        # Prepare the request details for the assembly into a request URL
        payload = {
                    'origins'        :  originList[i],
                    'destinations'   :  destList[i], 
                    'departure_time' :  'now',
                    'key'            :  'AIzaSyDisMSJlHVoeHyK_h7eo8A2sqdaHk33Pcs'
                   }
        # Assemble the URL and query the web service
        req = requests.get(base_url, params = payload).text
        data=json.loads(req)
        #print(data)
        
        #iterating through the api data
        for item in data['rows']:
            for elm in item['elements']:
                #print(elm['duration']['value'])
                duration_val       =  elm['duration']['value']
                duration_val_traf  =  elm['duration_in_traffic']['value']
                difference         =  duration_val_traf - duration_val
                traf_dif.append(difference)
                #print(traf_dif)
                
        #labeling the traffic
        if traf_dif[i] <= -1:
            traf_label.append("GREEN")
            print(traf_label)

        elif traf_dif[i] >= 0 and traf_dif[i] <= 7:
            traf_label.append("YELLOW")
            print(traf_label) 
            
        elif traf_dif[i] >= 8:
            traf_label.append("RED")
            print(traf_label)    
        
        #incrementing i
        i += 1
    #traffic = [traf_dif, traf_label]
    #print(traf_label)
    return  traf_label

# %%
# this is the list of locations we have, and we have hardcoded them manually
loclist =  ['Cheras', 'Sandakan', 'Kajang', 'Seremban', 'Kuantan', 'Tawau', 'Kuala Terengganu', 'Miri', 'Kota Bharu', 
'Selayang Baru', 'Subang Jaya', 'Kuala Lumpur', 'Klang', 'Johor Bahru', 'Ampang', 'Ipoh', 'Shah Alam', 'Kuching', 
'Petaling Jaya', 'Kota Kinabalu', 'George Town', 'Iskandar Puteri', 'Melaka ', 'Alor Setar', 'Bintulu', 'Kampung Baru Subang',
'Kota Bharu', 'Sungai Petani', 'Taiping', 'Bukit Mertajam', 'Sepang', 'Sibu', 'Kulim', 'Kluang', 'Skudai', 'Batu Pahat', 
'Kampung Pasir Gudang Baru', 'Kampung Sungai Ara', 'Tasek Glugor', 'Muar', 'Rawang', 'Butterworth', 'Lahad Datu', 'Semenyih',
'Port Dickson', 'Cukai', 'Putatan', 'Keningau', 'Ulu Tiram', 'Victoria', 'Taman Senai', 'Donggongon', 'Segamat', 
'Kampong Baharu Balakong', 'Perai', 'Kangar', 'Kulai', 'Jitra', 'Teluk Intan', 'Semporna', 'Putra Heights', 'Temerluh',
'Kampong Dungun', 'Simpang Empat', 'Kuala Selangor', 'Kampung Bukit Baharu', 'Bandar Labuan', 'Kota Tinggi', 'Pontian Kechil',
'Putrajaya', 'Bentong Town', 'Banting', 'Bedong', 'Batu Gajah', 'Mentekab', 'Nibong Tebal', 'Raub', 'Kampong Pangkal Kalong',
'Lumut', 'Kuala Kangsar', 'Klebang Besar', 'Kampung Ayer Keroh', 'Kampung Baharu Nilai', 'Tangkak', 'Jerantut', 'Kudat', 
'Pekan', 'Bahau', 'Bakri', 'Kuah', 'Bidur', 'Sarikei', 'Kampong Masjid Tanah', 'Tanah Merah', 'Serendah', 'Tampin', 
'Tapah Road', 'Parit Buntar', 'Simanggang', 'Permatang Kuching', 'Yong Peng', 'Sungai Besar', 'Limbang', 'Sungai Udang',
'Batu Berendam', 'Jenjarum', 'Kertih', 'Tanjung Tokong', 'Ladang Seri Kundang', 'Pekan Nenas', 'Peringat', 'Batu Arang',
'Tanjung Sepat', 'Mersing', 'Labis', 'Marang', 'Kuang', 'Paka', 'Bagan Serai', 'Alor Gajah', 'Batang Berjuntai', 
'Pelabuhan Klang', 'Batu Ferringhi', 'Gua Musang', 'Kuala Pilah', 'Ranau', 'Papar', 'Kampong Kadok', 'Kuala Kedah', 
'Kampar', 'Pasir Mas', 'Kampung Simpang Renggam', 'Parit Raja', 'Bukit Rambai', 'Sabak Bernam', 'Kepala Batas', 
'Kampung Tanjung Karang', 'Pantai Remis', 'Gurun', 'Beaufort', 'Kapit', 'Kinarut', 'Kampung Ayer Molek', 'Kuala Lipis',
'Pantai Cenang', 'Bemban', 'Kuala Perlis', 'Sungai Pelek New Village', 'Jertih', 'Kelapa Sawit', 'Buloh Kasap', 'Kota Belud',
'Kampung Bukit Tinggi', 'Tumpat', 'Kuala Sungai Baru', 'Juru', 'Pulau Sebang', 'Chaah', 'Ayer Hangat', 'Telaga Batu',
'Padang Mat Sirat', 'Taman Rajawali', 'Tanah Rata']


originList = ['3.105768, 101.715448', '5.839319, 118.116308', '2.991559, 101.787757', '2.724119, 101.932328', 
              '3.820882, 103.329190', '4.262185, 117.892673', '5.329034, 103.141363', '4.413783, 114.008027', 
              '6.125200, 102.240797', '3.208642, 101.640314', '3.056805, 101.583711', '3.154792, 101.710993', 
              '3.045467, 101.448585', '1.493519, 103.756294', '3.150286, 101.734089', '4.590321, 101.083404', 
              '3.069259, 101.517040', '1.558780, 110.345125', '3.105978, 101.644349', '5.979613, 116.073387', 
              '5.415615, 100.329268', '1.427055, 103.638804', '2.197080, 102.240415', '6.124170, 100.368033', 
              '3.166936, 113.030943', '3.149877, 101.535095', '6.125664, 102.238602', '5.644827, 100.491015', 
              '4.846619, 100.735841', '5.364246, 100.457759', '2.693213, 101.750353', '2.291600, 111.826412', 
              '5.370844, 100.553354', '2.035854, 103.321936', '1.545747, 103.660014', '1.849186, 102.937706', 
              '1.473463, 103.878967', '5.327720, 100.274414', '5.480420, 100.496637', '2.041929, 102.567964', 
              '3.321799, 101.576658', '5.394542, 100.373809', '5.020933, 118.326201', '2.950101, 101.842300', 
              '2.521226, 101.795273', '4.248530, 103.415624', '5.884386, 116.051037', '5.330091, 116.154413', 
              '1.604713, 103.821915', '5.277049, 115.242968', '1.600956, 103.640193', '5.908712, 116.101375', 
              '2.506640, 102.816490', '3.031533, 101.750393', '5.378693, 100.384053', '6.439258, 100.193265', 
              '1.655428, 103.606523', '6.267962, 100.418278', '4.022212, 101.026240', '4.479857, 118.611296', 
              '2.994738, 101.567746', '3.449655, 102.417469', '3.217083, 101.318535', '2.434517, 102.184780', 
              '3.339628, 101.249979', '2.216515, 102.284461', '5.290254, 115.267293', '1.731315, 103.901311', 
              '1.487496, 103.390578', '2.905137, 101.677160', '3.517828, 101.900402', '2.815510, 101.498527', 
              '5.726142, 100.510261', '4.472287, 101.037404', '3.484737, 102.350037', '5.171337, 100.477869', 
              '3.789439, 101.853587', '5.916335, 102.214399', '4.233735, 100.630448', '4.772207, 100.941900', 
              '2.218638, 102.198091', '2.266487, 102.281450', '2.801681, 101.796630', '2.268538, 102.540899', 
              '3.936554, 102.366655', '6.889470, 116.844672', '3.490114, 103.392606', '2.809882, 102.396563', 
              '2.051782, 102.666923', '6.325826, 99.844969', '4.115975, 101.282106', '2.130260, 111.524742', 
              '2.349884, 102.114899', '5.722118, 100.392378', '3.366510, 101.607005', '2.468052, 102.237294', 
              '4.172406, 101.197345', '5.130701, 100.488694', '1.246521, 111.454469', '5.462308, 100.382634', 
              '2.010742, 103.068337', '3.675912, 100.985425', '4.744346, 115.001928', '2.314298, 102.129679', 
              '2.245939, 102.248217', '2.883486, 101.503113', '4.512914, 103.446911', '5.447879, 100.305399', 
              '3.285342, 101.517530', '1.509135, 103.515767', '5.987414, 102.297651', '3.312107, 101.489875', 
              '2.659804, 101.564215', '2.426912, 103.834955', '2.385201, 103.021745', '5.206948, 103.205309', 
              '3.255824, 101.554280', '4.636765, 103.436538', '5.013243, 100.527234', '2.384545, 102.208206', 
              '3.382195, 101.419005', '3.003397, 101.395786', '5.470518, 100.249889', '4.880789, 101.964089', 
              '2.741951, 102.248646', '5.951456, 116.667792', '5.733695, 115.932742', '6.001634, 102.250963', 
              '6.106487, 100.294694', '4.308041, 101.149435', '6.049664, 102.141408', '1.827739, 103.298295', 
              '1.869368, 103.111003', '2.260183, 102.184348', '3.765769, 100.988252', '5.513266, 100.427297', 
              '3.425487, 101.186208', '4.456181, 100.626612', '5.816438, 100.474814', '5.353378, 115.745855', 
              '2.016907, 112.941330', '5.823094, 116.048297', '2.215134, 102.327890', '4.185383, 102.054926', 
              '6.299373, 99.721247', '2.269397, 102.376291', '6.402020, 100.136695', '2.650076, 101.702299', 
              '5.738042, 102.496706', '1.680095, 103.523240', '2.553305, 102.765363', '6.350239, 116.430836', 
              '3.349938, 101.818581', '6.197883, 102.166558', '2.358425, 102.036015', '5.315906, 100.439280', 
              '2.446942, 102.230118', '2.246170, 103.042407', '6.428995, 99.808533', '5.463150, 100.230763', 
              '6.349125, 99.731225', '5.889285, 118.041997', '4.471204, 101.379313']

destList = ['3.107233, 101.716458', '5.840197, 118.117920', '2.990069, 101.788762', '2.723786, 101.933958', 
            '3.819618, 103.329201', '4.263603, 117.892869', '5.330140, 103.140778', '4.414901, 114.009036', 
            '6.125749, 102.239295', '3.210444, 101.640261', '3.056805, 101.585511', '3.153324, 101.711964', 
            '3.047248, 101.448889', '1.495052, 103.755302', '3.151470, 101.733344', '4.591851, 101.083270', 
            '3.068606, 101.518284', '1.557182, 110.344245', '3.105812, 101.642622', '5.977959, 116.072507', 
            '5.416681, 100.330443', '1.426551, 103.640294', '2.195847, 102.240624', '6.122890, 100.368210', 
            '3.165693, 113.032241', '3.149915, 101.533260', '6.125754, 102.239283', '5.643556, 100.491401', 
            '4.847768, 100.737241', '5.363856, 100.455984', '2.692302, 101.750482', '2.290739, 111.826211', 
            '5.370810, 100.554666', '2.035350, 103.320477', '1.546578, 103.658887', '1.849845, 102.936100', 
            '1.472289, 103.878002', '5.326978, 100.273491', '5.479609, 100.498230', '2.042979, 102.566682', 
            '3.320358, 101.576594', '5.395304, 100.374842', '5.021606, 118.327585', '2.948370, 101.842916', 
            '2.522727, 101.794313', '4.250039, 103.416719', '5.883223, 116.050136', '5.328724, 116.155346', 
            '1.604337, 103.823814', '5.276699, 115.241726', '1.600549, 103.641700', '5.906962, 116.101450', 
            '2.506608, 102.815329', '3.033317, 101.750087', '5.377159, 100.383199', '6.438911, 100.194493', 
            '1.656816, 103.605962', '6.268484, 100.416835', '4.023588, 101.026412', '4.480221, 118.611795', 
            '2.995729, 101.566936', '3.450678, 102.417329', '3.217171, 101.316714', '2.436276, 102.184474', 
            '3.340646, 101.249437', '2.215250, 102.284654', '5.289057, 115.268602', '1.733122, 103.901405', 
            '1.486585, 103.389591', '2.906504, 101.676311', '3.516580, 101.900199', '2.816946, 101.499740', 
            '5.727557, 100.509467', '4.470656, 101.036626', '3.485599, 102.348476', '5.169676, 100.477756', 
            '3.791184, 101.853136', '5.915977, 102.216164', '4.232365, 100.630083', '4.772287, 100.940623', 
            '2.218600, 102.199507', '2.265568, 102.279923', '2.803095, 101.797058', '2.267097, 102.540108', 
            '3.936405, 102.366430', '6.889771, 116.842980', '3.490124, 103.393668', '2.808714, 102.395866', 
            '2.050002, 102.666681', '6.326540, 99.843188', '4.116704, 101.283299', '2.129727, 111.523015', 
            '2.349782, 102.116615', '5.720925, 100.392355', '3.365829, 101.606017', '2.467446, 102.235623', 
            '4.170972, 101.198364', '5.131610, 100.487127', '1.247449, 111.452929', '5.463322, 100.381631', 
            '2.010925, 103.066578', '3.677267, 100.986555', '4.745662, 115.002094', '2.312526, 102.129398', 
            '2.247251, 102.246996', '2.884922, 101.501998', '4.514281, 103.448053', '5.446088, 100.305227', 
            '3.285187, 101.518801', '1.509628, 103.513954', '5.987910, 102.295891', '3.310410, 101.490400', 
            '2.659868, 101.562913', '2.428001, 103.835771', '2.383665, 103.020858', '5.205645, 103.205920', 
            '3.255031, 101.553143', '4.637460, 103.436967', '5.011789, 100.527438', '2.382980, 102.209118', 
            '3.382511, 101.417804', '3.002473, 101.396872', '5.469012, 100.250849', '4.879442, 101.965285', 
            '2.742085, 102.249902', '5.951147, 116.666719', '5.733561, 115.931669', '6.000013, 102.250164', 
            '6.107226, 100.293738', '4.307517, 101.150768', '6.049575, 102.139858', '1.827911, 103.299674', 
            '1.867941, 103.112151', '2.259604, 102.183544', '3.767268, 100.987114', '5.514841, 100.427839', 
            '3.424004, 101.185194', '4.455123, 100.625861', '5.817722, 100.475383', '5.353116, 115.747276', 
            '2.016501, 112.939911', '5.823315, 116.046589', '2.213799, 102.327713', '4.186968, 102.054190', 
            '6.299980, 99.719984', '2.267918, 102.377053', '6.400730, 100.136239', '2.648924, 101.700947', 
            '5.737711, 102.495043', '1.679451, 103.524935', '2.553632, 102.763942', '6.349722, 116.429299', 
            '3.350166, 101.816752', '6.198534, 102.167566', '2.359154, 102.034684', '5.315817, 100.437417', 
            '2.445639, 102.230638', '2.245753, 103.041140', '6.430658, 99.809155', '5.464554, 100.229605', 
            '6.350010, 99.729996', '5.890725, 118.040887', '4.470504, 101.377731']

trafficUpdate(originList, destList)
#print(trafficUpdate(originList, destList)    )
# Out:
#  0
#
# ['GREEN']
#
#  1
#
# ['GREEN', 'GREEN']
#
#  2
#
# ['GREEN', 'GREEN', 'GREEN']
#
#  3
#
# ['GREEN', 'GREEN', 'GREEN', 'YELLOW']
#
#  4
#
# ['GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW']
#
#  5
#
# ['GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW']
#
#  6
#
# ['GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN']
#
#  7
#
# ['GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW']
#
#  8
#
# ['GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN']
#
#  9
#
# ['GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN']
#
#  10
#
# ['GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN']
#
#  11
#
# ['GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'RED']
#
#  12
#
# ['GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'RED', 'GREEN']
#
#  13
#
# ['GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'RED', 'GREEN', 'YELLOW']
#
#  14
#
# ['GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'RED', 'GREEN', 'YELLOW', 'YELLOW']
#
#  15
#
# ['GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'RED', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN']
#
#  16
#
# ['GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'RED', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'GREEN']
#
#  17
#
# ['GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'RED', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'GREEN', 'GREEN']
#
#  18
#
# ['GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'RED', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW']
#
#  19
#
# ['GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'RED', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW']
#
#  20
#
# ['GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'RED', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN']
#
#  21
#
# ['GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'RED', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW']
#
#  22
#
# ['GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'RED', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN']
#
#  23
#
# ['GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'RED', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN']
#
#  24
#
# ['GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'RED', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN']
#
#  25
#
# ['GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'RED', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW']
#
#  26
#
# ['GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'RED', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW']
#
#  27
#
# ['GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'RED', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'RED']
#
#  28
#
# ['GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'RED', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'RED', 'GREEN']
#
#  29
#
# ['GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'RED', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'RED', 'GREEN', 'GREEN']
#
#  30
#
# ['GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'RED', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'RED', 'GREEN', 'GREEN', 'YELLOW']
#
#  31
#
# ['GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'RED', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'RED', 'GREEN', 'GREEN', 'YELLOW', 'GREEN']
#
#  32
#
# ['GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'RED', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'RED', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'GREEN']
#
#  33
#
# ['GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'RED', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'RED', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'RED']
#
#  34
#
# ['GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'RED', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'RED', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'RED', 'GREEN']
#
#  35
#
# ['GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'RED', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'RED', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'RED', 'GREEN', 'GREEN']
#
#  36
#
# ['GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'RED', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'RED', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'RED', 'GREEN', 'GREEN', 'YELLOW']
#
#  37
#
# ['GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'RED', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'RED', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'RED', 'GREEN', 'GREEN', 'YELLOW', 'GREEN']
#
#  38
#
# ['GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'RED', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'RED', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'RED', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW']
#
#  39
#
# ['GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'RED', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'RED', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'RED', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN']
#
#  40
#
# ['GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'RED', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'RED', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'RED', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN']
#
#  41
#
# ['GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'RED', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'RED', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'RED', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN']
#
#  42
#
# ['GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'RED', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'RED', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'RED', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW']
#
#  43
#
# ['GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'RED', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'RED', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'RED', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN']
#
#  44
#
# ['GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'RED', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'RED', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'RED', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW']
#
#  45
#
# ['GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'RED', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'RED', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'RED', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN']
#
#  46
#
# ['GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'RED', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'RED', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'RED', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW']
#
#  47
#
# ['GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'RED', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'RED', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'RED', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'YELLOW']
#
#  48
#
# ['GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'RED', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'RED', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'RED', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW']
#
#  49
#
# ['GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'RED', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'RED', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'RED', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'YELLOW']
#
#  50
#
# ['GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'RED', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'RED', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'RED', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN']
#
#  51
#
# ['GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'RED', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'RED', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'RED', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN', 'GREEN']
#
#  52
#
# ['GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'RED', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'RED', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'RED', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN', 'GREEN', 'GREEN']
#
#  53
#
# ['GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'RED', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'RED', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'RED', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW']
#
#  54
#
# ['GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'RED', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'RED', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'RED', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN']
#
#  55
#
# ['GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'RED', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'RED', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'RED', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'GREEN']
#
#  56
#
# ['GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'RED', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'RED', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'RED', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'YELLOW']
#
#  57
#
# ['GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'RED', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'RED', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'RED', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'YELLOW', 'GREEN']
#
#  58
#
# ['GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'RED', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'RED', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'RED', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW']
#
#  59
#
# ['GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'RED', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'RED', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'RED', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN']
#
#  60
#
# ['GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'RED', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'RED', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'RED', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN']
#
#  61
#
# ['GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'RED', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'RED', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'RED', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN']
#
#  62
#
# ['GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'RED', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'RED', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'RED', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'GREEN']
#
#  63
#
# ['GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'RED', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'RED', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'RED', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'GREEN']
#
#  64
#
# ['GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'RED', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'RED', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'RED', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'YELLOW']
#
#  65
#
# ['GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'RED', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'RED', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'RED', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW']
#
#  66
#
# ['GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'RED', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'RED', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'RED', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN']
#
#  67
#
# ['GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'RED', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'RED', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'RED', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'RED']
#
#  68
#
# ['GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'RED', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'RED', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'RED', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'RED', 'GREEN']
#
#  69
#
# ['GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'RED', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'RED', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'RED', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'RED', 'GREEN', 'GREEN']
#
#  70
#
# ['GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'RED', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'RED', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'RED', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'RED', 'GREEN', 'GREEN', 'GREEN']
#
#  71
#
# ['GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'RED', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'RED', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'RED', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'RED', 'GREEN', 'GREEN', 'GREEN', 'GREEN']
#
#  72
#
# ['GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'RED', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'RED', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'RED', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'RED', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'YELLOW']
#
#  73
#
# ['GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'RED', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'RED', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'RED', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'RED', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN']
#
#  74
#
# ['GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'RED', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'RED', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'RED', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'RED', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW']
#
#  75
#
# ['GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'RED', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'RED', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'RED', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'RED', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN']
#
#  76
#
# ['GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'RED', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'RED', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'RED', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'RED', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN']
#
#  77
#
# ['GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'RED', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'RED', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'RED', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'RED', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN']
#
#  78
#
# ['GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'RED', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'RED', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'RED', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'RED', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW']
#
#  79
#
# ['GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'RED', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'RED', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'RED', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'RED', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN']
#
#  80
#
# ['GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'RED', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'RED', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'RED', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'RED', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW']
#
#  81
#
# ['GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'RED', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'RED', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'RED', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'RED', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN']
#
#  82
#
# ['GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'RED', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'RED', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'RED', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'RED', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN']
#
#  83
#
# ['GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'RED', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'RED', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'RED', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'RED', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'YELLOW']
#
#  84
#
# ['GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'RED', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'RED', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'RED', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'RED', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'YELLOW', 'GREEN']
#
#  85
#
# ['GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'RED', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'RED', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'RED', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'RED', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'GREEN']
#
#  86
#
# ['GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'RED', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'RED', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'RED', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'RED', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN']
#
#  87
#
# ['GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'RED', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'RED', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'RED', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'RED', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'GREEN']
#
#  88
#
# ['GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'RED', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'RED', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'RED', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'RED', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'GREEN']
#
#  89
#
# ['GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'RED', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'RED', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'RED', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'RED', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'YELLOW']
#
#  90
#
# ['GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'RED', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'RED', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'RED', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'RED', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN']
#
#  91
#
# ['GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'RED', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'RED', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'RED', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'RED', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'GREEN']
#
#  92
#
# ['GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'RED', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'RED', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'RED', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'RED', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN']
#
#  93
#
# ['GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'RED', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'RED', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'RED', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'RED', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'GREEN']
#
#  94
#
# ['GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'RED', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'RED', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'RED', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'RED', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'YELLOW']
#
#  95
#
# ['GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'RED', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'RED', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'RED', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'RED', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN']
#
#  96
#
# ['GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'RED', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'RED', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'RED', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'RED', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'GREEN']
#
#  97
#
# ['GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'RED', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'RED', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'RED', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'RED', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'YELLOW']
#
#  98
#
# ['GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'RED', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'RED', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'RED', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'RED', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'YELLOW', 'GREEN']
#
#  99
#
# ['GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'RED', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'RED', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'RED', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'RED', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW']
#
#  100
#
# ...
#
#  154
#
# ['GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'RED', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'RED', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'RED', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'RED', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'YELLOW', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW']
#
#  155
#
# ['GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'RED', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'RED', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'RED', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'RED', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'YELLOW', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN']
#
#  156
#
# ['GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'RED', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'RED', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'RED', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'RED', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'YELLOW', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW']
#
#  157
#
# ['GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'RED', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'RED', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'RED', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'RED', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'YELLOW', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'YELLOW']
#
#  158
#
# ['GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'RED', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'RED', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'RED', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'RED', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'YELLOW', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW']
#
#  159
#
# ['GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'RED', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'RED', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'RED', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'RED', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'YELLOW', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN']
#
#  160
#
# ['GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'RED', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'RED', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'RED', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'RED', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'YELLOW', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW']
#
#  161
#
# ['GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'RED', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'RED', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'RED', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'RED', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'YELLOW', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN']
#
#  162
#
# ['GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'RED', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'RED', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'RED', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'RED', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'YELLOW', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN']
# ['GREEN',
#  'GREEN',
#  'GREEN',
#  'YELLOW',
#  'YELLOW',
#  'YELLOW',
#  'GREEN',
#  'YELLOW',
#  'GREEN',
#  'GREEN',
#  'GREEN',
#  'RED',
#  'GREEN',
#  'YELLOW',
#  'YELLOW',
#  'GREEN',
#  'GREEN',
#  'GREEN',
#  'YELLOW',
#  'YELLOW',
#  'GREEN',
#  'YELLOW',
#  'GREEN',
#  'GREEN',
#  'GREEN',
#  'YELLOW',
#  'YELLOW',
#  'RED',
#  'GREEN',
#  'GREEN',
#  'YELLOW',
#  'GREEN',
#  'GREEN',
#  'RED',
#  'GREEN',
#  'GREEN',
#  'YELLOW',
#  'GREEN',
#  'YELLOW',
#  'GREEN',
#  'GREEN',
#  'GREEN',
#  'YELLOW',
#  'GREEN',
#  'YELLOW',
#  'GREEN',
#  'YELLOW',
#  'YELLOW',
#  'YELLOW',
#  'YELLOW',
#  'GREEN',
#  'GREEN',
#  'GREEN',
#  'YELLOW',
#  'GREEN',
#  'GREEN',
#  'YELLOW',
#  'GREEN',
#  'YELLOW',
#  'GREEN',
#  'GREEN',
#  'GREEN',
#  'GREEN',
#  'GREEN',
#  'YELLOW',
#  'YELLOW',
#  'GREEN',
#  'RED',
#  'GREEN',
#  'GREEN',
#  'GREEN',
#  'GREEN',
#  'YELLOW',
#  'GREEN',
#  'YELLOW',
#  'GREEN',
#  'GREEN',
#  'GREEN',
#  'YELLOW',
#  'GREEN',
#  'YELLOW',
#  'GREEN',
#  'GREEN',
#  'YELLOW',
#  'GREEN',
#  'GREEN',
#  'GREEN',
#  'GREEN',
#  'GREEN',
#  'YELLOW',
#  'GREEN',
#  'GREEN',
#  'GREEN',
#  'GREEN',
#  'YELLOW',
#  'GREEN',
#  'GREEN',
#  'YELLOW',
#  'GREEN',
#  'YELLOW',
#  'YELLOW',
#  'GREEN',
#  'GREEN',
#  'YELLOW',
#  'YELLOW',
#  'GREEN',
#  'YELLOW',
#  'YELLOW',
#  'YELLOW',
#  'YELLOW',
#  'GREEN',
#  'YELLOW',
#  'GREEN',
#  'YELLOW',
#  'YELLOW',
#  'GREEN',
#  'GREEN',
#  'GREEN',
#  'GREEN',
#  'YELLOW',
#  'YELLOW',
#  'GREEN',
#  'GREEN',
#  'GREEN',
#  'GREEN',
#  'YELLOW',
#  'YELLOW',
#  'YELLOW',
#  'GREEN',
#  'YELLOW',
#  'GREEN',
#  'YELLOW',
#  'YELLOW',
#  'GREEN',
#  'GREEN',
#  'GREEN',
#  'GREEN',
#  'GREEN',
#  'YELLOW',
#  'YELLOW',
#  'YELLOW',
#  'YELLOW',
#  'YELLOW',
#  'YELLOW',
#  'YELLOW',
#  'GREEN',
#  'GREEN',
#  'YELLOW',
#  'GREEN',
#  'GREEN',
#  'GREEN',
#  'GREEN',
#  'YELLOW',
#  'YELLOW',
#  'YELLOW',
#  'GREEN',
#  'YELLOW',
#  'YELLOW',
#  'YELLOW',
#  'GREEN',
#  'YELLOW',
#  'GREEN',
#  'GREEN']

# %%
r = 0
info_dict = {}
date = datetime.today()
print(date)
while r <= len(loclist)-1 :  #put in len(loclist)-1 for ittarating all the locations
    info_dict[r]= nonCoordinates(loclist[r])
    if info_dict[r] == {}:
        print("\nI am empty: ", loclist[r] )
        info_dict[r] = coordinates(loclist[r])
    
    r+=1
    print(r,"\n")

traffic_label = trafficUpdate(originList, destList)    
pprint.pprint( info_dict) 
print(traffic_label)
# Out:
# 2018-07-05 17:22:22.005903
# Cheras
# ?({"message":"accurate","cod":"200","count":2,"list":[{"id":1733046,"name":"Cheras","coord":{"lat":3.0858,"lon":101.7574},"main":{"temp":305.15,"pressure":1007,"humidity":59,"temp_min":305.15,"temp_max":305.15},"dt":1530781200,"wind":{"speed":5.1,"deg":180},"sys":{"country":"MY"},"rain":null,"snow":null,"clouds":{"all":75},"weather":[{"id":803,"main":"Clouds","description":"broken clouds","icon":"04d"}]},{"id":1733046,"name":"Cheras","coord":{"lat":3.1072,"lon":101.7165},"main":{"temp":305.15,"pressure":1007,"humidity":59,"temp_min":305.15,"temp_max":305.15},"dt":1530781200,"wind":{"speed":5.1,"deg":180},"sys":{"country":"MY"},"rain":null,"snow":null,"clouds":{"all":75},"weather":[{"id":803,"main":"Clouds","description":"broken clouds","icon":"04d"}]}]})
# 1
#
# Sandakan
# ?({"message":"accurate","cod":"200","count":1,"list":[{"id":1734052,"name":"Sandakan","coord":{"lat":5.8402,"lon":118.1179},"main":{"temp":303.15,"pressure":1006,"humidity":70,"temp_min":303.15,"temp_max":303.15},"dt":1530781200,"wind":{"speed":2.1,"deg":100},"sys":{"country":"MY"},"rain":null,"snow":null,"clouds":{"all":75},"weather":[{"id":803,"main":"Clouds","description":"broken clouds","icon":"04d"}]}]})
# 2
#
# Kajang
# ?({"message":"accurate","cod":"200","count":1,"list":[{"id":1734798,"name":"Kajang","coord":{"lat":2.99,"lon":101.7886},"main":{"temp":305.15,"pressure":1007,"humidity":59,"temp_min":305.15,"temp_max":305.15},"dt":1530781200,"wind":{"speed":3.6,"deg":140},"sys":{"country":"MY"},"rain":null,"snow":null,"clouds":{"all":75},"weather":[{"id":803,"main":"Clouds","description":"broken clouds","icon":"04d"}]}]})
# 3
#
# Seremban
# ?({"message":"accurate","cod":"200","count":1,"list":[{"id":1734810,"name":"Seremban","coord":{"lat":2.7248,"lon":101.9345},"main":{"temp":304.33,"pressure":1007,"humidity":59,"temp_min":303.15,"temp_max":305.15},"dt":1530781200,"wind":{"speed":3.6,"deg":140},"sys":{"country":"MY"},"rain":null,"snow":null,"clouds":{"all":75},"weather":[{"id":803,"main":"Clouds","description":"broken clouds","icon":"04d"}]}]})
# 4
#
# Kuantan
# ?({"message":"accurate","cod":"200","count":1,"list":[{"id":1735227,"name":"Kuantan","coord":{"lat":3.8197,"lon":103.3292},"main":{"temp":305.15,"pressure":1007,"humidity":66,"temp_min":305.15,"temp_max":305.15},"dt":1530777600,"wind":{"speed":2.6,"deg":170},"sys":{"country":"MY"},"rain":null,"snow":null,"clouds":{"all":75},"weather":[{"id":803,"main":"Clouds","description":"broken clouds","icon":"04d"}]}]})
# 5
#
# Tawau
# ?({"message":"accurate","cod":"200","count":1,"list":[{"id":1734199,"name":"Tawau","coord":{"lat":4.2635,"lon":117.893},"main":{"temp":301.15,"pressure":1007,"humidity":78,"temp_min":301.15,"temp_max":301.15},"dt":1530781200,"wind":{"speed":2.6},"sys":{"country":"MY"},"rain":null,"snow":null,"clouds":{"all":75},"weather":[{"id":521,"main":"Rain","description":"proximity shower rain","icon":"09d"}]}]})
# 6
#
# Kuala Terengganu
# ?({"message":"accurate","cod":"200","count":1,"list":[{"id":1734705,"name":"Kuala Terengganu","coord":{"lat":5.3302,"lon":103.1408},"main":{"temp":306.15,"pressure":1006,"humidity":66,"temp_min":306.15,"temp_max":306.15},"dt":1530777600,"wind":{"speed":2.1},"sys":{"country":"MY"},"rain":null,"snow":null,"clouds":{"all":75},"weather":[{"id":803,"main":"Clouds","description":"broken clouds","icon":"04d"}]}]})
# 7
#
# Miri
# ?({"message":"accurate","cod":"200","count":1,"list":[{"id":1738050,"name":"Miri","coord":{"lat":4.4148,"lon":114.0089},"main":{"temp":304.15,"pressure":1006,"humidity":58,"temp_min":304.15,"temp_max":304.15},"dt":1530781200,"wind":{"speed":2.1,"deg":270},"sys":{"country":"MY"},"rain":null,"snow":null,"clouds":{"all":75},"weather":[{"id":803,"main":"Clouds","description":"broken clouds","icon":"04d"}]}]})
# 8
#
# Kota Bharu
# ?({"message":"accurate","cod":"200","count":1,"list":[{"id":1736376,"name":"Kota Bharu","coord":{"lat":6.1256,"lon":102.2393},"main":{"temp":304.51,"pressure":1006,"humidity":70,"temp_min":304.15,"temp_max":305.15},"dt":1530777600,"wind":{"speed":3.6,"deg":80},"sys":{"country":"MY"},"rain":null,"snow":null,"clouds":{"all":75},"weather":[{"id":521,"main":"Rain","description":"proximity shower rain","icon":"09d"}]}]})
# 9
#
# Selayang Baru
# ?({"message":"accurate","cod":"200","count":0,"list":[]})
#
# I am empty:  Selayang Baru
# Selayang Baru
# {"coord":{"lon":101.64,"lat":3.21},"weather":[{"id":803,"main":"Clouds","description":"broken clouds","icon":"04d"}],"base":"stations","main":{"temp":32,"pressure":1007,"humidity":59,"temp_min":32,"temp_max":32},"visibility":10000,"wind":{"speed":5.1,"deg":180},"clouds":{"all":75},"dt":1530781200,"sys":{"type":1,"id":8138,"message":0.0066,"country":"MY","sunrise":1530745740,"sunset":1530790026},"id":1760605,"name":"Kepong","cod":200}
# 10
#
# Subang Jaya
# ?({"message":"accurate","cod":"200","count":1,"list":[{"id":1733046,"name":"Subang Jaya","coord":{"lat":3.0568,"lon":101.5855},"main":{"temp":305.15,"pressure":1007,"humidity":59,"temp_min":305.15,"temp_max":305.15},"dt":1530781200,"wind":{"speed":5.1,"deg":180},"sys":{"country":"MY"},"rain":null,"snow":null,"clouds":{"all":75},"weather":[{"id":803,"main":"Clouds","description":"broken clouds","icon":"04d"}]}]})
# 11
#
# Kuala Lumpur
# ?({"message":"accurate","cod":"200","count":1,"list":[{"id":1733046,"name":"Kuala Lumpur","coord":{"lat":3.1547,"lon":101.7136},"main":{"temp":305.15,"pressure":1007,"humidity":59,"temp_min":305.15,"temp_max":305.15},"dt":1530781200,"wind":{"speed":5.1,"deg":180},"sys":{"country":"MY"},"rain":null,"snow":null,"clouds":{"all":75},"weather":[{"id":803,"main":"Clouds","description":"broken clouds","icon":"04d"}]}]})
# 12
#
# Klang
# ?({"message":"accurate","cod":"200","count":1,"list":[{"id":1732905,"name":"Klang","coord":{"lat":3.0472,"lon":101.4492},"main":{"temp":305.15,"pressure":1007,"humidity":59,"temp_min":305.15,"temp_max":305.15},"dt":1530781200,"wind":{"speed":5.1,"deg":180},"sys":{"country":"MY"},"rain":null,"snow":null,"clouds":{"all":75},"weather":[{"id":803,"main":"Clouds","description":"broken clouds","icon":"04d"}]}]})
# 13
#
# Johor Bahru
# ?({"message":"accurate","cod":"200","count":1,"list":[{"id":1732752,"name":"Johor Bahru","coord":{"lat":1.4953,"lon":103.7551},"main":{"temp":304.4,"pressure":1008,"humidity":52,"temp_min":304.15,"temp_max":305.15},"dt":1530781200,"wind":{"speed":4.6,"deg":180},"sys":{"country":"MY"},"rain":null,"snow":null,"clouds":{"all":75},"weather":[{"id":803,"main":"Clouds","description":"broken clouds","icon":"04d"}]}]})
# 14
#
# Ampang
# ?({"message":"accurate","cod":"200","count":2,"list":[{"id":1733046,"name":"Ampang","coord":{"lat":3.1498,"lon":101.768},"main":{"temp":305.15,"pressure":1007,"humidity":59,"temp_min":305.15,"temp_max":305.15},"dt":1530781200,"wind":{"speed":5.1,"deg":180},"sys":{"country":"MY"},"rain":null,"snow":null,"clouds":{"all":75},"weather":[{"id":803,"main":"Clouds","description":"broken clouds","icon":"04d"}]},{"id":1733046,"name":"Ampang","coord":{"lat":3.1521,"lon":101.7322},"main":{"temp":305.15,"pressure":1007,"humidity":59,"temp_min":305.15,"temp_max":305.15},"dt":1530781200,"wind":{"speed":5.1,"deg":180},"sys":{"country":"MY"},"rain":null,"snow":null,"clouds":{"all":75},"weather":[{"id":803,"main":"Clouds","description":"broken clouds","icon":"04d"}]}]})
# 15
#
# Ipoh
# ?({"message":"accurate","cod":"200","count":1,"list":[{"id":1734634,"name":"Ipoh","coord":{"lat":4.592,"lon":101.0833},"main":{"temp":305.54,"pressure":1006,"humidity":52,"temp_min":305.15,"temp_max":306.15},"dt":1530777600,"wind":{"speed":4.6,"deg":200},"sys":{"country":"MY"},"rain":null,"snow":null,"clouds":{"all":75},"weather":[{"id":803,"main":"Clouds","description":"broken clouds","icon":"04d"}]}]})
# 16
#
# Shah Alam
# ?({"message":"accurate","cod":"200","count":1,"list":[{"id":1732903,"name":"Shah Alam","coord":{"lat":3.0686,"lon":101.5183},"main":{"temp":305.15,"pressure":1007,"humidity":59,"temp_min":305.15,"temp_max":305.15},"dt":1530781200,"wind":{"speed":5.1,"deg":180},"sys":{"country":"MY"},"rain":null,"snow":null,"clouds":{"all":75},"weather":[{"id":803,"main":"Clouds","description":"broken clouds","icon":"04d"}]}]})
# 17
#
# Kuching
# ?({"message":"accurate","cod":"200","count":1,"list":[{"id":1735634,"name":"Kuching","coord":{"lat":1.5574,"lon":110.344},"main":{"temp":304.15,"pressure":1007,"humidity":66,"temp_min":304.15,"temp_max":304.15},"dt":1530781200,"wind":{"speed":2.6,"deg":150},"sys":{"country":"MY"},"rain":null,"snow":null,"clouds":{"all":75},"weather":[{"id":803,"main":"Clouds","description":"broken clouds","icon":"04d"}]}]})
# 18
#
# Petaling Jaya
# ?({"message":"accurate","cod":"200","count":1,"list":[{"id":1735158,"name":"Petaling Jaya","coord":{"lat":3.1056,"lon":101.6427},"main":{"temp":305.15,"pressure":1007,"humidity":59,"temp_min":305.15,"temp_max":305.15},"dt":1530781200,"wind":{"speed":5.1,"deg":180},"sys":{"country":"MY"},"rain":null,"snow":null,"clouds":{"all":75},"weather":[{"id":803,"main":"Clouds","description":"broken clouds","icon":"04d"}]}]})
# 19
#
# Kota Kinabalu
# ?({"message":"accurate","cod":"200","count":1,"list":[{"id":1733432,"name":"Kota Kinabalu","coord":{"lat":5.978,"lon":116.0729},"main":{"temp":303.15,"pressure":1007,"humidity":70,"temp_min":303.15,"temp_max":303.15},"dt":1530781200,"wind":{"speed":3.6},"sys":{"country":"MY"},"rain":null,"snow":null,"clouds":{"all":75},"weather":[{"id":803,"main":"Clouds","description":"broken clouds","icon":"04d"}]}]})
# 20
#
# George Town
# ?({"message":"accurate","cod":"200","count":1,"list":[{"id":1735106,"name":"George Town","coord":{"lat":5.4166,"lon":100.3304},"main":{"temp":305.15,"pressure":1007,"humidity":66,"temp_min":305.15,"temp_max":305.15},"dt":1530781200,"wind":{"speed":6.7,"deg":220},"sys":{"country":"MY"},"rain":null,"snow":null,"clouds":{"all":75},"weather":[{"id":803,"main":"Clouds","description":"broken clouds","icon":"04d"}]}]})
# 21
#
# Iskandar Puteri
# ?({"message":"accurate","cod":"200","count":1,"list":[{"id":1732752,"name":"Iskandar Puteri","coord":{"lat":1.4266,"lon":103.6402},"main":{"temp":304.4,"pressure":1007,"humidity":70,"temp_min":304.15,"temp_max":305.15},"dt":1530781200,"wind":{"speed":3.1,"deg":170},"sys":{"country":"MY"},"rain":null,"snow":null,"clouds":{"all":75},"weather":[{"id":803,"main":"Clouds","description":"broken clouds","icon":"04d"}]}]})
# 22
#
# Melaka
# ?({"message":"accurate","cod":"200","count":1,"list":[{"id":1734759,"name":"Melaka","coord":{"lat":2.196,"lon":102.2405},"main":{"temp":303.15,"pressure":1008,"humidity":70,"temp_min":303.15,"temp_max":303.15},"dt":1530777600,"wind":{"speed":2.1},"sys":{"country":"MY"},"rain":null,"snow":null,"clouds":{"all":75},"weather":[{"id":803,"main":"Clouds","description":"broken clouds","icon":"04d"}]}]})
# 23
#
# Alor Setar
# ?({"message":"accurate","cod":"200","count":1,"list":[{"id":1736309,"name":"Alor Setar","coord":{"lat":6.1232,"lon":100.3684},"main":{"temp":305.15,"pressure":1006,"humidity":79,"temp_min":305.15,"temp_max":305.15},"dt":1530777600,"wind":{"speed":4.6,"deg":270},"sys":{"country":"MY"},"rain":null,"snow":null,"clouds":{"all":75},"weather":[{"id":803,"main":"Clouds","description":"broken clouds","icon":"04d"}]}]})
# 24
#
# Bintulu
# ?({"message":"accurate","cod":"200","count":1,"list":[{"id":1737486,"name":"Bintulu","coord":{"lat":3.1667,"lon":113.0333},"main":{"temp":304.15,"pressure":1007,"humidity":70,"temp_min":304.15,"temp_max":304.15},"dt":1530781200,"wind":{"speed":2.6,"deg":310},"sys":{"country":"MY"},"rain":null,"snow":null,"clouds":{"all":75},"weather":[{"id":803,"main":"Clouds","description":"broken clouds","icon":"04d"}]}]})
# 25
#
# Kampung Baru Subang
# ?({"message":"accurate","cod":"200","count":1,"list":[{"id":1771023,"name":"Kampung Baru Subang","coord":{"lat":3.15,"lon":101.5333},"main":{"temp":305.15,"pressure":1007,"humidity":59,"temp_min":305.15,"temp_max":305.15},"dt":1530781200,"wind":{"speed":5.1,"deg":180},"sys":{"country":"MY"},"rain":null,"snow":null,"clouds":{"all":75},"weather":[{"id":803,"main":"Clouds","description":"broken clouds","icon":"04d"}]}]})
# 26
#
# Kota Bharu
# ?({"message":"accurate","cod":"200","count":1,"list":[{"id":1736376,"name":"Kota Bharu","coord":{"lat":6.1256,"lon":102.2393},"main":{"temp":304.51,"pressure":1006,"humidity":70,"temp_min":304.15,"temp_max":305.15},"dt":1530777600,"wind":{"speed":3.6,"deg":80},"sys":{"country":"MY"},"rain":null,"snow":null,"clouds":{"all":75},"weather":[{"id":521,"main":"Rain","description":"proximity shower rain","icon":"09d"}]}]})
# 27
#
# Sungai Petani
# ?({"message":"accurate","cod":"200","count":1,"list":[{"id":1735498,"name":"Sungai Petani","coord":{"lat":5.6439,"lon":100.4916},"main":{"temp":305.15,"pressure":1007,"humidity":66,"temp_min":305.15,"temp_max":305.15},"dt":1530781200,"wind":{"speed":6.7,"deg":220},"sys":{"country":"MY"},"rain":null,"snow":null,"clouds":{"all":75},"weather":[{"id":803,"main":"Clouds","description":"broken clouds","icon":"04d"}]}]})
# 28
#
# Taiping
# ?({"message":"accurate","cod":"200","count":1,"list":[{"id":1734586,"name":"Taiping","coord":{"lat":4.8478,"lon":100.7372},"main":{"temp":306.15,"pressure":1006,"humidity":52,"temp_min":306.15,"temp_max":306.15},"dt":1530777600,"wind":{"speed":4.6,"deg":200},"sys":{"country":"MY"},"rain":null,"snow":null,"clouds":{"all":75},"weather":[{"id":803,"main":"Clouds","description":"broken clouds","icon":"04d"}]}]})
# 29
#
# Bukit Mertajam
# ?({"message":"accurate","cod":"200","count":1,"list":[{"id":1735079,"name":"Bukit Mertajam","coord":{"lat":5.3637,"lon":100.456},"main":{"temp":305.15,"pressure":1007,"humidity":66,"temp_min":305.15,"temp_max":305.15},"dt":1530781200,"wind":{"speed":6.7,"deg":220},"sys":{"country":"MY"},"rain":null,"snow":null,"clouds":{"all":75},"weather":[{"id":803,"main":"Clouds","description":"broken clouds","icon":"04d"}]}]})
# 30
#
# Sepang
# ?({"message":"accurate","cod":"200","count":1,"list":[{"id":1734815,"name":"Sepang","coord":{"lat":2.6924,"lon":101.7502},"main":{"temp":305.15,"pressure":1007,"humidity":59,"temp_min":305.15,"temp_max":305.15},"dt":1530781200,"wind":{"speed":3.6,"deg":140},"sys":{"country":"MY"},"rain":null,"snow":null,"clouds":{"all":75},"weather":[{"id":803,"main":"Clouds","description":"broken clouds","icon":"04d"}]}]})
# 31
#
# Sibu
# ?({"message":"accurate","cod":"200","count":1,"list":[{"id":1735902,"name":"Sibu","coord":{"lat":2.2907,"lon":111.8263},"main":{"temp":304.15,"pressure":1006,"humidity":66,"temp_min":304.15,"temp_max":304.15},"dt":1530777600,"wind":{"speed":1},"sys":{"country":"MY"},"rain":null,"snow":null,"clouds":{"all":75},"weather":[{"id":803,"main":"Clouds","description":"broken clouds","icon":"04d"}]}]})
# 32
#
# Kulim
# ?({"message":"accurate","cod":"200","count":1,"list":[{"id":1734393,"name":"Kulim","coord":{"lat":5.3708,"lon":100.5547},"main":{"temp":305.15,"pressure":1007,"humidity":66,"temp_min":305.15,"temp_max":305.15},"dt":1530781200,"wind":{"speed":6.7,"deg":220},"sys":{"country":"MY"},"rain":null,"snow":null,"clouds":{"all":75},"weather":[{"id":803,"main":"Clouds","description":"broken clouds","icon":"04d"}]}]})
# 33
#
# Kluang
# ?({"message":"accurate","cod":"200","count":1,"list":[{"id":1732811,"name":"Kluang","coord":{"lat":2.0353,"lon":103.3205},"main":{"temp":304.15,"pressure":1007,"humidity":70,"temp_min":304.15,"temp_max":304.15},"dt":1530781200,"wind":{"speed":3.1,"deg":170},"sys":{"country":"MY"},"rain":null,"snow":null,"clouds":{"all":75},"weather":[{"id":803,"main":"Clouds","description":"broken clouds","icon":"04d"}]}]})
# 34
#
# Skudai
# ?({"message":"accurate","cod":"200","count":1,"list":[{"id":1732752,"name":"Skudai","coord":{"lat":1.5469,"lon":103.6593},"main":{"temp":304.4,"pressure":1007,"humidity":70,"temp_min":304.15,"temp_max":305.15},"dt":1530781200,"wind":{"speed":3.1,"deg":170},"sys":{"country":"MY"},"rain":null,"snow":null,"clouds":{"all":75},"weather":[{"id":803,"main":"Clouds","description":"broken clouds","icon":"04d"}]}]})
# 35
#
# Batu Pahat
# ?({"message":"accurate","cod":"200","count":1,"list":[{"id":1732687,"name":"Batu Pahat","coord":{"lat":1.85,"lon":102.9363},"main":{"temp":304.464,"pressure":1017.47,"humidity":69,"temp_min":304.464,"temp_max":304.464,"sea_level":1020.4,"grnd_level":1017.47},"dt":1530782586,"wind":{"speed":5.36,"deg":157},"sys":{"country":"MY"},"rain":null,"snow":null,"clouds":{"all":8},"weather":[{"id":800,"main":"Clear","description":"sky is clear","icon":"02d"}]}]})
# 36
#
# Kampung Pasir Gudang Baru
# ?({"message":"accurate","cod":"200","count":1,"list":[{"id":1732721,"name":"Kampung Pasir Gudang Baru","coord":{"lat":1.4726,"lon":103.878},"main":{"temp":304.4,"pressure":1008,"humidity":52,"temp_min":304.15,"temp_max":305.15},"dt":1530781200,"wind":{"speed":4.6,"deg":180},"sys":{"country":"MY"},"rain":null,"snow":null,"clouds":{"all":75},"weather":[{"id":803,"main":"Clouds","description":"broken clouds","icon":"04d"}]}]})
# 37
#
# Kampung Sungai Ara
# ?({"message":"accurate","cod":"200","count":1,"list":[{"id":1764160,"name":"Kampung Sungai Ara","coord":{"lat":5.327,"lon":100.2735},"main":{"temp":305.15,"pressure":1007,"humidity":66,"temp_min":305.15,"temp_max":305.15},"dt":1530781200,"wind":{"speed":6.7,"deg":220},"sys":{"country":"MY"},"rain":null,"snow":null,"clouds":{"all":75},"weather":[{"id":803,"main":"Clouds","description":"broken clouds","icon":"04d"}]}]})
# 38
#
# Tasek Glugor
# ?({"message":"accurate","cod":"200","count":1,"list":[{"id":1735093,"name":"Tasek Glugor","coord":{"lat":5.4803,"lon":100.4985},"main":{"temp":305.15,"pressure":1007,"humidity":66,"temp_min":305.15,"temp_max":305.15},"dt":1530781200,"wind":{"speed":6.7,"deg":220},"sys":{"country":"MY"},"rain":null,"snow":null,"clouds":{"all":75},"weather":[{"id":803,"main":"Clouds","description":"broken clouds","icon":"04d"}]}]})
# 39
#
# Muar
# ?({"message":"accurate","cod":"200","count":1,"list":[{"id":1732869,"name":"Muar","coord":{"lat":2.0432,"lon":102.5667},"main":{"temp":303.15,"pressure":1008,"humidity":70,"temp_min":303.15,"temp_max":303.15},"dt":1530777600,"wind":{"speed":2.1},"sys":{"country":"MY"},"rain":null,"snow":null,"clouds":{"all":75},"weather":[{"id":803,"main":"Clouds","description":"broken clouds","icon":"04d"}]}]})
# 40
#
# Rawang
# ?({"message":"accurate","cod":"200","count":1,"list":[{"id":1735150,"name":"Rawang","coord":{"lat":3.3204,"lon":101.5766},"main":{"temp":305.15,"pressure":1007,"humidity":59,"temp_min":305.15,"temp_max":305.15},"dt":1530781200,"wind":{"speed":5.1,"deg":180},"sys":{"country":"MY"},"rain":null,"snow":null,"clouds":{"all":75},"weather":[{"id":803,"main":"Clouds","description":"broken clouds","icon":"04d"}]}]})
# 41
#
# Butterworth
# ?({"message":"accurate","cod":"200","count":1,"list":[{"id":1735076,"name":"Butterworth","coord":{"lat":5.3954,"lon":100.3749},"main":{"temp":305.15,"pressure":1007,"humidity":66,"temp_min":305.15,"temp_max":305.15},"dt":1530781200,"wind":{"speed":6.7,"deg":220},"sys":{"country":"MY"},"rain":null,"snow":null,"clouds":{"all":75},"weather":[{"id":803,"main":"Clouds","description":"broken clouds","icon":"04d"}]}]})
# 42
#
# Lahad Datu
# ?({"message":"accurate","cod":"200","count":1,"list":[{"id":1733953,"name":"Lahad Datu","coord":{"lat":5.0216,"lon":118.3276},"main":{"temp":300.314,"pressure":1000.12,"humidity":89,"temp_min":300.314,"temp_max":300.314,"sea_level":1021.42,"grnd_level":1000.12},"dt":1530782593,"wind":{"speed":1.81,"deg":147.5},"sys":{"country":"MY"},"rain":{"3h":0.2325},"snow":null,"clouds":{"all":36},"weather":[{"id":500,"main":"Rain","description":"light rain","icon":"10d"}]}]})
# 43
#
# Semenyih
# ?({"message":"accurate","cod":"200","count":1,"list":[{"id":1734798,"name":"Semenyih","coord":{"lat":2.9483,"lon":101.8427},"main":{"temp":305.15,"pressure":1007,"humidity":59,"temp_min":305.15,"temp_max":305.15},"dt":1530781200,"wind":{"speed":3.6,"deg":140},"sys":{"country":"MY"},"rain":null,"snow":null,"clouds":{"all":75},"weather":[{"id":803,"main":"Clouds","description":"broken clouds","icon":"04d"}]}]})
# 44
#
# Port Dickson
# ?({"message":"accurate","cod":"200","count":1,"list":[{"id":1734815,"name":"Port Dickson","coord":{"lat":2.5229,"lon":101.7945},"main":{"temp":303.75,"pressure":1007,"humidity":59,"temp_min":303.15,"temp_max":305.15},"dt":1530781200,"wind":{"speed":3.6,"deg":140},"sys":{"country":"MY"},"rain":null,"snow":null,"clouds":{"all":75},"weather":[{"id":803,"main":"Clouds","description":"broken clouds","icon":"04d"}]}]})
# 45
#
# Cukai
# ?({"message":"accurate","cod":"200","count":1,"list":[{"id":1732945,"name":"Cukai","coord":{"lat":4.25,"lon":103.4167},"main":{"temp":304.71,"pressure":1006,"humidity":66,"temp_min":304.15,"temp_max":305.15},"dt":1530777600,"wind":{"speed":4.1,"deg":150},"sys":{"country":"MY"},"rain":null,"snow":null,"clouds":{"all":75},"weather":[{"id":803,"main":"Clouds","description":"broken clouds","icon":"04d"}]}]})
# 46
#
# Putatan
# ?({"message":"accurate","cod":"200","count":1,"list":[{"id":1733440,"name":"Putatan","coord":{"lat":5.8833,"lon":116.05},"main":{"temp":303.15,"pressure":1007,"humidity":70,"temp_min":303.15,"temp_max":303.15},"dt":1530781200,"wind":{"speed":3.6},"sys":{"country":"MY"},"rain":null,"snow":null,"clouds":{"all":75},"weather":[{"id":803,"main":"Clouds","description":"broken clouds","icon":"04d"}]}]})
# 47
#
# Keningau
# ?({"message":"accurate","cod":"200","count":1,"list":[{"id":1734098,"name":"Keningau","coord":{"lat":5.3288,"lon":116.1555},"main":{"temp":303.15,"pressure":1007,"humidity":70,"temp_min":303.15,"temp_max":303.15},"dt":1530781200,"wind":{"speed":3.6},"sys":{"country":"MY"},"rain":null,"snow":null,"clouds":{"all":75},"weather":[{"id":803,"main":"Clouds","description":"broken clouds","icon":"04d"}]}]})
# 48
#
# Ulu Tiram
# ?({"message":"accurate","cod":"200","count":1,"list":[{"id":1738294,"name":"Ulu Tiram","coord":{"lat":1.6051,"lon":103.8239},"main":{"temp":304.4,"pressure":1007,"humidity":70,"temp_min":304.15,"temp_max":305.15},"dt":1530781200,"wind":{"speed":3.1,"deg":170},"sys":{"country":"MY"},"rain":null,"snow":null,"clouds":{"all":75},"weather":[{"id":803,"main":"Clouds","description":"broken clouds","icon":"04d"}]}]})
# 49
#
# Victoria
# ?({"message":"accurate","cod":"200","count":1,"list":[{"id":1733782,"name":"Victoria","coord":{"lat":5.2767,"lon":115.2417},"main":{"temp":303.71,"pressure":1007,"humidity":70,"temp_min":303.15,"temp_max":304.15},"dt":1530781200,"wind":{"speed":1.5,"deg":270},"sys":{"country":"MY"},"rain":null,"snow":null,"clouds":{"all":75},"weather":[{"id":803,"main":"Clouds","description":"broken clouds","icon":"04d"}]}]})
# 50
#
# Taman Senai
# ?({"message":"accurate","cod":"200","count":1,"list":[{"id":1732741,"name":"Taman Senai","coord":{"lat":1.6006,"lon":103.6419},"main":{"temp":304.4,"pressure":1007,"humidity":70,"temp_min":304.15,"temp_max":305.15},"dt":1530781200,"wind":{"speed":3.1,"deg":170},"sys":{"country":"MY"},"rain":null,"snow":null,"clouds":{"all":75},"weather":[{"id":803,"main":"Clouds","description":"broken clouds","icon":"04d"}]}]})
# 51
#
# Donggongon
# ?({"message":"accurate","cod":"200","count":1,"list":[{"id":1733438,"name":"Donggongon","coord":{"lat":5.907,"lon":116.1015},"main":{"temp":303.15,"pressure":1007,"humidity":70,"temp_min":303.15,"temp_max":303.15},"dt":1530781200,"wind":{"speed":3.6},"sys":{"country":"MY"},"rain":null,"snow":null,"clouds":{"all":75},"weather":[{"id":803,"main":"Clouds","description":"broken clouds","icon":"04d"}]}]})
# 52
#
# Segamat
# ?({"message":"accurate","cod":"200","count":1,"list":[{"id":1732846,"name":"Segamat","coord":{"lat":2.5064,"lon":102.8151},"main":{"temp":303.15,"pressure":1008,"humidity":70,"temp_min":303.15,"temp_max":303.15},"dt":1530777600,"wind":{"speed":2.1},"sys":{"country":"MY"},"rain":null,"snow":null,"clouds":{"all":75},"weather":[{"id":803,"main":"Clouds","description":"broken clouds","icon":"04d"}]}]})
# 53
#
# Kampong Baharu Balakong
# ?({"message":"accurate","cod":"200","count":1,"list":[{"id":1771304,"name":"Kampong Baharu Balakong","coord":{"lat":3.0333,"lon":101.75},"main":{"temp":305.15,"pressure":1007,"humidity":59,"temp_min":305.15,"temp_max":305.15},"dt":1530781200,"wind":{"speed":5.1,"deg":180},"sys":{"country":"MY"},"rain":null,"snow":null,"clouds":{"all":75},"weather":[{"id":803,"main":"Clouds","description":"broken clouds","icon":"04d"}]}]})
# 54
#
# Perai
# ?({"message":"accurate","cod":"200","count":1,"list":[{"id":1735106,"name":"Prai","coord":{"lat":5.3778,"lon":100.382},"main":{"temp":305.15,"pressure":1007,"humidity":66,"temp_min":305.15,"temp_max":305.15},"dt":1530781200,"wind":{"speed":6.7,"deg":220},"sys":{"country":"MY"},"rain":null,"snow":null,"clouds":{"all":75},"weather":[{"id":803,"main":"Clouds","description":"broken clouds","icon":"04d"}]}]})
# 55
#
# Kangar
# ?({"message":"accurate","cod":"200","count":1,"list":[{"id":1736278,"name":"Kangar","coord":{"lat":6.4389,"lon":100.1945},"main":{"temp":302.44,"pressure":1007,"humidity":74,"temp_min":300.15,"temp_max":305.15},"dt":1530779400,"wind":{"speed":3.1,"deg":270},"sys":{"country":"MY"},"rain":null,"snow":null,"clouds":{"all":75},"weather":[{"id":201,"main":"Thunderstorm","description":"thunderstorm with rain","icon":"11d"},{"id":500,"main":"Rain","description":"light rain","icon":"10d"}]}]})
# 56
#
# Kulai
# ?({"message":"accurate","cod":"200","count":1,"list":[{"id":1732742,"name":"Kulai","coord":{"lat":1.6569,"lon":103.6059},"main":{"temp":304.4,"pressure":1007,"humidity":70,"temp_min":304.15,"temp_max":305.15},"dt":1530781200,"wind":{"speed":3.1,"deg":170},"sys":{"country":"MY"},"rain":null,"snow":null,"clouds":{"all":75},"weather":[{"id":803,"main":"Clouds","description":"broken clouds","icon":"04d"}]}]})
# 57
#
# Jitra
# ?({"message":"accurate","cod":"200","count":1,"list":[{"id":1736302,"name":"Jitra","coord":{"lat":6.2692,"lon":100.4168},"main":{"temp":305.15,"pressure":1006,"humidity":79,"temp_min":305.15,"temp_max":305.15},"dt":1530777600,"wind":{"speed":4.6,"deg":270},"sys":{"country":"MY"},"rain":null,"snow":null,"clouds":{"all":75},"weather":[{"id":803,"main":"Clouds","description":"broken clouds","icon":"04d"}]}]})
# 58
#
# Teluk Intan
# ?({"message":"accurate","cod":"200","count":1,"list":[{"id":1735459,"name":"Teluk Intan","coord":{"lat":4.0232,"lon":101.0262},"main":{"temp":305.7,"pressure":1006,"humidity":62,"temp_min":305.15,"temp_max":306.15},"dt":1530777600,"wind":{"speed":4.6},"sys":{"country":"MY"},"rain":null,"snow":null,"clouds":{"all":75},"weather":[{"id":803,"main":"Clouds","description":"broken clouds","icon":"04d"}]}]})
# 59
#
# Semporna
# ?({"message":"accurate","cod":"200","count":1,"list":[{"id":1733697,"name":"Semporna","coord":{"lat":4.48,"lon":118.6117},"main":{"temp":301.15,"pressure":1007,"humidity":78,"temp_min":301.15,"temp_max":301.15},"dt":1530781200,"wind":{"speed":2.6},"sys":{"country":"MY"},"rain":null,"snow":null,"clouds":{"all":75},"weather":[{"id":521,"main":"Rain","description":"proximity shower rain","icon":"09d"}]}]})
# 60
#
# Putra Heights
# ?({"message":"accurate","cod":"200","count":1,"list":[{"id":1732905,"name":"Putra Heights","coord":{"lat":2.9957,"lon":101.5671},"main":{"temp":305.15,"pressure":1007,"humidity":59,"temp_min":305.15,"temp_max":305.15},"dt":1530781200,"wind":{"speed":5.1,"deg":180},"sys":{"country":"MY"},"rain":null,"snow":null,"clouds":{"all":75},"weather":[{"id":803,"main":"Clouds","description":"broken clouds","icon":"04d"}]}]})
# 61
#
# Temerluh
# ?({"message":"accurate","cod":"200","count":1,"list":[{"id":1735022,"name":"Temerluh","coord":{"lat":3.4506,"lon":102.4176},"main":{"temp":304.664,"pressure":1008.47,"humidity":63,"temp_min":304.664,"temp_max":304.664,"sea_level":1019.8,"grnd_level":1008.47},"dt":1530782619,"wind":{"speed":2.21,"deg":195},"sys":{"country":"MY"},"rain":null,"snow":null,"clouds":{"all":24},"weather":[{"id":801,"main":"Clouds","description":"few clouds","icon":"02d"}]}]})
# 62
#
# Kampong Dungun
# ?({"message":"accurate","cod":"200","count":1,"list":[{"id":1769612,"name":"Kampong Dungun","coord":{"lat":3.2167,"lon":101.3167},"main":{"temp":305.15,"pressure":1007,"humidity":59,"temp_min":305.15,"temp_max":305.15},"dt":1530781200,"wind":{"speed":5.1,"deg":180},"sys":{"country":"MY"},"rain":null,"snow":null,"clouds":{"all":75},"weather":[{"id":803,"main":"Clouds","description":"broken clouds","icon":"04d"}]}]})
# 63
#
# Simpang Empat
# ?({"message":"accurate","cod":"200","count":4,"list":[{"id":1733040,"name":"Simpang Empat","coord":{"lat":6.3358,"lon":100.1842},"main":{"temp":302.42,"pressure":1007,"humidity":74,"temp_min":300.15,"temp_max":305.15},"dt":1530779400,"wind":{"speed":3.1,"deg":270},"sys":{"country":"MY"},"rain":null,"snow":null,"clouds":{"all":75},"weather":[{"id":201,"main":"Thunderstorm","description":"thunderstorm with rain","icon":"11d"},{"id":500,"main":"Rain","description":"light rain","icon":"10d"}]},{"id":1735459,"name":"Simpang Empat","coord":{"lat":3.8947,"lon":100.9355},"main":{"temp":305.15,"pressure":1006,"humidity":62,"temp_min":305.15,"temp_max":305.15},"dt":1530777600,"wind":{"speed":4.6},"sys":{"country":"MY"},"rain":null,"snow":null,"clouds":{"all":75},"weather":[{"id":803,"main":"Clouds","description":"broken clouds","icon":"04d"}]},{"id":1736309,"name":"Simpang Empat","coord":{"lat":6.024,"lon":100.3818},"main":{"temp":305.15,"pressure":1006,"humidity":79,"temp_min":305.15,"temp_max":305.15},"dt":1530777600,"wind":{"speed":4.6,"deg":270},"sys":{"country":"MY"},"rain":null,"snow":null,"clouds":{"all":75},"weather":[{"id":803,"main":"Clouds","description":"broken clouds","icon":"04d"}]},{"id":1767021,"name":"Simpang Empat","coord":{"lat":2.4362,"lon":102.1844},"main":{"temp":303.98,"pressure":1007,"humidity":59,"temp_min":303.15,"temp_max":305.15},"dt":1530781200,"wind":{"speed":3.6,"deg":140},"sys":{"country":"MY"},"rain":null,"snow":null,"clouds":{"all":75},"weather":[{"id":803,"main":"Clouds","description":"broken clouds","icon":"04d"}]}]})
# 64
#
# Kuala Selangor
# ?({"message":"accurate","cod":"200","count":1,"list":[{"id":1732891,"name":"Kuala Selangor","coord":{"lat":3.3407,"lon":101.2496},"main":{"temp":305.15,"pressure":1007,"humidity":59,"temp_min":305.15,"temp_max":305.15},"dt":1530781200,"wind":{"speed":5.1,"deg":180},"sys":{"country":"MY"},"rain":null,"snow":null,"clouds":{"all":75},"weather":[{"id":803,"main":"Clouds","description":"broken clouds","icon":"04d"}]}]})
# 65
#
# Kampung Bukit Baharu
# ?({"message":"accurate","cod":"200","count":1,"list":[{"id":1770351,"name":"Kampung Bukit Baharu","coord":{"lat":2.2152,"lon":102.2851},"main":{"temp":303.15,"pressure":1008,"humidity":70,"temp_min":303.15,"temp_max":303.15},"dt":1530777600,"wind":{"speed":2.1},"sys":{"country":"MY"},"rain":null,"snow":null,"clouds":{"all":75},"weather":[{"id":803,"main":"Clouds","description":"broken clouds","icon":"04d"}]}]})
# 66
#
# Bandar Labuan
# ?({"message":"accurate","cod":"200","count":1,"list":[{"id":7302815,"name":"Bandar Labuan","coord":{"lat":5.2888,"lon":115.2692},"main":{"temp":303.71,"pressure":1007,"humidity":70,"temp_min":303.15,"temp_max":304.15},"dt":1530781200,"wind":{"speed":1.5,"deg":270},"sys":{"country":"MY"},"rain":null,"snow":null,"clouds":{"all":75},"weather":[{"id":803,"main":"Clouds","description":"broken clouds","icon":"04d"}]}]})
# 67
#
# Kota Tinggi
# ?({"message":"accurate","cod":"200","count":1,"list":[{"id":1732738,"name":"Kota Tinggi","coord":{"lat":1.7331,"lon":103.9015},"main":{"temp":304.4,"pressure":1007,"humidity":70,"temp_min":304.15,"temp_max":305.15},"dt":1530781200,"wind":{"speed":3.1,"deg":170},"sys":{"country":"MY"},"rain":null,"snow":null,"clouds":{"all":75},"weather":[{"id":803,"main":"Clouds","description":"broken clouds","icon":"04d"}]}]})
# 68
#
# Pontian Kechil
# ?({"message":"accurate","cod":"200","count":1,"list":[{"id":1732711,"name":"Pontian Kechil","coord":{"lat":1.4866,"lon":103.3896},"main":{"temp":304.4,"pressure":1007,"humidity":70,"temp_min":304.15,"temp_max":305.15},"dt":1530781200,"wind":{"speed":3.1,"deg":170},"sys":{"country":"MY"},"rain":null,"snow":null,"clouds":{"all":75},"weather":[{"id":803,"main":"Clouds","description":"broken clouds","icon":"04d"}]}]})
# 69
#
# Putrajaya
# ?({"message":"accurate","cod":"200","count":1,"list":[{"id":6697380,"name":"Putrajaya","coord":{"lat":2.907,"lon":101.6751},"main":{"temp":305.15,"pressure":1007,"humidity":59,"temp_min":305.15,"temp_max":305.15},"dt":1530781200,"wind":{"speed":3.6,"deg":140},"sys":{"country":"MY"},"rain":null,"snow":null,"clouds":{"all":75},"weather":[{"id":803,"main":"Clouds","description":"broken clouds","icon":"04d"}]}]})
# 70
#
# Bentong Town
# ?({"message":"accurate","cod":"200","count":1,"list":[{"id":1779790,"name":"Bentong Town","coord":{"lat":3.5167,"lon":101.9},"main":{"temp":305.15,"pressure":1007,"humidity":59,"temp_min":305.15,"temp_max":305.15},"dt":1530781200,"wind":{"speed":5.1,"deg":180},"sys":{"country":"MY"},"rain":null,"snow":null,"clouds":{"all":75},"weather":[{"id":803,"main":"Clouds","description":"broken clouds","icon":"04d"}]}]})
# 71
#
# Banting
# ?({"message":"accurate","cod":"200","count":1,"list":[{"id":1734781,"name":"Banting","coord":{"lat":2.8171,"lon":101.4995},"main":{"temp":305.15,"pressure":1007,"humidity":59,"temp_min":305.15,"temp_max":305.15},"dt":1530781200,"wind":{"speed":3.6,"deg":140},"sys":{"country":"MY"},"rain":null,"snow":null,"clouds":{"all":75},"weather":[{"id":803,"main":"Clouds","description":"broken clouds","icon":"04d"}]}]})
# 72
#
# Bedong
# ?({"message":"accurate","cod":"200","count":1,"list":[{"id":1734439,"name":"Bedong","coord":{"lat":5.7275,"lon":100.5095},"main":{"temp":305.15,"pressure":1007,"humidity":66,"temp_min":305.15,"temp_max":305.15},"dt":1530781200,"wind":{"speed":6.7,"deg":220},"sys":{"country":"MY"},"rain":null,"snow":null,"clouds":{"all":75},"weather":[{"id":803,"main":"Clouds","description":"broken clouds","icon":"04d"}]}]})
# 73
#
# Batu Gajah
# ?({"message":"accurate","cod":"200","count":1,"list":[{"id":1735268,"name":"Batu Gajah","coord":{"lat":4.4705,"lon":101.037},"main":{"temp":305.58,"pressure":1006,"humidity":52,"temp_min":305.15,"temp_max":306.15},"dt":1530777600,"wind":{"speed":4.6,"deg":200},"sys":{"country":"MY"},"rain":null,"snow":null,"clouds":{"all":75},"weather":[{"id":803,"main":"Clouds","description":"broken clouds","icon":"04d"}]}]})
# 74
#
# Mentekab
# ?({"message":"accurate","cod":"200","count":1,"list":[{"id":1735018,"name":"Mentekab","coord":{"lat":3.4854,"lon":102.3484},"main":{"temp":304.664,"pressure":1008.47,"humidity":63,"temp_min":304.664,"temp_max":304.664,"sea_level":1019.8,"grnd_level":1008.47},"dt":1530782632,"wind":{"speed":2.21,"deg":195},"sys":{"country":"MY"},"rain":null,"snow":null,"clouds":{"all":24},"weather":[{"id":801,"main":"Clouds","description":"few clouds","icon":"02d"}]}]})
# 75
#
# Nibong Tebal
# ?({"message":"accurate","cod":"200","count":1,"list":[{"id":1735086,"name":"Nibong Tebal","coord":{"lat":5.1698,"lon":100.4775},"main":{"temp":305.15,"pressure":1007,"humidity":66,"temp_min":305.15,"temp_max":305.15},"dt":1530781200,"wind":{"speed":6.7,"deg":220},"sys":{"country":"MY"},"rain":null,"snow":null,"clouds":{"all":75},"weather":[{"id":803,"main":"Clouds","description":"broken clouds","icon":"04d"}]}]})
# 76
#
# Raub
# ?({"message":"accurate","cod":"200","count":1,"list":[{"id":1732663,"name":"Raub","coord":{"lat":3.7913,"lon":101.8535},"main":{"temp":300.664,"pressure":981.39,"humidity":76,"temp_min":300.664,"temp_max":300.664,"sea_level":1020.24,"grnd_level":981.39},"dt":1530782635,"wind":{"speed":1.61,"deg":183.5},"sys":{"country":"MY"},"rain":{"3h":1.1075},"snow":null,"clouds":{"all":48},"weather":[{"id":500,"main":"Rain","description":"light rain","icon":"10d"}]}]})
# 77
#
# Kampong Pangkal Kalong
# ?({"message":"accurate","cod":"200","count":1,"list":[{"id":1766249,"name":"Kampong Pangkal Kalong","coord":{"lat":5.9167,"lon":102.2167},"main":{"temp":305.15,"pressure":1006,"humidity":70,"temp_min":305.15,"temp_max":305.15},"dt":1530777600,"wind":{"speed":3.6,"deg":80},"sys":{"country":"MY"},"rain":null,"snow":null,"clouds":{"all":75},"weather":[{"id":803,"main":"Clouds","description":"broken clouds","icon":"04d"}]}]})
# 78
#
# Lumut
# ?({"message":"accurate","cod":"200","count":1,"list":[{"id":1735450,"name":"Lumut","coord":{"lat":4.2323,"lon":100.6298},"main":{"temp":305.77,"pressure":1006,"humidity":62,"temp_min":305.15,"temp_max":306.15},"dt":1530777600,"wind":{"speed":4.6},"sys":{"country":"MY"},"rain":null,"snow":null,"clouds":{"all":75},"weather":[{"id":803,"main":"Clouds","description":"broken clouds","icon":"04d"}]}]})
# 79
#
# Kuala Kangsar
# ?({"message":"accurate","cod":"200","count":1,"list":[{"id":1734599,"name":"Kuala Kangsar","coord":{"lat":4.7721,"lon":100.9409},"main":{"temp":305.56,"pressure":1006,"humidity":52,"temp_min":305.15,"temp_max":306.15},"dt":1530777600,"wind":{"speed":4.6,"deg":200},"sys":{"country":"MY"},"rain":null,"snow":null,"clouds":{"all":75},"weather":[{"id":803,"main":"Clouds","description":"broken clouds","icon":"04d"}]}]})
# 80
#
# Klebang Besar
# ?({"message":"accurate","cod":"200","count":1,"list":[{"id":1761242,"name":"Klebang Besar","coord":{"lat":2.2186,"lon":102.1995},"main":{"temp":303.15,"pressure":1008,"humidity":70,"temp_min":303.15,"temp_max":303.15},"dt":1530777600,"wind":{"speed":2.1},"sys":{"country":"MY"},"rain":null,"snow":null,"clouds":{"all":75},"weather":[{"id":803,"main":"Clouds","description":"broken clouds","icon":"04d"}]}]})
# 81
#
# Kampung Ayer Keroh
# ?({"message":"accurate","cod":"200","count":1,"list":[{"id":1734753,"name":"Kampung Ayer Keroh","coord":{"lat":2.2654,"lon":102.2801},"main":{"temp":303.15,"pressure":1008,"humidity":70,"temp_min":303.15,"temp_max":303.15},"dt":1530777600,"wind":{"speed":2.1},"sys":{"country":"MY"},"rain":null,"snow":null,"clouds":{"all":75},"weather":[{"id":803,"main":"Clouds","description":"broken clouds","icon":"04d"}]}]})
# 82
#
# Kampung Baharu Nilai
# ?({"message":"accurate","cod":"200","count":1,"list":[{"id":1771287,"name":"Kampung Baharu Nilai","coord":{"lat":2.8033,"lon":101.7972},"main":{"temp":305.15,"pressure":1007,"humidity":59,"temp_min":305.15,"temp_max":305.15},"dt":1530781200,"wind":{"speed":3.6,"deg":140},"sys":{"country":"MY"},"rain":null,"snow":null,"clouds":{"all":75},"weather":[{"id":803,"main":"Clouds","description":"broken clouds","icon":"04d"}]}]})
# 83
#
# Tangkak
# ?({"message":"accurate","cod":"200","count":1,"list":[{"id":1732857,"name":"Tangkak","coord":{"lat":2.267,"lon":102.54},"main":{"temp":303.15,"pressure":1008,"humidity":70,"temp_min":303.15,"temp_max":303.15},"dt":1530777600,"wind":{"speed":2.1},"sys":{"country":"MY"},"rain":null,"snow":null,"clouds":{"all":75},"weather":[{"id":803,"main":"Clouds","description":"broken clouds","icon":"04d"}]}]})
# 84
#
# Jerantut
# ?({"message":"accurate","cod":"200","count":1,"list":[{"id":1732602,"name":"Jerantut","coord":{"lat":3.9359,"lon":102.3652},"main":{"temp":303.814,"pressure":986.58,"humidity":60,"temp_min":303.814,"temp_max":303.814,"sea_level":1019.63,"grnd_level":986.58},"dt":1530782643,"wind":{"speed":1.76,"deg":192.5},"sys":{"country":"MY"},"rain":{"3h":0.44},"snow":null,"clouds":{"all":12},"weather":[{"id":500,"main":"Rain","description":"light rain","icon":"10d"}]}]})
# 85
#
# Kudat
# ?({"message":"accurate","cod":"200","count":1,"list":[{"id":1736458,"name":"Kudat","coord":{"lat":6.8895,"lon":116.8431},"main":{"temp":301.15,"pressure":1007,"humidity":78,"temp_min":301.15,"temp_max":301.15},"dt":1530781200,"wind":{"speed":5.1,"deg":280},"sys":{"country":"MY"},"rain":null,"snow":null,"clouds":{"all":75},"weather":[{"id":803,"main":"Clouds","description":"broken clouds","icon":"04d"}]}]})
# 86
#
# Pekan
# ?({"message":"accurate","cod":"200","count":1,"list":[{"id":1734971,"name":"Pekan","coord":{"lat":3.4901,"lon":103.3937},"main":{"temp":305.15,"pressure":1007,"humidity":66,"temp_min":305.15,"temp_max":305.15},"dt":1530777600,"wind":{"speed":2.6,"deg":170},"sys":{"country":"MY"},"rain":null,"snow":null,"clouds":{"all":75},"weather":[{"id":803,"main":"Clouds","description":"broken clouds","icon":"04d"}]}]})
# 87
#
# Bahau
# ?({"message":"accurate","cod":"200","count":1,"list":[{"id":1734839,"name":"Bahau","coord":{"lat":2.8087,"lon":102.3964},"main":{"temp":303.15,"pressure":1008,"humidity":70,"temp_min":303.15,"temp_max":303.15},"dt":1530777600,"wind":{"speed":2.1},"sys":{"country":"MY"},"rain":null,"snow":null,"clouds":{"all":75},"weather":[{"id":803,"main":"Clouds","description":"broken clouds","icon":"04d"}]}]})
# 88
#
# Bakri
# ?({"message":"accurate","cod":"200","count":1,"list":[{"id":1732871,"name":"Bakri","coord":{"lat":2.05,"lon":102.6667},"main":{"temp":303.15,"pressure":1008,"humidity":70,"temp_min":303.15,"temp_max":303.15},"dt":1530777600,"wind":{"speed":2.1},"sys":{"country":"MY"},"rain":null,"snow":null,"clouds":{"all":75},"weather":[{"id":803,"main":"Clouds","description":"broken clouds","icon":"04d"}]}]})
# 89
#
# Kuah
# ?({"message":"accurate","cod":"200","count":1,"list":[{"id":1222396,"name":"Kuah","coord":{"lat":6.3265,"lon":99.8432},"main":{"temp":303.19,"pressure":1007,"humidity":83,"temp_min":300.15,"temp_max":305.15},"dt":1530777600,"wind":{"speed":2.1,"deg":140},"sys":{"country":"MY"},"rain":null,"snow":null,"clouds":{"all":75},"weather":[{"id":201,"main":"Thunderstorm","description":"thunderstorm with rain","icon":"11d"}]}]})
# 90
#
# Bidur
# ?({"message":"accurate","cod":"200","count":1,"list":[{"id":1735287,"name":"Bidur","coord":{"lat":4.1167,"lon":101.2833},"main":{"temp":305.62,"pressure":1006,"humidity":52,"temp_min":305.15,"temp_max":306.15},"dt":1530777600,"wind":{"speed":4.6,"deg":200},"sys":{"country":"MY"},"rain":null,"snow":null,"clouds":{"all":75},"weather":[{"id":803,"main":"Clouds","description":"broken clouds","icon":"04d"}]}]})
# 91
#
# Sarikei
# ?({"message":"accurate","cod":"200","count":1,"list":[{"id":1735837,"name":"Sarikei","coord":{"lat":2.1295,"lon":111.5231},"main":{"temp":304.15,"pressure":1006,"humidity":66,"temp_min":304.15,"temp_max":304.15},"dt":1530777600,"wind":{"speed":1},"sys":{"country":"MY"},"rain":null,"snow":null,"clouds":{"all":75},"weather":[{"id":803,"main":"Clouds","description":"broken clouds","icon":"04d"}]}]})
# 92
#
# Kampong Masjid Tanah
# ?({"message":"accurate","cod":"200","count":1,"list":[{"id":1767021,"name":"Kampong Masjid Tanah","coord":{"lat":2.35,"lon":102.1167},"main":{"temp":303.99,"pressure":1007,"humidity":59,"temp_min":303.15,"temp_max":305.15},"dt":1530781200,"wind":{"speed":3.6,"deg":140},"sys":{"country":"MY"},"rain":null,"snow":null,"clouds":{"all":75},"weather":[{"id":803,"main":"Clouds","description":"broken clouds","icon":"04d"}]}]})
# 93
#
# Tanah Merah
# ?({"message":"accurate","cod":"200","count":5,"list":[{"id":1735553,"name":"Tanah Merah","coord":{"lat":5.8098,"lon":102.1484},"main":{"temp":305.15,"pressure":1006,"humidity":70,"temp_min":305.15,"temp_max":305.15},"dt":1530777600,"wind":{"speed":3.6,"deg":80},"sys":{"country":"MY"},"rain":null,"snow":null,"clouds":{"all":75},"weather":[{"id":803,"main":"Clouds","description":"broken clouds","icon":"04d"}]},{"id":1736309,"name":"Tanah Merah","coord":{"lat":6.0261,"lon":100.4773},"main":{"temp":305.15,"pressure":1006,"humidity":79,"temp_min":305.15,"temp_max":305.15},"dt":1530777600,"wind":{"speed":4.6,"deg":270},"sys":{"country":"MY"},"rain":null,"snow":null,"clouds":{"all":75},"weather":[{"id":803,"main":"Clouds","description":"broken clouds","icon":"04d"}]},{"id":1880252,"name":"Tanah Merah","coord":{"lat":1.317,"lon":103.9875},"main":{"temp":304.4,"pressure":1008,"humidity":62,"temp_min":304.15,"temp_max":305.15},"dt":1530781200,"wind":{"speed":5.1,"deg":170},"sys":{"country":"MY"},"rain":null,"snow":null,"clouds":{"all":75},"weather":[{"id":803,"main":"Clouds","description":"broken clouds","icon":"04d"}]},{"id":1736309,"name":"Tanah Merah","coord":{"lat":6.2413,"lon":100.4165},"main":{"temp":305.15,"pressure":1006,"humidity":79,"temp_min":305.15,"temp_max":305.15},"dt":1530777600,"wind":{"speed":4.6,"deg":270},"sys":{"country":"MY"},"rain":null,"snow":null,"clouds":{"all":75},"weather":[{"id":803,"main":"Clouds","description":"broken clouds","icon":"04d"}]},{"id":1735498,"name":"Tanah Merah","coord":{"lat":5.721,"lon":100.3925},"main":{"temp":305.15,"pressure":1007,"humidity":66,"temp_min":305.15,"temp_max":305.15},"dt":1530781200,"wind":{"speed":6.7,"deg":220},"sys":{"country":"MY"},"rain":null,"snow":null,"clouds":{"all":75},"weather":[{"id":803,"main":"Clouds","description":"broken clouds","icon":"04d"}]}]})
# 94
#
# Serendah
# ?({"message":"accurate","cod":"200","count":1,"list":[{"id":1735148,"name":"Serendah","coord":{"lat":3.3646,"lon":101.6062},"main":{"temp":305.15,"pressure":1007,"humidity":59,"temp_min":305.15,"temp_max":305.15},"dt":1530781200,"wind":{"speed":5.1,"deg":180},"sys":{"country":"MY"},"rain":null,"snow":null,"clouds":{"all":75},"weather":[{"id":803,"main":"Clouds","description":"broken clouds","icon":"04d"}]}]})
# 95
#
# Tampin
# ?({"message":"accurate","cod":"200","count":1,"list":[{"id":1734738,"name":"Tampin","coord":{"lat":2.4672,"lon":102.2358},"main":{"temp":303.98,"pressure":1007,"humidity":59,"temp_min":303.15,"temp_max":305.15},"dt":1530781200,"wind":{"speed":3.6,"deg":140},"sys":{"country":"MY"},"rain":null,"snow":null,"clouds":{"all":75},"weather":[{"id":803,"main":"Clouds","description":"broken clouds","icon":"04d"}]}]})
# 96
#
# Tapah Road
# ?({"message":"accurate","cod":"200","count":1,"list":[{"id":1735282,"name":"Tapah Road","coord":{"lat":4.1697,"lon":101.1965},"main":{"temp":305.63,"pressure":1006,"humidity":52,"temp_min":305.15,"temp_max":306.15},"dt":1530777600,"wind":{"speed":4.6,"deg":200},"sys":{"country":"MY"},"rain":null,"snow":null,"clouds":{"all":75},"weather":[{"id":803,"main":"Clouds","description":"broken clouds","icon":"04d"}]}]})
# 97
#
# Parit Buntar
# ?({"message":"accurate","cod":"200","count":1,"list":[{"id":1735089,"name":"Parit Buntar","coord":{"lat":5.1314,"lon":100.487},"main":{"temp":305.15,"pressure":1007,"humidity":66,"temp_min":305.15,"temp_max":305.15},"dt":1530781200,"wind":{"speed":6.7,"deg":220},"sys":{"country":"MY"},"rain":null,"snow":null,"clouds":{"all":75},"weather":[{"id":803,"main":"Clouds","description":"broken clouds","icon":"04d"}]}]})
# 98
#
# Simanggang
# ?({"message":"accurate","cod":"200","count":1,"list":[{"id":1735799,"name":"Simanggang","coord":{"lat":1.2472,"lon":111.4528},"main":{"temp":302.15,"pressure":1006,"humidity":79,"temp_min":302.15,"temp_max":302.15},"dt":1530781200,"wind":{"speed":1},"sys":{"country":"MY"},"rain":null,"snow":null,"clouds":{"all":75},"weather":[{"id":803,"main":"Clouds","description":"broken clouds","icon":"04d"}]}]})
# 99
#
# Permatang Kuching
# ?({"message":"accurate","cod":"200","count":1,"list":[{"id":1750500,"name":"Permatang Kuching","coord":{"lat":5.4634,"lon":100.3814},"main":{"temp":305.15,"pressure":1007,"humidity":66,"temp_min":305.15,"temp_max":305.15},"dt":1530781200,"wind":{"speed":6.7,"deg":220},"sys":{"country":"MY"},"rain":null,"snow":null,"clouds":{"all":75},"weather":[{"id":803,"main":"Clouds","description":"broken clouds","icon":"04d"}]}]})
# 100
#
# Yong Peng
# ?({"message":"accurate","cod":"200","count":1,"list":[{"id":1732814,"name":"Yong Peng","coord":{"lat":2.0111,"lon":103.0666},"main":{"temp":304.464,"pressure":1017.47,"humidity":69,"temp_min":304.464,"temp_max":304.464,"sea_level":1020.4,"grnd_level":1017.47},"dt":1530782659,"wind":{"speed":5.36,"deg":157},"sys":{"country":"MY"},"rain":null,"snow":null,"clouds":{"all":8},"weather":[{"id":800,"main":"Clear","description":"sky is clear","icon":"02d"}]}]})
# 101
#
# Sungai Besar
# ?({"message":"accurate","cod":"200","count":1,"list":[{"id":1735199,"name":"Sungai Besar","coord":{"lat":3.6774,"lon":100.9864},"main":{"temp":305.15,"pressure":1006,"humidity":62,"temp_min":305.15,"temp_max":305.15},"dt":1530777600,"wind":{"speed":4.6},"sys":{"country":"MY"},"rain":null,"snow":null,"clouds":{"all":75},"weather":[{"id":803,"main":"Clouds","description":"broken clouds","icon":"04d"}]}]})
# 102
#
# Limbang
# ?({"message":"accurate","cod":"200","count":1,"list":[{"id":1737714,"name":"Limbang","coord":{"lat":4.75,"lon":115},"main":{"temp":303.6,"pressure":1007,"humidity":62,"temp_min":303.15,"temp_max":304.15},"dt":1530781200,"wind":{"speed":2.1,"deg":330},"sys":{"country":"MY"},"rain":null,"snow":null,"clouds":{"all":75},"weather":[{"id":803,"main":"Clouds","description":"broken clouds","icon":"04d"}]}]})
# 103
#
# Sungai Udang
# ...
#        'Returned Location': 'Sabak',
#        'Temparature(in celcius)': 32.0,
#        'Time': '17:24:53',
#        'Weather_Condition': 'Clouds',
#        'Weather_Description': 'broken clouds',
#        'Wind_Speed(m/s)': 4.6},
#  135: {'Actual Location': 'Kepala Batas',
#        'Clouds(%)': 75,
#        'Country': 'MY',
#        'Date': '07/05/2018',
#        'Humidity(%)': 66,
#        'Latitude': 5.5147,
#        'Longitude': 100.4285,
#        'Max_temp': 32.0,
#        'Min_temp': 32.0,
#        'Pressure(hpa)': 1007,
#        'Returned Location': 'Kepala Batas',
#        'Temparature(in celcius)': 32.0,
#        'Time': '17:24:54',
#        'Weather_Condition': 'Clouds',
#        'Weather_Description': 'broken clouds',
#        'Wind_Speed(m/s)': 6.7},
#  136: {'Actual Location': 'Kampung Tanjung Karang',
#        'Clouds(%)': 75,
#        'Country': 'MY',
#        'Date': '07/05/2018',
#        'Humidity(%)': 59,
#        'Latitude': 3.4242,
#        'Longitude': 101.1849,
#        'Max_temp': 32.0,
#        'Min_temp': 32.0,
#        'Pressure(hpa)': 1007,
#        'Returned Location': 'Kampung Tanjung Karang',
#        'Temparature(in celcius)': 32.0,
#        'Time': '17:24:55',
#        'Weather_Condition': 'Clouds',
#        'Weather_Description': 'broken clouds',
#        'Wind_Speed(m/s)': 5.1},
#  137: {'Actual Location': 'Pantai Remis',
#        'Clouds(%)': 75,
#        'Country': 'MY',
#        'Date': '07/05/2018',
#        'Humidity(%)': 62,
#        'Latitude': 4.4553,
#        'Longitude': 100.626,
#        'Max_temp': 33.0,
#        'Min_temp': 32.0,
#        'Pressure(hpa)': 1006,
#        'Returned Location': 'Pantai Remis',
#        'Temparature(in celcius)': 32.55,
#        'Time': '17:24:56',
#        'Weather_Condition': 'Clouds',
#        'Weather_Description': 'broken clouds',
#        'Wind_Speed(m/s)': 4.6},
#  138: {'Actual Location': 'Gurun',
#        'Clouds(%)': 75,
#        'Country': 'MY',
#        'Date': '07/05/2018',
#        'Humidity(%)': 66,
#        'Latitude': 5.8178,
#        'Longitude': 100.4759,
#        'Max_temp': 32.0,
#        'Min_temp': 32.0,
#        'Pressure(hpa)': 1007,
#        'Returned Location': 'Gurun',
#        'Temparature(in celcius)': 32.0,
#        'Time': '17:24:57',
#        'Weather_Condition': 'Clouds',
#        'Weather_Description': 'broken clouds',
#        'Wind_Speed(m/s)': 6.7},
#  139: {'Actual Location': 'Beaufort',
#        'Clouds(%)': 75,
#        'Country': 'MY',
#        'Date': '07/05/2018',
#        'Humidity(%)': 70,
#        'Latitude': 5.3583,
#        'Longitude': 115.7564,
#        'Max_temp': 30.0,
#        'Min_temp': 30.0,
#        'Pressure(hpa)': 1007,
#        'Returned Location': 'Beaufort',
#        'Temparature(in celcius)': 30.0,
#        'Time': '17:24:58',
#        'Weather_Condition': 'Clouds',
#        'Weather_Description': 'broken clouds',
#        'Wind_Speed(m/s)': 1.5},
#  140: {'Actual Location': 'Kapit',
#        'Clouds(%)': 76,
#        'Country': 'MY',
#        'Date': '07/05/2018',
#        'Humidity(%)': 73,
#        'Latitude': 2.0165,
#        'Longitude': 112.9399,
#        'Max_temp': 27.91,
#        'Min_temp': 27.91,
#        'Pressure(hpa)': 997.2,
#        'Returned Location': 'Kapit',
#        'Temparature(in celcius)': 27.91,
#        'Time': '17:24:59',
#        'Weather_Condition': 'Clouds',
#        'Weather_Description': 'broken clouds',
#        'Wind_Speed(m/s)': 1.06},
#  141: {'Actual Location': 'Kinarut',
#        'Clouds(%)': 75,
#        'Country': 'MY',
#        'Date': '07/05/2018',
#        'Humidity(%)': 70,
#        'Latitude': 5.8231,
#        'Longitude': 116.0466,
#        'Max_temp': 30.0,
#        'Min_temp': 30.0,
#        'Pressure(hpa)': 1007,
#        'Returned Location': 'Kinarut',
#        'Temparature(in celcius)': 30.0,
#        'Time': '17:25:00',
#        'Weather_Condition': 'Clouds',
#        'Weather_Description': 'broken clouds',
#        'Wind_Speed(m/s)': 3.6},
#  142: {'Actual Location': 'Kampung Ayer Molek',
#        'Clouds(%)': 75,
#        'Country': 'MY',
#        'Date': '07/05/2018',
#        'Humidity(%)': 70,
#        'Latitude': 2.2139,
#        'Longitude': 102.3278,
#        'Max_temp': 30.0,
#        'Min_temp': 30.0,
#        'Pressure(hpa)': 1008,
#        'Returned Location': 'Kampung Ayer Molek',
#        'Temparature(in celcius)': 30.0,
#        'Time': '17:25:01',
#        'Weather_Condition': 'Clouds',
#        'Weather_Description': 'broken clouds',
#        'Wind_Speed(m/s)': 2.1},
#  143: {'Actual Location': 'Kuala Lipis',
#        'Clouds(%)': 20,
#        'Country': 'MY',
#        'Date': '07/05/2018',
#        'Humidity(%)': 99,
#        'Latitude': 4.187,
#        'Longitude': 102.0544,
#        'Max_temp': 26.56,
#        'Min_temp': 26.56,
#        'Pressure(hpa)': 998.58,
#        'Returned Location': 'Kuala Lipis',
#        'Temparature(in celcius)': 26.56,
#        'Time': '17:25:02',
#        'Weather_Condition': 'Rain',
#        'Weather_Description': 'moderate rain',
#        'Wind_Speed(m/s)': 2.21},
#  144: {'Actual Location': 'Pantai Cenang',
#        'Clouds(%)': 75,
#        'Country': 'MY',
#        'Date': '07/05/2018',
#        'Humidity(%)': 83,
#        'Latitude': 6.3,
#        'Longitude': 99.72,
#        'Max_temp': 27,
#        'Min_temp': 27,
#        'Pressure(hpa)': 1007,
#        'Returned Location': 'Chabang Wahid',
#        'Temparature(in celcius)': 27,
#        'Time': '17:25:03',
#        'Weather_Condition': 'Thunderstorm',
#        'Weather_Description': 'thunderstorm with rain',
#        'Wind_Speed(m/s)': 2.1},
#  145: {'Actual Location': 'Bemban',
#        'Clouds(%)': 75,
#        'Country': 'MY',
#        'Date': '07/05/2018',
#        'Humidity(%)': 70,
#        'Latitude': 2.268,
#        'Longitude': 102.3772,
#        'Max_temp': 30.0,
#        'Min_temp': 30.0,
#        'Pressure(hpa)': 1008,
#        'Returned Location': 'Bemban',
#        'Temparature(in celcius)': 30.0,
#        'Time': '17:25:04',
#        'Weather_Condition': 'Clouds',
#        'Weather_Description': 'broken clouds',
#        'Wind_Speed(m/s)': 2.1},
#  146: {'Actual Location': 'Kuala Perlis',
#        'Clouds(%)': 75,
#        'Country': 'MY',
#        'Date': '07/05/2018',
#        'Humidity(%)': 74,
#        'Latitude': 6.4007,
#        'Longitude': 100.1361,
#        'Max_temp': 32.0,
#        'Min_temp': 27.0,
#        'Pressure(hpa)': 1007,
#        'Returned Location': 'Kuala Perlis',
#        'Temparature(in celcius)': 29.31,
#        'Time': '17:25:06',
#        'Weather_Condition': 'Rain',
#        'Weather_Description': 'light rain',
#        'Wind_Speed(m/s)': 3.1},
#  147: {'Actual Location': 'Sungai Pelek New Village',
#        'Clouds(%)': 75,
#        'Country': 'MY',
#        'Date': '07/05/2018',
#        'Humidity(%)': 59,
#        'Latitude': 2.65,
#        'Longitude': 101.7,
#        'Max_temp': 32.0,
#        'Min_temp': 32.0,
#        'Pressure(hpa)': 1007,
#        'Returned Location': 'Sungai Pelek New Village',
#        'Temparature(in celcius)': 32.0,
#        'Time': '17:25:06',
#        'Weather_Condition': 'Clouds',
#        'Weather_Description': 'broken clouds',
#        'Wind_Speed(m/s)': 3.6},
#  148: {'Actual Location': 'Jertih',
#        'Clouds(%)': 75,
#        'Country': 'MY',
#        'Date': '07/05/2018',
#        'Humidity(%)': 70,
#        'Latitude': 5.7377,
#        'Longitude': 102.495,
#        'Max_temp': 32.0,
#        'Min_temp': 32.0,
#        'Pressure(hpa)': 1006,
#        'Returned Location': 'Jertih',
#        'Temparature(in celcius)': 32.0,
#        'Time': '17:25:07',
#        'Weather_Condition': 'Clouds',
#        'Weather_Description': 'broken clouds',
#        'Wind_Speed(m/s)': 3.6},
#  149: {'Actual Location': 'Kelapa Sawit',
#        'Clouds(%)': 75,
#        'Country': 'MY',
#        'Date': '07/05/2018',
#        'Humidity(%)': 70,
#        'Latitude': 1.6803,
#        'Longitude': 103.5253,
#        'Max_temp': 32.0,
#        'Min_temp': 31.0,
#        'Pressure(hpa)': 1007,
#        'Returned Location': 'Kelapa Sawit',
#        'Temparature(in celcius)': 31.25,
#        'Time': '17:25:08',
#        'Weather_Condition': 'Clouds',
#        'Weather_Description': 'broken clouds',
#        'Wind_Speed(m/s)': 3.1},
#  150: {'Actual Location': 'Buloh Kasap',
#        'Clouds(%)': 75,
#        'Country': 'MY',
#        'Date': '07/05/2018',
#        'Humidity(%)': 70,
#        'Latitude': 2.5536,
#        'Longitude': 102.764,
#        'Max_temp': 30.0,
#        'Min_temp': 30.0,
#        'Pressure(hpa)': 1008,
#        'Returned Location': 'Buloh Kasap',
#        'Temparature(in celcius)': 30.0,
#        'Time': '17:25:09',
#        'Weather_Condition': 'Clouds',
#        'Weather_Description': 'broken clouds',
#        'Wind_Speed(m/s)': 2.1},
#  151: {'Actual Location': 'Kota Belud',
#        'Clouds(%)': 75,
#        'Country': 'MY',
#        'Date': '07/05/2018',
#        'Humidity(%)': 70,
#        'Latitude': 6.3498,
#        'Longitude': 116.4293,
#        'Max_temp': 30.0,
#        'Min_temp': 30.0,
#        'Pressure(hpa)': 1007,
#        'Returned Location': 'Kota Belud',
#        'Temparature(in celcius)': 30.0,
#        'Time': '17:25:10',
#        'Weather_Condition': 'Clouds',
#        'Weather_Description': 'broken clouds',
#        'Wind_Speed(m/s)': 3.6},
#  152: {'Actual Location': 'Kampung Bukit Tinggi',
#        'Clouds(%)': 75,
#        'Country': 'MY',
#        'Date': '07/05/2018',
#        'Humidity(%)': 59,
#        'Latitude': 3.35,
#        'Longitude': 101.8167,
#        'Max_temp': 32.0,
#        'Min_temp': 32.0,
#        'Pressure(hpa)': 1007,
#        'Returned Location': 'Kampung Bukit Tinggi',
#        'Temparature(in celcius)': 32.0,
#        'Time': '17:25:11',
#        'Weather_Condition': 'Clouds',
#        'Weather_Description': 'broken clouds',
#        'Wind_Speed(m/s)': 5.1},
#  153: {'Actual Location': 'Tumpat',
#        'Clouds(%)': 75,
#        'Country': 'MY',
#        'Date': '07/05/2018',
#        'Humidity(%)': 70,
#        'Latitude': 6.1984,
#        'Longitude': 102.1682,
#        'Max_temp': 32.0,
#        'Min_temp': 31.0,
#        'Pressure(hpa)': 1006,
#        'Returned Location': 'Tumpat',
#        'Temparature(in celcius)': 31.4,
#        'Time': '17:25:12',
#        'Weather_Condition': 'Rain',
#        'Weather_Description': 'proximity shower rain',
#        'Wind_Speed(m/s)': 3.6},
#  154: {'Actual Location': 'Kuala Sungai Baru',
#        'Clouds(%)': 75,
#        'Country': 'MY',
#        'Date': '07/05/2018',
#        'Humidity(%)': 59,
#        'Latitude': 2.3579,
#        'Longitude': 102.0342,
#        'Max_temp': 32.0,
#        'Min_temp': 30.0,
#        'Pressure(hpa)': 1007,
#        'Returned Location': 'Kuala Sungai Baru',
#        'Temparature(in celcius)': 30.79,
#        'Time': '17:25:13',
#        'Weather_Condition': 'Clouds',
#        'Weather_Description': 'broken clouds',
#        'Wind_Speed(m/s)': 3.6},
#  155: {'Actual Location': 'Juru',
#        'Clouds(%)': 75,
#        'Country': 'MY',
#        'Date': '07/05/2018',
#        'Humidity(%)': 66,
#        'Latitude': 5.3159,
#        'Longitude': 100.4374,
#        'Max_temp': 32.0,
#        'Min_temp': 32.0,
#        'Pressure(hpa)': 1007,
#        'Returned Location': 'Juru',
#        'Temparature(in celcius)': 32.0,
#        'Time': '17:25:16',
#        'Weather_Condition': 'Clouds',
#        'Weather_Description': 'broken clouds',
#        'Wind_Speed(m/s)': 6.7},
#  156: {'Actual Location': 'Pulau Sebang',
#        'Clouds(%)': 75,
#        'Country': 'MY',
#        'Date': '07/05/2018',
#        'Humidity(%)': 59,
#        'Latitude': 2.4438,
#        'Longitude': 102.2306,
#        'Max_temp': 32.0,
#        'Min_temp': 30.0,
#        'Pressure(hpa)': 1007,
#        'Returned Location': 'Pulau Sebang',
#        'Temparature(in celcius)': 30.84,
#        'Time': '17:25:17',
#        'Weather_Condition': 'Clouds',
#        'Weather_Description': 'broken clouds',
#        'Wind_Speed(m/s)': 3.6},
#  157: {'Actual Location': 'Chaah',
#        'Clouds(%)': 24,
#        'Country': 'MY',
#        'Date': '07/05/2018',
#        'Humidity(%)': 59,
#        'Latitude': 2.2457,
#        'Longitude': 103.0416,
#        'Max_temp': 30.81,
#        'Min_temp': 30.81,
#        'Pressure(hpa)': 1006.12,
#        'Returned Location': 'Chaah',
#        'Temparature(in celcius)': 30.81,
#        'Time': '17:25:18',
#        'Weather_Condition': 'Rain',
#        'Weather_Description': 'light rain',
#        'Wind_Speed(m/s)': 2.51},
#  158: {'Actual Location': 'Ayer Hangat',
#        'Clouds(%)': 75,
#        'Country': 'MY',
#        'Date': '07/05/2018',
#        'Humidity(%)': 83,
#        'Latitude': 6.43,
#        'Longitude': 99.81,
#        'Max_temp': 27,
#        'Min_temp': 27,
#        'Pressure(hpa)': 1007,
#        'Returned Location': 'Kuah',
#        'Temparature(in celcius)': 27,
#        'Time': '17:25:19',
#        'Weather_Condition': 'Thunderstorm',
#        'Weather_Description': 'thunderstorm with rain',
#        'Wind_Speed(m/s)': 2.1},
#  159: {'Actual Location': 'Telaga Batu',
#        'Clouds(%)': 75,
#        'Country': 'MY',
#        'Date': '07/05/2018',
#        'Humidity(%)': 66,
#        'Latitude': 5.47,
#        'Longitude': 100.23,
#        'Max_temp': 32,
#        'Min_temp': 32,
#        'Pressure(hpa)': 1007,
#        'Returned Location': 'Tanjung Tokong',
#        'Temparature(in celcius)': 32,
#        'Time': '17:25:20',
#        'Weather_Condition': 'Clouds',
#        'Weather_Description': 'broken clouds',
#        'Wind_Speed(m/s)': 6.7},
#  160: {'Actual Location': 'Padang Mat Sirat',
#        'Clouds(%)': 75,
#        'Country': 'MY',
#        'Date': '07/05/2018',
#        'Humidity(%)': 83,
#        'Latitude': 6.35,
#        'Longitude': 99.73,
#        'Max_temp': 27,
#        'Min_temp': 27,
#        'Pressure(hpa)': 1007,
#        'Returned Location': 'Chabang Wahid',
#        'Temparature(in celcius)': 27,
#        'Time': '17:25:21',
#        'Weather_Condition': 'Thunderstorm',
#        'Weather_Description': 'thunderstorm with rain',
#        'Wind_Speed(m/s)': 2.1},
#  161: {'Actual Location': 'Taman Rajawali',
#        'Clouds(%)': 75,
#        'Country': 'MY',
#        'Date': '07/05/2018',
#        'Humidity(%)': 70,
#        'Latitude': 5.89,
#        'Longitude': 118.04,
#        'Max_temp': 30,
#        'Min_temp': 30,
#        'Pressure(hpa)': 1006,
#        'Returned Location': 'Kampung Pamaguan',
#        'Temparature(in celcius)': 30,
#        'Time': '17:25:23',
#        'Weather_Condition': 'Clouds',
#        'Weather_Description': 'broken clouds',
#        'Wind_Speed(m/s)': 2.1},
#  162: {'Actual Location': 'Tanah Rata',
#        'Clouds(%)': 75,
#        'Country': 'MY',
#        'Date': '07/05/2018',
#        'Humidity(%)': 52,
#        'Latitude': 4.4707,
#        'Longitude': 101.3777,
#        'Max_temp': 33.0,
#        'Min_temp': 33.0,
#        'Pressure(hpa)': 1006,
#        'Returned Location': 'Tanah Rata',
#        'Temparature(in celcius)': 33.0,
#        'Time': '17:25:23',
#        'Weather_Condition': 'Clouds',
#        'Weather_Description': 'broken clouds',
#        'Wind_Speed(m/s)': 4.6}}
# ['GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'RED', 'YELLOW', 'YELLOW', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'RED', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'RED', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'YELLOW', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'YELLOW', 'RED', 'GREEN', 'GREEN', 'GREEN', 'GREEN', 'YELLOW', 'YELLOW', 'GREEN', 'YELLOW', 'YELLOW', 'YELLOW', 'GREEN', 'GREEN', 'GREEN', 'GREEN']

# %%
traffic_label[0]
# Out:
# 'GREEN'

# %%
df = pd.DataFrame.from_dict(info_dict)
df
df = df.T
df['Traffic_status'] = pd.DataFrame(np.array(traffic_label))
df.reindex()
df
df.notnull()
name = str(datetime.today()).split(" ")
date_str = name[0]
time_str = name[1].replace(":",".")
name = date_str+" " + time_str + ".csv"
print(time_str)
df.to_csv(r'G:\\MovingWalls\\weather-traffic\\' + name)
# Out:
#               Actual Location Clouds(%) Country        Date Humidity(%)  \
# 0                      Cheras        75      MY  07/05/2018          59
# 1                    Sandakan        75      MY  07/05/2018          70
# 2                      Kajang        75      MY  07/05/2018          59
# 3                    Seremban        75      MY  07/05/2018          59
# 4                     Kuantan        75      MY  07/05/2018          66
# 5                       Tawau        75      MY  07/05/2018          78
# 6            Kuala Terengganu        75      MY  07/05/2018          66
# 7                        Miri        75      MY  07/05/2018          58
# 8                  Kota Bharu        75      MY  07/05/2018          70
# 9               Selayang Baru        75      MY  07/05/2018          59
# 10                Subang Jaya        75      MY  07/05/2018          59
# 11               Kuala Lumpur        75      MY  07/05/2018          59
# 12                      Klang        75      MY  07/05/2018          59
# 13                Johor Bahru        75      MY  07/05/2018          52
# 14                     Ampang        75      MY  07/05/2018          59
# 15                       Ipoh        75      MY  07/05/2018          52
# 16                  Shah Alam        75      MY  07/05/2018          59
# 17                    Kuching        75      MY  07/05/2018          66
# 18              Petaling Jaya        75      MY  07/05/2018          59
# 19              Kota Kinabalu        75      MY  07/05/2018          70
# 20                George Town        75      MY  07/05/2018          66
# 21            Iskandar Puteri        75      MY  07/05/2018          70
# 22                    Melaka         75      MY  07/05/2018          70
# 23                 Alor Setar        75      MY  07/05/2018          79
# 24                    Bintulu        75      MY  07/05/2018          70
# 25        Kampung Baru Subang        75      MY  07/05/2018          59
# 26                 Kota Bharu        75      MY  07/05/2018          70
# 27              Sungai Petani        75      MY  07/05/2018          66
# 28                    Taiping        75      MY  07/05/2018          52
# 29             Bukit Mertajam        75      MY  07/05/2018          66
# ..                        ...       ...     ...         ...         ...
# 133              Bukit Rambai        75      MY  07/05/2018          70
# 134              Sabak Bernam        75      MY  07/05/2018          62
# 135              Kepala Batas        75      MY  07/05/2018          66
# 136    Kampung Tanjung Karang        75      MY  07/05/2018          59
# 137              Pantai Remis        75      MY  07/05/2018          62
# 138                     Gurun        75      MY  07/05/2018          66
# 139                  Beaufort        75      MY  07/05/2018          70
# 140                     Kapit        76      MY  07/05/2018          73
# 141                   Kinarut        75      MY  07/05/2018          70
# 142        Kampung Ayer Molek        75      MY  07/05/2018          70
# 143               Kuala Lipis        20      MY  07/05/2018          99
# 144             Pantai Cenang        75      MY  07/05/2018          83
# 145                    Bemban        75      MY  07/05/2018          70
# 146              Kuala Perlis        75      MY  07/05/2018          74
# 147  Sungai Pelek New Village        75      MY  07/05/2018          59
# 148                    Jertih        75      MY  07/05/2018          70
# 149              Kelapa Sawit        75      MY  07/05/2018          70
# 150               Buloh Kasap        75      MY  07/05/2018          70
# 151                Kota Belud        75      MY  07/05/2018          70
# 152      Kampung Bukit Tinggi        75      MY  07/05/2018          59
# 153                    Tumpat        75      MY  07/05/2018          70
# 154         Kuala Sungai Baru        75      MY  07/05/2018          59
# 155                      Juru        75      MY  07/05/2018          66
# 156              Pulau Sebang        75      MY  07/05/2018          59
# 157                     Chaah        24      MY  07/05/2018          59
# 158               Ayer Hangat        75      MY  07/05/2018          83
# 159               Telaga Batu        75      MY  07/05/2018          66
# 160          Padang Mat Sirat        75      MY  07/05/2018          83
# 161            Taman Rajawali        75      MY  07/05/2018          70
# 162                Tanah Rata        75      MY  07/05/2018          52
#
#     Latitude Longitude Max_temp Min_temp Pressure(hpa)  \
# 0     3.1072   101.716       32       32          1007
# 1     5.8402   118.118       30       30          1006
# 2       2.99   101.789       32       32          1007
# 3     2.7248   101.934       32       30          1007
# 4     3.8197   103.329       32       32          1007
# 5     4.2635   117.893       28       28          1007
# 6     5.3302   103.141       33       33          1006
# 7     4.4148   114.009       31       31          1006
# 8     6.1256   102.239       32       31          1006
# 9       3.21    101.64       32       32          1007
# 10    3.0568   101.585       32       32          1007
# 11    3.1547   101.714       32       32          1007
# 12    3.0472   101.449       32       32          1007
# 13    1.4953   103.755       32       31          1008
# 14    3.1521   101.732       32       32          1007
# 15     4.592   101.083       33       32          1006
# 16    3.0686   101.518       32       32          1007
# 17    1.5574   110.344       31       31          1007
# 18    3.1056   101.643       32       32          1007
# 19     5.978   116.073       30       30          1007
# 20    5.4166    100.33       32       32          1007
# 21    1.4266    103.64       32       31          1007
# 22     2.196    102.24       30       30          1008
# 23    6.1232   100.368       32       32          1006
# 24    3.1667   113.033       31       31          1007
# 25      3.15   101.533       32       32          1007
# 26    6.1256   102.239       32       31          1006
# 27    5.6439   100.492       32       32          1007
# 28    4.8478   100.737       33       33          1006
# 29    5.3637   100.456       32       32          1007
# ..       ...       ...      ...      ...           ...
# 133   2.2594   102.184       30       30          1008
# 134   3.7675   100.987       32       32          1006
# 135   5.5147   100.428       32       32          1007
# 136   3.4242   101.185       32       32          1007
# 137   4.4553   100.626       33       32          1006
# 138   5.8178   100.476       32       32          1007
# 139   5.3583   115.756       30       30          1007
# 140   2.0165    112.94    27.91    27.91         997.2
# 141   5.8231   116.047       30       30          1007
# 142   2.2139   102.328       30       30          1008
# 143    4.187   102.054    26.56    26.56        998.58
# 144      6.3     99.72       27       27          1007
# 145    2.268   102.377       30       30          1008
# 146   6.4007   100.136       32       27          1007
# 147     2.65     101.7       32       32          1007
# 148   5.7377   102.495       32       32          1006
# 149   1.6803   103.525       32       31          1007
# 150   2.5536   102.764       30       30          1008
# 151   6.3498   116.429       30       30          1007
# 152     3.35   101.817       32       32          1007
# 153   6.1984   102.168       32       31          1006
# 154   2.3579   102.034       32       30          1007
# 155   5.3159   100.437       32       32          1007
# 156   2.4438   102.231       32       30          1007
# 157   2.2457   103.042    30.81    30.81       1006.12
# 158     6.43     99.81       27       27          1007
# 159     5.47    100.23       32       32          1007
# 160     6.35     99.73       27       27          1007
# 161     5.89    118.04       30       30          1006
# 162   4.4707   101.378       33       33          1006
#
#             Returned Location Temparature(in celcius)      Time  \
# 0                      Cheras                      32  17:22:28
# 1                    Sandakan                      30  17:22:30
# 2                      Kajang                      32  17:22:31
# 3                    Seremban                   31.18  17:22:32
# 4                     Kuantan                      32  17:22:33
# 5                       Tawau                      28  17:22:34
# 6            Kuala Terengganu                      33  17:22:35
# 7                        Miri                      31  17:22:36
# 8                  Kota Bharu                   31.36  17:22:37
# 9                      Kepong                      32  17:22:38
# 10                Subang Jaya                      32  17:22:39
# 11               Kuala Lumpur                      32  17:22:40
# 12                      Klang                      32  17:22:41
# 13                Johor Bahru                   31.25  17:22:42
# 14                     Ampang                      32  17:22:43
# 15                       Ipoh                   32.39  17:22:44
# 16                  Shah Alam                      32  17:22:45
# 17                    Kuching                      31  17:22:46
# 18              Petaling Jaya                      32  17:22:47
# 19              Kota Kinabalu                      30  17:22:48
# 20                George Town                      32  17:22:49
# 21            Iskandar Puteri                   31.25  17:22:50
# 22                     Melaka                      30  17:22:51
# 23                 Alor Setar                      32  17:22:52
# 24                    Bintulu                      31  17:22:53
# 25        Kampung Baru Subang                      32  17:22:54
# 26                 Kota Bharu                   31.36  17:22:55
# 27              Sungai Petani                      32  17:22:56
# 28                    Taiping                      33  17:22:57
# 29             Bukit Mertajam                      32  17:22:58
# ..                        ...                     ...       ...
# 133              Bukit Rambai                      30  17:24:52
# 134                     Sabak                      32  17:24:53
# 135              Kepala Batas                      32  17:24:54
# 136    Kampung Tanjung Karang                      32  17:24:55
# 137              Pantai Remis                   32.55  17:24:56
# 138                     Gurun                      32  17:24:57
# 139                  Beaufort                      30  17:24:58
# 140                     Kapit                   27.91  17:24:59
# 141                   Kinarut                      30  17:25:00
# 142        Kampung Ayer Molek                      30  17:25:01
# 143               Kuala Lipis                   26.56  17:25:02
# 144             Chabang Wahid                      27  17:25:03
# 145                    Bemban                      30  17:25:04
# 146              Kuala Perlis                   29.31  17:25:06
# 147  Sungai Pelek New Village                      32  17:25:06
# 148                    Jertih                      32  17:25:07
# 149              Kelapa Sawit                   31.25  17:25:08
# 150               Buloh Kasap                      30  17:25:09
# 151                Kota Belud                      30  17:25:10
# 152      Kampung Bukit Tinggi                      32  17:25:11
# 153                    Tumpat                    31.4  17:25:12
# 154         Kuala Sungai Baru                   30.79  17:25:13
# 155                      Juru                      32  17:25:16
# 156              Pulau Sebang                   30.84  17:25:17
# 157                     Chaah                   30.81  17:25:18
# 158                      Kuah                      27  17:25:19
# 159            Tanjung Tokong                      32  17:25:20
# 160             Chabang Wahid                      27  17:25:21
# 161          Kampung Pamaguan                      30  17:25:23
# 162                Tanah Rata                      33  17:25:23
#
#     Weather_Condition     Weather_Description Wind_Speed(m/s) Traffic_status
# 0              Clouds           broken clouds             5.1          GREEN
# 1              Clouds           broken clouds             2.1          GREEN
# 2              Clouds           broken clouds             3.6          GREEN
# 3              Clouds           broken clouds             3.6         YELLOW
# 4              Clouds           broken clouds             2.6         YELLOW
# 5                Rain   proximity shower rain             2.6         YELLOW
# 6              Clouds           broken clouds             2.1          GREEN
# 7              Clouds           broken clouds             2.1         YELLOW
# 8                Rain   proximity shower rain             3.6         YELLOW
# 9              Clouds           broken clouds             5.1          GREEN
# 10             Clouds           broken clouds             5.1         YELLOW
# 11             Clouds           broken clouds             5.1            RED
# 12             Clouds           broken clouds             5.1         YELLOW
# 13             Clouds           broken clouds             4.6         YELLOW
# 14             Clouds           broken clouds             5.1         YELLOW
# 15             Clouds           broken clouds             4.6         YELLOW
# 16             Clouds           broken clouds             5.1         YELLOW
# 17             Clouds           broken clouds             2.6          GREEN
# 18             Clouds           broken clouds             5.1         YELLOW
# 19             Clouds           broken clouds             3.6         YELLOW
# 20             Clouds           broken clouds             6.7         YELLOW
# 21             Clouds           broken clouds             3.1            RED
# 22             Clouds           broken clouds             2.1          GREEN
# 23             Clouds           broken clouds             4.6          GREEN
# 24             Clouds           broken clouds             2.6          GREEN
# 25             Clouds           broken clouds             5.1         YELLOW
# 26               Rain   proximity shower rain             3.6          GREEN
# 27             Clouds           broken clouds             6.7          GREEN
# 28             Clouds           broken clouds             4.6          GREEN
# 29             Clouds           broken clouds             6.7          GREEN
# ..                ...                     ...             ...            ...
# 133            Clouds           broken clouds             2.1          GREEN
# 134            Clouds           broken clouds             4.6          GREEN
# 135            Clouds           broken clouds             6.7          GREEN
# 136            Clouds           broken clouds             5.1          GREEN
# 137            Clouds           broken clouds             4.6          GREEN
# 138            Clouds           broken clouds             6.7         YELLOW
# 139            Clouds           broken clouds             1.5         YELLOW
# 140            Clouds           broken clouds            1.06         YELLOW
# 141            Clouds           broken clouds             3.6         YELLOW
# 142            Clouds           broken clouds             2.1         YELLOW
# 143              Rain           moderate rain            2.21         YELLOW
# 144      Thunderstorm  thunderstorm with rain             2.1         YELLOW
# 145            Clouds           broken clouds             2.1          GREEN
# 146              Rain              light rain             3.1         YELLOW
# 147            Clouds           broken clouds             3.6         YELLOW
# 148            Clouds           broken clouds             3.6            RED
# 149            Clouds           broken clouds             3.1          GREEN
# 150            Clouds           broken clouds             2.1          GREEN
# 151            Clouds           broken clouds             3.6          GREEN
# 152            Clouds           broken clouds             5.1          GREEN
# 153              Rain   proximity shower rain             3.6         YELLOW
# 154            Clouds           broken clouds             3.6         YELLOW
# 155            Clouds           broken clouds             6.7          GREEN
# 156            Clouds           broken clouds             3.6         YELLOW
# 157              Rain              light rain            2.51         YELLOW
# 158      Thunderstorm  thunderstorm with rain             2.1         YELLOW
# 159            Clouds           broken clouds             6.7          GREEN
# 160      Thunderstorm  thunderstorm with rain             2.1          GREEN
# 161            Clouds           broken clouds             2.1          GREEN
# 162            Clouds           broken clouds             4.6          GREEN
#
# [163 rows x 17 columns]

# %% [markdown]
#  #### Testing the google distance matrix api to find out about the traffic

# %%
origins = ['Vancouver, BC', 'Seattle']
pay = {'origins' : '|'.join(origins)}
print(pay["origins"])
# Out:
# Vancouver, BC|Seattle

# %%
# Google Distance Matrix base URL to which all other parameters are attached
base_url = 'https://maps.googleapis.com/maps/api/distancematrix/json?'

# Google Distance Matrix domain-specific terms: origins and destinations
origins = ['Vancouver, BC', 'Seattle']
destinations = ['San Francisco', 'Victoria, BC']

# Prepare the request details for the assembly into a request URL
payload = {
            'origins'       :  '|'.join(origins),
            'destinations'  :  '|'.join(destinations), 
            'mode'          :  'driving',
            'departure_time':  'now',
            'key'           :  'AIzaSyDisMSJlHVoeHyK_h7eo8A2sqdaHk33Pcs'
           }
# Assemble the URL and query the web service
data = requests.get(base_url, params = payload).text
#print(data)
#data = data.strip("?()")
data=json.loads(data)
pprint.pprint(data)
pprint.pprint(data['rows'])
# Out:
# {'destination_addresses': ['San Francisco, CA, USA', 'Victoria, BC, Canada'],
#  'origin_addresses': ['Vancouver, BC, Canada', 'Seattle, WA, USA'],
#  'rows': [{'elements': [{'distance': {'text': '1,527 km', 'value': 1527123},
#                          'duration': {'text': '15 hours 3 mins',
#                                       'value': 54150},
#                          'duration_in_traffic': {'text': '15 hours 34 mins',
#                                                  'value': 56043},
#                          'status': 'OK'},
#                         {'distance': {'text': '114 km', 'value': 114179},
#                          'duration': {'text': '3 hours 13 mins',
#                                       'value': 11578},
#                          'duration_in_traffic': {'text': '2 hours 59 mins',
#                                                  'value': 10745},
#                          'status': 'OK'}]},
#           {'elements': [{'distance': {'text': '1,299 km', 'value': 1298736},
#                          'duration': {'text': '12 hours 36 mins',
#                                       'value': 45333},
#                          'duration_in_traffic': {'text': '12 hours 47 mins',
#                                                  'value': 46011},
#                          'status': 'OK'},
#                         {'distance': {'text': '172 km', 'value': 171959},
#                          'duration': {'text': '4 hours 41 mins',
#                                       'value': 16843},
#                          'duration_in_traffic': {'text': '4 hours 33 mins',
#                                                  'value': 16374},
#                          'status': 'OK'}]}],
#  'status': 'OK'}
# [{'elements': [{'distance': {'text': '1,527 km', 'value': 1527123},
#                 'duration': {'text': '15 hours 3 mins', 'value': 54150},
#                 'duration_in_traffic': {'text': '15 hours 34 mins',
#                                         'value': 56043},
#                 'status': 'OK'},
#                {'distance': {'text': '114 km', 'value': 114179},
#                 'duration': {'text': '3 hours 13 mins', 'value': 11578},
#                 'duration_in_traffic': {'text': '2 hours 59 mins',
#                                         'value': 10745},
#                 'status': 'OK'}]},
#  {'elements': [{'distance': {'text': '1,299 km', 'value': 1298736},
#                 'duration': {'text': '12 hours 36 mins', 'value': 45333},
#                 'duration_in_traffic': {'text': '12 hours 47 mins',
#                                         'value': 46011},
#                 'status': 'OK'},
#                {'distance': {'text': '172 km', 'value': 171959},
#                 'duration': {'text': '4 hours 41 mins', 'value': 16843},
#                 'duration_in_traffic': {'text': '4 hours 33 mins',
#                                         'value': 16374},
#                 'status': 'OK'}]}]

# %%
# Google Distance Matrix base URL to which all other parameters are attached
base_url = 'https://maps.googleapis.com/maps/api/distancematrix/json?'

# Google Distance Matrix domain-specific terms: origins and destinations
origins = ['3.1390,101.6869']
destinations = ['2.9213,101.6559']

# Prepare the request details for the assembly into a request URL
payload = {
            'origins'       :  '|'.join(origins),
            'destinations'  :  '|'.join(destinations), 
            'departure_time':  'now',
            'key'       :  'AIzaSyDisMSJlHVoeHyK_h7eo8A2sqdaHk33Pcs'
           }
# Assemble the URL and query the web service
r = requests.get(base_url, params = payload).text

print(r)
# Out:
# {
#    "destination_addresses" : [ "San Francisco, CA, USA", "Victoria, BC, Canada" ],
#    "origin_addresses" : [ "Vancouver, BC, Canada", "Seattle, WA, USA" ],
#    "rows" : [
#       {
#          "elements" : [
#             {
#                "distance" : {
#                   "text" : "1,527 km",
#                   "value" : 1527123
#                },
#                "duration" : {
#                   "text" : "15 hours 3 mins",
#                   "value" : 54150
#                },
#                "duration_in_traffic" : {
#                   "text" : "15 hours 33 mins",
#                   "value" : 55985
#                },
#                "status" : "OK"
#             },
#             {
#                "distance" : {
#                   "text" : "114 km",
#                   "value" : 114179
#                },
#                "duration" : {
#                   "text" : "3 hours 13 mins",
#                   "value" : 11578
#                },
#                "duration_in_traffic" : {
#                   "text" : "2 hours 59 mins",
#                   "value" : 10734
#                },
#                "status" : "OK"
#             }
#          ]
#       },
#       {
#          "elements" : [
#             {
#                "distance" : {
#                   "text" : "1,299 km",
#                   "value" : 1298736
#                },
#                "duration" : {
#                   "text" : "12 hours 36 mins",
#                   "value" : 45333
#                },
#                "duration_in_traffic" : {
#                   "text" : "12 hours 47 mins",
#                   "value" : 46035
#                },
#                "status" : "OK"
#             },
#             {
#                "distance" : {
#                   "text" : "172 km",
#                   "value" : 171959
#                },
#                "duration" : {
#                   "text" : "4 hours 41 mins",
#                   "value" : 16843
#                },
#                "duration_in_traffic" : {
#                   "text" : "4 hours 33 mins",
#                   "value" : 16370
#                },
#                "status" : "OK"
#             }
#          ]
#       }
#    ],
#    "status" : "OK"
# }

# %%
# the co ordinates to find out the traffic 
road = pd.read_csv(r"G:\MovingWalls\weather-traffic\with road co ordinates.csv")
road 
#originList = road["From"].values.tolist()
#destList = road["to"].values.tolist()
#print(len(roadList))
#print(str(locationList[0]).strip('[]\''))

#print(destlist)
# Out:
# ['3.107233, 101.716458', '5.840197, 118.117920', '2.990069, 101.788762', '2.723786, 101.933958', '3.819618, 103.329201', '4.263603, 117.892869', '5.330140, 103.140778', '4.414901, 114.009036', '6.125749, 102.239295', '3.210444, 101.640261', '3.056805, 101.585511', '3.153324, 101.711964', '3.047248, 101.448889', '1.495052, 103.755302', '3.151470, 101.733344', '4.591851, 101.083270', '3.068606, 101.518284', '1.557182, 110.344245', '3.105812, 101.642622', '5.977959, 116.072507', '5.416681, 100.330443', '1.426551, 103.640294', '2.195847, 102.240624', '6.122890, 100.368210', '3.165693, 113.032241', '3.149915, 101.533260', '6.125754, 102.239283', '5.643556, 100.491401', '4.847768, 100.737241', '5.363856, 100.455984', '2.692302, 101.750482', '2.290739, 111.826211', '5.370810, 100.554666', '2.035350, 103.320477', '1.546578, 103.658887', '1.849845, 102.936100', '1.472289, 103.878002', '5.326978, 100.273491', '5.479609, 100.498230', '2.042979, 102.566682', '3.320358, 101.576594', '5.395304, 100.374842', '5.021606, 118.327585', '2.948370, 101.842916', '2.522727, 101.794313', '4.250039, 103.416719', '5.883223, 116.050136', '5.328724, 116.155346', '1.604337, 103.823814', '5.276699, 115.241726', '1.600549, 103.641700', '5.906962, 116.101450', '2.506608, 102.815329', '3.033317, 101.750087', '5.377159, 100.383199', '6.438911, 100.194493', '1.656816, 103.605962', '6.268484, 100.416835', '4.023588, 101.026412', '4.480221, 118.611795', '2.995729, 101.566936', '3.450678, 102.417329', '3.217171, 101.316714', '2.436276, 102.184474', '3.340646, 101.249437', '2.215250, 102.284654', '5.289057, 115.268602', '1.733122, 103.901405', '1.486585, 103.389591', '2.906504, 101.676311', '3.516580, 101.900199', '2.816946, 101.499740', '5.727557, 100.509467', '4.470656, 101.036626', '3.485599, 102.348476', '5.169676, 100.477756', '3.791184, 101.853136', '5.915977, 102.216164', '4.232365, 100.630083', '4.772287, 100.940623', '2.218600, 102.199507', '2.265568, 102.279923', '2.803095, 101.797058', '2.267097, 102.540108', '3.936405, 102.366430', '6.889771, 116.842980', '3.490124, 103.393668', '2.808714, 102.395866', '2.050002, 102.666681', '6.326540, 99.843188', '4.116704, 101.283299', '2.129727, 111.523015', '2.349782, 102.116615', '5.720925, 100.392355', '3.365829, 101.606017', '2.467446, 102.235623', '4.170972, 101.198364', '5.131610, 100.487127', '1.247449, 111.452929', '5.463322, 100.381631', '2.010925, 103.066578', '3.677267, 100.986555', '4.745662, 115.002094', '2.312526, 102.129398', '2.247251, 102.246996', '2.884922, 101.501998', '4.514281, 103.448053', '5.446088, 100.305227', '3.285187, 101.518801', '1.509628, 103.513954', '5.987910, 102.295891', '3.310410, 101.490400', '2.659868, 101.562913', '2.428001, 103.835771', '2.383665, 103.020858', '5.205645, 103.205920', '3.255031, 101.553143', '4.637460, 103.436967', '5.011789, 100.527438', '2.382980, 102.209118', '3.382511, 101.417804', '3.002473, 101.396872', '5.469012, 100.250849', '4.879442, 101.965285', '2.742085, 102.249902', '5.951147, 116.666719', '5.733561, 115.931669', '6.000013, 102.250164', '6.107226, 100.293738', '4.307517, 101.150768', '6.049575, 102.139858', '1.827911, 103.299674', '1.867941, 103.112151', '2.259604, 102.183544', '3.767268, 100.987114', '5.514841, 100.427839', '3.424004, 101.185194', '4.455123, 100.625861', '5.817722, 100.475383', '5.353116, 115.747276', '2.016501, 112.939911', '5.823315, 116.046589', '2.213799, 102.327713', '4.186968, 102.054190', '6.299980, 99.719984', '2.267918, 102.377053', '6.400730, 100.136239', '2.648924, 101.700947', '5.737711, 102.495043', '1.679451, 103.524935', '2.553632, 102.763942', '6.349722, 116.429299', '3.350166, 101.816752', '6.198534, 102.167566', '2.359154, 102.034684', '5.315817, 100.437417', '2.445639, 102.230638', '2.245753, 103.041140', '6.430658, 99.809155', '5.464554, 100.229605', '6.350010, 99.729996', '5.890725, 118.040887', '4.470504, 101.377731']

# %%
originList = ['3.105768, 101.715448', '5.839319, 118.116308', '2.991559, 101.787757', '2.724119, 101.932328', 
              '3.820882, 103.329190', '4.262185, 117.892673', '5.329034, 103.141363', '4.413783, 114.008027', 
              '6.125200, 102.240797', '3.208642, 101.640314', '3.056805, 101.583711', '3.154792, 101.710993', 
              '3.045467, 101.448585', '1.493519, 103.756294', '3.150286, 101.734089', '4.590321, 101.083404', 
              '3.069259, 101.517040', '1.558780, 110.345125', '3.105978, 101.644349', '5.979613, 116.073387', 
              '5.415615, 100.329268', '1.427055, 103.638804', '2.197080, 102.240415', '6.124170, 100.368033', 
              '3.166936, 113.030943', '3.149877, 101.535095', '6.125664, 102.238602', '5.644827, 100.491015', 
              '4.846619, 100.735841', '5.364246, 100.457759', '2.693213, 101.750353', '2.291600, 111.826412', 
              '5.370844, 100.553354', '2.035854, 103.321936', '1.545747, 103.660014', '1.849186, 102.937706', 
              '1.473463, 103.878967', '5.327720, 100.274414', '5.480420, 100.496637', '2.041929, 102.567964', 
              '3.321799, 101.576658', '5.394542, 100.373809', '5.020933, 118.326201', '2.950101, 101.842300', 
              '2.521226, 101.795273', '4.248530, 103.415624', '5.884386, 116.051037', '5.330091, 116.154413', 
              '1.604713, 103.821915', '5.277049, 115.242968', '1.600956, 103.640193', '5.908712, 116.101375', 
              '2.506640, 102.816490', '3.031533, 101.750393', '5.378693, 100.384053', '6.439258, 100.193265', 
              '1.655428, 103.606523', '6.267962, 100.418278', '4.022212, 101.026240', '4.479857, 118.611296', 
              '2.994738, 101.567746', '3.449655, 102.417469', '3.217083, 101.318535', '2.434517, 102.184780', 
              '3.339628, 101.249979', '2.216515, 102.284461', '5.290254, 115.267293', '1.731315, 103.901311', 
              '1.487496, 103.390578', '2.905137, 101.677160', '3.517828, 101.900402', '2.815510, 101.498527', 
              '5.726142, 100.510261', '4.472287, 101.037404', '3.484737, 102.350037', '5.171337, 100.477869', 
              '3.789439, 101.853587', '5.916335, 102.214399', '4.233735, 100.630448', '4.772207, 100.941900', 
              '2.218638, 102.198091', '2.266487, 102.281450', '2.801681, 101.796630', '2.268538, 102.540899', 
              '3.936554, 102.366655', '6.889470, 116.844672', '3.490114, 103.392606', '2.809882, 102.396563', 
              '2.051782, 102.666923', '6.325826, 99.844969', '4.115975, 101.282106', '2.130260, 111.524742', 
              '2.349884, 102.114899', '5.722118, 100.392378', '3.366510, 101.607005', '2.468052, 102.237294', 
              '4.172406, 101.197345', '5.130701, 100.488694', '1.246521, 111.454469', '5.462308, 100.382634', 
              '2.010742, 103.068337', '3.675912, 100.985425', '4.744346, 115.001928', '2.314298, 102.129679', 
              '2.245939, 102.248217', '2.883486, 101.503113', '4.512914, 103.446911', '5.447879, 100.305399', 
              '3.285342, 101.517530', '1.509135, 103.515767', '5.987414, 102.297651', '3.312107, 101.489875', 
              '2.659804, 101.564215', '2.426912, 103.834955', '2.385201, 103.021745', '5.206948, 103.205309', 
              '3.255824, 101.554280', '4.636765, 103.436538', '5.013243, 100.527234', '2.384545, 102.208206', 
              '3.382195, 101.419005', '3.003397, 101.395786', '5.470518, 100.249889', '4.880789, 101.964089', 
              '2.741951, 102.248646', '5.951456, 116.667792', '5.733695, 115.932742', '6.001634, 102.250963', 
              '6.106487, 100.294694', '4.308041, 101.149435', '6.049664, 102.141408', '1.827739, 103.298295', 
              '1.869368, 103.111003', '2.260183, 102.184348', '3.765769, 100.988252', '5.513266, 100.427297', 
              '3.425487, 101.186208', '4.456181, 100.626612', '5.816438, 100.474814', '5.353378, 115.745855', 
              '2.016907, 112.941330', '5.823094, 116.048297', '2.215134, 102.327890', '4.185383, 102.054926', 
              '6.299373, 99.721247', '2.269397, 102.376291', '6.402020, 100.136695', '2.650076, 101.702299', 
              '5.738042, 102.496706', '1.680095, 103.523240', '2.553305, 102.765363', '6.350239, 116.430836', 
              '3.349938, 101.818581', '6.197883, 102.166558', '2.358425, 102.036015', '5.315906, 100.439280', 
              '2.446942, 102.230118', '2.246170, 103.042407', '6.428995, 99.808533', '5.463150, 100.230763', 
              '6.349125, 99.731225', '5.889285, 118.041997', '4.471204, 101.379313']

destList = ['3.107233, 101.716458', '5.840197, 118.117920', '2.990069, 101.788762', '2.723786, 101.933958', 
            '3.819618, 103.329201', '4.263603, 117.892869', '5.330140, 103.140778', '4.414901, 114.009036', 
            '6.125749, 102.239295', '3.210444, 101.640261', '3.056805, 101.585511', '3.153324, 101.711964', 
            '3.047248, 101.448889', '1.495052, 103.755302', '3.151470, 101.733344', '4.591851, 101.083270', 
            '3.068606, 101.518284', '1.557182, 110.344245', '3.105812, 101.642622', '5.977959, 116.072507', 
            '5.416681, 100.330443', '1.426551, 103.640294', '2.195847, 102.240624', '6.122890, 100.368210', 
            '3.165693, 113.032241', '3.149915, 101.533260', '6.125754, 102.239283', '5.643556, 100.491401', 
            '4.847768, 100.737241', '5.363856, 100.455984', '2.692302, 101.750482', '2.290739, 111.826211', 
            '5.370810, 100.554666', '2.035350, 103.320477', '1.546578, 103.658887', '1.849845, 102.936100', 
            '1.472289, 103.878002', '5.326978, 100.273491', '5.479609, 100.498230', '2.042979, 102.566682', 
            '3.320358, 101.576594', '5.395304, 100.374842', '5.021606, 118.327585', '2.948370, 101.842916', 
            '2.522727, 101.794313', '4.250039, 103.416719', '5.883223, 116.050136', '5.328724, 116.155346', 
            '1.604337, 103.823814', '5.276699, 115.241726', '1.600549, 103.641700', '5.906962, 116.101450', 
            '2.506608, 102.815329', '3.033317, 101.750087', '5.377159, 100.383199', '6.438911, 100.194493', 
            '1.656816, 103.605962', '6.268484, 100.416835', '4.023588, 101.026412', '4.480221, 118.611795', 
            '2.995729, 101.566936', '3.450678, 102.417329', '3.217171, 101.316714', '2.436276, 102.184474', 
            '3.340646, 101.249437', '2.215250, 102.284654', '5.289057, 115.268602', '1.733122, 103.901405', 
            '1.486585, 103.389591', '2.906504, 101.676311', '3.516580, 101.900199', '2.816946, 101.499740', 
            '5.727557, 100.509467', '4.470656, 101.036626', '3.485599, 102.348476', '5.169676, 100.477756', 
            '3.791184, 101.853136', '5.915977, 102.216164', '4.232365, 100.630083', '4.772287, 100.940623', 
            '2.218600, 102.199507', '2.265568, 102.279923', '2.803095, 101.797058', '2.267097, 102.540108', 
            '3.936405, 102.366430', '6.889771, 116.842980', '3.490124, 103.393668', '2.808714, 102.395866', 
            '2.050002, 102.666681', '6.326540, 99.843188', '4.116704, 101.283299', '2.129727, 111.523015', 
            '2.349782, 102.116615', '5.720925, 100.392355', '3.365829, 101.606017', '2.467446, 102.235623', 
            '4.170972, 101.198364', '5.131610, 100.487127', '1.247449, 111.452929', '5.463322, 100.381631', 
            '2.010925, 103.066578', '3.677267, 100.986555', '4.745662, 115.002094', '2.312526, 102.129398', 
            '2.247251, 102.246996', '2.884922, 101.501998', '4.514281, 103.448053', '5.446088, 100.305227', 
            '3.285187, 101.518801', '1.509628, 103.513954', '5.987910, 102.295891', '3.310410, 101.490400', 
            '2.659868, 101.562913', '2.428001, 103.835771', '2.383665, 103.020858', '5.205645, 103.205920', 
            '3.255031, 101.553143', '4.637460, 103.436967', '5.011789, 100.527438', '2.382980, 102.209118', 
            '3.382511, 101.417804', '3.002473, 101.396872', '5.469012, 100.250849', '4.879442, 101.965285', 
            '2.742085, 102.249902', '5.951147, 116.666719', '5.733561, 115.931669', '6.000013, 102.250164', 
            '6.107226, 100.293738', '4.307517, 101.150768', '6.049575, 102.139858', '1.827911, 103.299674', 
            '1.867941, 103.112151', '2.259604, 102.183544', '3.767268, 100.987114', '5.514841, 100.427839', 
            '3.424004, 101.185194', '4.455123, 100.625861', '5.817722, 100.475383', '5.353116, 115.747276', 
            '2.016501, 112.939911', '5.823315, 116.046589', '2.213799, 102.327713', '4.186968, 102.054190', 
            '6.299980, 99.719984', '2.267918, 102.377053', '6.400730, 100.136239', '2.648924, 101.700947', 
            '5.737711, 102.495043', '1.679451, 103.524935', '2.553632, 102.763942', '6.349722, 116.429299', 
            '3.350166, 101.816752', '6.198534, 102.167566', '2.359154, 102.034684', '5.315817, 100.437417', 
            '2.445639, 102.230638', '2.245753, 103.041140', '6.430658, 99.809155', '5.464554, 100.229605', 
            '6.350010, 99.729996', '5.890725, 118.040887', '4.470504, 101.377731']
print(len(destList))
# Out:
# 163
