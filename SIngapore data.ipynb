# %%
import numpy as np
import pandas as pd

# %%
sing = pd.read_csv(r'G:\MovingWalls\singapore.csv')
sing.head()
# Out:
#                    Name          Display Name               Ref ID  \
# 0      Grand Indonesia       Grand Indonesia                   NaN
# 1           DTCP05789-P           DTCP05789-P  TH-THR-10120-D-0001
# 2       WOW Subang SS15       WOW Subang SS15  MY-WOW-47500-D-0037
# 3             Media Uno             Media Uno  MY-MED-47800-D-0025
# 4  WOW Taman Sri Rampai  WOW Taman Sri Rampai  MY-WOW-53300-D-0036
#
#                           Media Operator Facing Direction Category Format  \
# 0                    Movingwalls Sdn Bhd            SOUTH   INDOOR    NaN
# 1  ThreeSixtyFive Public Company Limited       NORTH-WEST   INDOOR    NaN
# 2                    WOW OUTDOOR SDN BHD            NORTH  OUTDOOR  LARGE
# 3                      Media Uno Sdn Bhd       NORTH-EAST  OUTDOOR    NaN
# 4                    WOW OUTDOOR SDN BHD             EAST  OUTDOOR  LARGE
#
#   Group             Type                                     Market Segment  \
# ...

# %%
sing.Country
# Out:
# 0                  NaN
# 1             Thailand
# 2             Malaysia
# 3             Malaysia
# 4             Malaysia
# 5             Malaysia
# 6             Malaysia
# 7             Malaysia
# 8             Malaysia
# 9             Malaysia
# 10            Malaysia
# 11           Singapore
# 12           Singapore
# 13           Singapore
# 14           Singapore
# 15           Singapore
# 16           Singapore
# 17            Malaysia
# 18           Singapore
# 19            Malaysia
# 20            Malaysia
# 21            Malaysia
# 22            Malaysia
# 23            Malaysia
# 24            Malaysia
# 25            Malaysia
# 26            Malaysia
# 27            Malaysia
# 28            Malaysia
# 29            Malaysia
#              ...
# 4096         Indonesia
# 4097         Indonesia
# 4098         Indonesia
# 4099          Malaysia
# 4100          Malaysia
# 4101          Malaysia
# 4102          Malaysia
# 4103          Malaysia
# 4104          Malaysia
# ...

# %%
big = sing[sing["Country"]=="Singapore"]
big.head()
big = big.reset_index()
big.head()
big.columns
big["Ref ID"].unique
big[big["Name"]=="City House"]
# Out:
#      index        Name Display Name                Ref ID Media Operator  \
# 691   3932  City House   City House  SG-FOC-068877-D-0007    Focus Media
#
#     Facing Direction Category Format Group     Type    ...    Video Support  \
# 691            NORTH   INDOOR    NaN  WORK  DIGITAL    ...              NaN
#
#      Image Support  Audio Support Content Approval Feature Support  \
# 691            NaN            NaN              NaN             NaN
#
#     Available Hours Lead Time (in days) Any Exclusion  \
# 691             NaN                 NaN           NaN
#
#                               Address  MI Stage
# 691  36 Robinson Rd, Singapore 068877       New
#
# [1 rows x 43 columns]

# %%
big[big["Name"]=="KINGSMEN-  POMO"]
# Out:
#      index             Name Display Name                Ref ID  \
# 209   3173  KINGSMEN-  POMO     POMO OOH  SG-KIN-188666-D-0001
#
#                  Media Operator Facing Direction Category  Format  Group  \
# 209  Kingsmen Ooh Media Pte Ltd            NORTH  OUTDOOR  MEDIUM  STUDY
#
#         Type    ...                       Video Support  \
# 209  DIGITAL    ...     mp4,avi,mov,mpg,wmv,vob,fla,swf
#
#              Image Support  Audio Support Content Approval Feature Support  \
# 209  jpg,jpeg,png,tiff,gif             NO              YES     IMAGE,VIDEO
#
#     Available Hours Lead Time (in days) Any Exclusion  \
# 209           15:00                 5.0           NaN
#
#                                Address  MI Stage
# 209  19 Kirk Terrace, Singapore 228835       New
#
# [1 rows x 43 columns]

# %%
trik = big.loc[:,['Ref ID','Latitude', 'Longitude','Name','Postal Code','Address']]
trik.head()
trik.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 695 entries, 0 to 694
# Data columns (total 6 columns):
# Ref ID         695 non-null object
# Latitude       695 non-null float64
# Longitude      695 non-null float64
# Name           695 non-null object
# Postal Code    681 non-null object
# Address        605 non-null object
# dtypes: float64(2), object(4)
# memory usage: 32.7+ KB

# %%
trik.to_csv(r'G:\MovingWalls\SingaporeSubzones.csv', index=None)
