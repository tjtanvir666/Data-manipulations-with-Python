# %%
import numpy as np
import pandas as pd

# %%
name = "2018-05-31.csv"
df_1 = pd.read_csv(r"G:\\MovingWalls\\GAP ESTIMATION\\2.shell_traffic_20180611\\Result\\Jalan Tun Sambanthan 1\\" + name)
df_2 = pd.read_csv(r"G:\\MovingWalls\\GAP ESTIMATION\\2.shell_traffic_20180611\\Result\\Jalan Tun Sambanthan 2\\" + name)
df_3 = pd.read_csv(r"G:\\MovingWalls\\GAP ESTIMATION\\2.shell_traffic_20180611\\Result\\Jalan Tun Sambanthan 3\\" + name)

# %%
df_1.head()
df_2.head()
df_3.head()
# Out:
#              Date_Time  Cars_per_hour
# 0  2018-05-31 00:00:50            138
# 1  2018-05-31 01:00:33             48
# 2  2018-05-31 02:00:34            150
# 3  2018-05-31 03:00:34              3
# 4  2018-05-31 04:00:39              3

# %%
df_1["Total_cars"]= df_1.Cars_per_hour + df_2.Cars_per_hour + df_3.Cars_per_hour

# %%
df_1.head()
# Out:
#              Date_Time  Cars_per_hour  Total_cars
# 0  2018-05-31 00:00:50              4         146
# 1  2018-05-31 01:00:33              4          55
# 2  2018-05-31 02:00:35              5         159
# 3  2018-05-31 03:00:35              4          11
# 4  2018-05-31 04:00:40              4          11

# %%
final = df_1.drop(["Cars_per_hour"], axis = 1)

# %%
final.head()
# Out:
#              Date_Time  Total_cars
# 0  2018-05-31 00:00:50         146
# 1  2018-05-31 01:00:33          55
# 2  2018-05-31 02:00:35         159
# 3  2018-05-31 03:00:35          11
# 4  2018-05-31 04:00:40          11

# %%
final.to_csv(r"G:\\MovingWalls\\GAP ESTIMATION\\2.shell_traffic_20180611\\Result\\Jalan Tun Sambanthan total\\" + name, index = None)

# %%
sing = pd.read_csv(r'G:\MovingWalls\singapore.csv')
sing.head()
# Out:
#                    Name          Display Name               Ref ID  \
# 0      Grand Indonesia       Grand Indonesia                   NaN
# 1           DTCP05789-P           DTCP05789-P  TH-THR-10120-D-0001
# 2       WOW Subang SS15       WOW Subang SS15  MY-WOW-47500-D-0037
# 3             Media Uno             Media Uno  MY-MED-47800-D-0025
# 4  WOW Taman Sri Rampai  WOW Taman Sri Rampai  MY-WOW-53300-D-0036
#
#                           Media Operator Facing Direction Category Format  \
# 0                    Movingwalls Sdn Bhd            SOUTH   INDOOR    NaN
# 1  ThreeSixtyFive Public Company Limited       NORTH-WEST   INDOOR    NaN
# 2                    WOW OUTDOOR SDN BHD            NORTH  OUTDOOR  LARGE
# 3                      Media Uno Sdn Bhd       NORTH-EAST  OUTDOOR    NaN
# 4                    WOW OUTDOOR SDN BHD             EAST  OUTDOOR  LARGE
#
#   Group             Type                                     Market Segment  \
# ...

# %%
sing.Country
# Out:
# 0                  NaN
# 1             Thailand
# 2             Malaysia
# 3             Malaysia
# 4             Malaysia
# 5             Malaysia
# 6             Malaysia
# 7             Malaysia
# 8             Malaysia
# 9             Malaysia
# 10            Malaysia
# 11           Singapore
# 12           Singapore
# 13           Singapore
# 14           Singapore
# 15           Singapore
# 16           Singapore
# 17            Malaysia
# 18           Singapore
# 19            Malaysia
# 20            Malaysia
# 21            Malaysia
# 22            Malaysia
# 23            Malaysia
# 24            Malaysia
# 25            Malaysia
# 26            Malaysia
# 27            Malaysia
# 28            Malaysia
# 29            Malaysia
#              ...
# 4096         Indonesia
# 4097         Indonesia
# 4098         Indonesia
# 4099          Malaysia
# 4100          Malaysia
# 4101          Malaysia
# 4102          Malaysia
# 4103          Malaysia
# 4104          Malaysia
# ...

# %%
big = sing[sing["Country"]=="Singapore"]
big.head()
big = big.reset_index()
big.head()
# Out:
#    index                                        Name  \
# 0     11                         SPHMBO- South Beach
# 1     12                        OOHMedia- JUNCTION 8
# 2     13     Tanah Merah Ferry terminal Arrival hall
# 3     14  Tanah Merah Ferry terminal Departure Hall
# 4     15    Harbour Front – Level 2– departure hall
#
#                                  Display Name                Ref ID  \
# 0                                 South Beach  SG-SPH-189671-D-0001
# 1                                  JUNCTION 8  SG-MED-579840-D-0002
# 2     Tanah Merah Ferry terminal Arrival hall  SG-KIN-498833-D-0005
# 3  Tanah Merah Ferry terminal Departure Hall   SG-KIN-498833-D-0004
# 4    Harbour Front – Level 2– departure hall   SG-KIN-099253-D-0003
#
#                Media Operator Facing Direction Category  Format   Group  \
# 0                      sphmbo            NORTH   INDOOR   LARGE    SHOP
# 1         Mediacorp Singapore            NORTH  OUTDOOR  MEDIUM    SHOP
# ...

# %%
big = big.loc[:,['Ref ID','Latitude','Longitude',"Postal Code","Address"]]

# %%
big.head()
# Out:
#    Ref ID  Latitude   Longitude Postal Code  \
# 0     NaN  1.293772  103.855358      189671
# 1     NaN  1.350542  103.849092      579840
# 2     NaN  1.313845  103.986453      498833
# 3     NaN  1.314009  103.986412      498833
# 4     NaN  1.263282  103.819781       99253
#
#                                        Address
# 0                28 Beach Rd, Singapore 189768
# 1                9 Bishan Pl, Singapore 579837
# 2  50 Tanah Merah Ferry Road, Singapore 498833
# 3  50 Tanah Merah Ferry Road, Singapore 498833
# 4                  Harbourfront Ave, Singapore

# %%
big.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 695 entries, 0 to 694
# Data columns (total 5 columns):
# Ref Id         0 non-null float64
# Latitude       695 non-null float64
# Longitude      695 non-null float64
# Postal Code    681 non-null object
# Address        605 non-null object
# dtypes: float64(3), object(2)
# memory usage: 27.2+ KB
